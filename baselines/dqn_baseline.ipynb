# %%
import gymnasium as gym
import gymnasium_2048
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque, defaultdict, Counter
import random

# --- Setup --- 
# create and fully unwrap (removes TimeLimit wrapper)
env = gym.make("gymnasium_2048/TwentyFortyEight-v0")
env = env.unwrapped

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Hyperparameters ---
GAMMA = 0.99
LR = 1e-3
EPSILON_START = 1.0
EPSILON_END = 0.05
EPSILON_DECAY = 0.995
BATCH_SIZE = 64
MEMORY_SIZE = 10000
TARGET_UPDATE_FREQ = 10
ROLLING_WINDOW = 20
CONVERGENCE_SCORE = 2000
MAX_EPISODES = 10000
WARMUP_MEMORY = 1000
DEBUG_EPISODES = 0

ACTION_MAP = {0: "Up", 1: "Right", 2: "Down", 3: "Left"}

# --- DQN Model ---
class DQN(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(16, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 4)
        )
    def forward(self, x):
        return self.net(x)

# --- Preprocess ---
def preprocess(state):
    # same as before: log2 scaling into float32
    if state.ndim == 3:
        exp_board = np.argmax(state, axis=2)
        board = exp_board.astype(np.float32)
    elif state.ndim == 2:
        board = np.where(state == 0, 0, np.log2(state)).astype(np.float32)
    else:
        raise ValueError(f"Unexpected state shape: {state.shape}")
    return torch.tensor(board.flatten(), dtype=torch.float32, device=device)

# --- Decode for debug & int‐casting to avoid uint8 wraparound ---
def decode_obs(obs):
    if obs.ndim == 3:
        exp_board = np.argmax(obs, axis=2)
        # cast to int32 so merges >256 don’t wrap
        return np.where(exp_board == 0, 0, 2 ** exp_board).astype(np.int32)
    # obs may be uint8; cast it
    return obs.astype(np.int32)

# --- Slide logic for valid moves ---
def slide_row(row):
    nonzeros = [int(v) for v in row if v]  # ensure Python ints
    merged = []
    i = 0
    while i < len(nonzeros):
        if i + 1 < len(nonzeros) and nonzeros[i] == nonzeros[i+1]:
            merged.append(nonzeros[i] * 2)
            i += 2
        else:
            merged.append(nonzeros[i])
            i += 1
    merged += [0] * (len(row) - len(merged))
    return merged

def slide(board, action):
    # board is assumed int32 numpy array
    b = board.copy().astype(np.int32)
    if action == 0:  # Up
        b = b.T
        for i in range(4):
            b[i] = slide_row(list(b[i]))
        b = b.T
    elif action == 2:  # Down
        b = b.T
        for i in range(4):
            rev = list(reversed(b[i]))
            slid = slide_row(rev)
            b[i] = list(reversed(slid))
        b = b.T
    elif action == 3:  # Left
        for i in range(4):
            b[i] = slide_row(list(b[i]))
    elif action == 1:  # Right
        for i in range(4):
            rev = list(reversed(b[i]))
            slid = slide_row(rev)
            b[i] = list(reversed(slid))
    return b

# --- Valid actions without env.step ---
def valid_actions(obs):
    board = decode_obs(obs)
    # try each action on integer board
    return [a for a in range(4) if not np.array_equal(board, slide(board, a))]

# --- Select action ---
def sample_action(state, obs, explore=True):
    valids = valid_actions(obs)
    if not valids:
        return None
    if explore and random.random() < epsilon:
        return random.choice(valids)
    with torch.no_grad():
        q_vals = policy_net(state).cpu().numpy()
        return max(valids, key=lambda a: q_vals[a])

# --- Networks & memory ---
policy_net = DQN().to(device)
target_net = DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=LR)
memory    = deque(maxlen=MEMORY_SIZE)

epsilon = EPSILON_START
score_history = []
move_counter_global = defaultdict(int)
episode_bucket_counts = []

# --- Optimize ---
def optimize():
    if len(memory) < BATCH_SIZE:
        return
    batch = random.sample(memory, BATCH_SIZE)
    states, actions, rewards, next_states, dones = zip(*batch)
    states      = torch.stack(states)
    actions     = torch.tensor(actions).unsqueeze(1).to(device)
    rewards     = torch.tensor(rewards).float().to(device)
    next_states = torch.stack(next_states)
    dones       = torch.tensor(dones).float().to(device)

    q      = policy_net(states).gather(1, actions).squeeze()
    q_next = target_net(next_states).max(1)[0].detach()
    target = rewards + GAMMA * q_next * (1 - dones)

    loss = nn.functional.mse_loss(q, target)
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(policy_net.parameters(), 1.0)
    optimizer.step()

# --- Training Loop ---
global_max_tile = 0
episode = 0
episode_max_tile = 0
while episode < MAX_EPISODES:
    obs, _ = env.reset()
    # track the largest tile this episode
    episode_max_tile = 0
    state   = preprocess(obs)
    running_score = 0
    move_counter_episode = defaultdict(int)

    step = 0
    while True:
        action = sample_action(state, obs)
        if action is None:
            break

        move_counter_episode[ACTION_MAP[action]] += 1
        move_counter_global[ACTION_MAP[action]] += 1

        next_obs, reward, terminated, truncated, info = env.step(action)
        # decode board into ints and update max‐tile
        board = decode_obs(next_obs)
        episode_max_tile = max(episode_max_tile, int(board.max()))
        done = terminated or truncated
        next_state = preprocess(next_obs)

        memory.append((state, action, reward, next_state, done))
        state, obs = next_state, next_obs

        # force Python int accumulation
        running_score = int(running_score) + int(reward)

        if len(memory) > WARMUP_MEMORY:
            optimize()
        if done:
            break
        step += 1

    # Episode summary
    print(f"Episode {episode}, Score:{running_score}, MaxTile:{episode_max_tile}, Epsilon:{epsilon:.3f}")

    # Update global max tile
    global_max_tile = max(global_max_tile, episode_max_tile)

    # Target network update
    if episode % TARGET_UPDATE_FREQ == 0:
        target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
    score_history.append(running_score)

    # Check convergence
    if (episode >= ROLLING_WINDOW and
        np.mean(score_history[-ROLLING_WINDOW:]) >= CONVERGENCE_SCORE):
        print(f"\n✅ Converged at episode {episode}")
        break

    episode += 1

# Print best max tile over all episodes
print(f"🏆 Best MaxTile over all episodes: {global_max_tile}")
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cs224r-final-project/lib/python3.10/site-packages/gymnasium_2048/envs/twenty_forty_eight.py:250: RuntimeWarning: overflow encountered in scalar add
#   self.total_score += self.step_score
# Episode 0, Score:1252, MaxTile:128, Epsilon:1.000
# Episode 1, Score:988, MaxTile:64, Epsilon:0.995
# Episode 2, Score:828, MaxTile:64, Epsilon:0.990
# Episode 3, Score:1568, MaxTile:128, Epsilon:0.985
# Episode 4, Score:1872, MaxTile:128, Epsilon:0.980
# Episode 5, Score:2048, MaxTile:128, Epsilon:0.975
# Episode 6, Score:596, MaxTile:64, Epsilon:0.970
# Episode 7, Score:1204, MaxTile:128, Epsilon:0.966
# Episode 8, Score:720, MaxTile:64, Epsilon:0.961
# Episode 9, Score:388, MaxTile:32, Epsilon:0.956
# Episode 10, Score:1272, MaxTile:128, Epsilon:0.951
# Episode 11, Score:328, MaxTile:32, Epsilon:0.946
# Episode 12, Score:1300, MaxTile:128, Epsilon:0.942
# Episode 13, Score:532, MaxTile:64, Epsilon:0.937
# Episode 14, Score:1752, MaxTile:128, Epsilon:0.932
# Episode 15, Score:600, MaxTile:64, Epsilon:0.928
# Episode 16, Score:1444, MaxTile:128, Epsilon:0.923
# Episode 17, Score:1344, MaxTile:128, Epsilon:0.918
# Episode 18, Score:1036, MaxTile:128, Epsilon:0.914
# Episode 19, Score:1312, MaxTile:128, Epsilon:0.909
# Episode 20, Score:1436, MaxTile:128, Epsilon:0.905
# Episode 21, Score:564, MaxTile:64, Epsilon:0.900
# Episode 22, Score:268, MaxTile:32, Epsilon:0.896
# Episode 23, Score:904, MaxTile:64, Epsilon:0.891
# Episode 24, Score:612, MaxTile:64, Epsilon:0.887
# Episode 25, Score:632, MaxTile:64, Epsilon:0.882
# Episode 26, Score:1084, MaxTile:64, Epsilon:0.878
# Episode 27, Score:688, MaxTile:64, Epsilon:0.873
# Episode 28, Score:1556, MaxTile:128, Epsilon:0.869
# Episode 29, Score:1364, MaxTile:128, Epsilon:0.865
# Episode 30, Score:620, MaxTile:64, Epsilon:0.860
# Episode 31, Score:1524, MaxTile:128, Epsilon:0.856
# Episode 32, Score:540, MaxTile:64, Epsilon:0.852
# Episode 33, Score:1420, MaxTile:128, Epsilon:0.848
# Episode 34, Score:652, MaxTile:64, Epsilon:0.843
# Episode 35, Score:800, MaxTile:64, Epsilon:0.839
# Episode 36, Score:1804, MaxTile:128, Epsilon:0.835
# Episode 37, Score:620, MaxTile:64, Epsilon:0.831
# Episode 38, Score:1272, MaxTile:128, Epsilon:0.827
# Episode 39, Score:1320, MaxTile:128, Epsilon:0.822
# Episode 40, Score:544, MaxTile:64, Epsilon:0.818
# Episode 41, Score:712, MaxTile:64, Epsilon:0.814
# Episode 42, Score:568, MaxTile:64, Epsilon:0.810
# Episode 43, Score:556, MaxTile:64, Epsilon:0.806
# Episode 44, Score:504, MaxTile:32, Epsilon:0.802
# Episode 45, Score:1300, MaxTile:128, Epsilon:0.798
# Episode 46, Score:1316, MaxTile:128, Epsilon:0.794
# Episode 47, Score:1356, MaxTile:128, Epsilon:0.790
# Episode 48, Score:828, MaxTile:64, Epsilon:0.786
# Episode 49, Score:1240, MaxTile:128, Epsilon:0.782
# Episode 50, Score:684, MaxTile:64, Epsilon:0.778
# Episode 51, Score:672, MaxTile:64, Epsilon:0.774
# Episode 52, Score:1412, MaxTile:128, Epsilon:0.771
# Episode 53, Score:676, MaxTile:64, Epsilon:0.767
# Episode 54, Score:1732, MaxTile:128, Epsilon:0.763
# Episode 55, Score:532, MaxTile:64, Epsilon:0.759
# Episode 56, Score:720, MaxTile:64, Epsilon:0.755
# Episode 57, Score:620, MaxTile:64, Epsilon:0.751
# Episode 58, Score:1408, MaxTile:128, Epsilon:0.748
# Episode 59, Score:580, MaxTile:64, Epsilon:0.744
# Episode 60, Score:740, MaxTile:64, Epsilon:0.740
# Episode 61, Score:2128, MaxTile:256, Epsilon:0.737
# Episode 62, Score:1320, MaxTile:128, Epsilon:0.733
# Episode 63, Score:1076, MaxTile:128, Epsilon:0.729
# Episode 64, Score:912, MaxTile:64, Epsilon:0.726
# Episode 65, Score:292, MaxTile:32, Epsilon:0.722
# Episode 66, Score:1320, MaxTile:128, Epsilon:0.718
# Episode 67, Score:1424, MaxTile:128, Epsilon:0.715
# Episode 68, Score:592, MaxTile:64, Epsilon:0.711
# Episode 69, Score:664, MaxTile:64, Epsilon:0.708
# Episode 70, Score:1136, MaxTile:64, Epsilon:0.704
# Episode 71, Score:636, MaxTile:64, Epsilon:0.701
# Episode 72, Score:1572, MaxTile:128, Epsilon:0.697
# Episode 73, Score:652, MaxTile:64, Epsilon:0.694
# Episode 74, Score:944, MaxTile:64, Epsilon:0.690
# Episode 75, Score:1456, MaxTile:128, Epsilon:0.687
# Episode 76, Score:1304, MaxTile:128, Epsilon:0.683
# Episode 77, Score:1372, MaxTile:128, Epsilon:0.680
# Episode 78, Score:1132, MaxTile:128, Epsilon:0.676
# Episode 79, Score:652, MaxTile:64, Epsilon:0.673
# Episode 80, Score:1156, MaxTile:128, Epsilon:0.670
# Episode 81, Score:1424, MaxTile:128, Epsilon:0.666
# Episode 82, Score:564, MaxTile:64, Epsilon:0.663
# Episode 83, Score:1296, MaxTile:128, Epsilon:0.660
# Episode 84, Score:856, MaxTile:128, Epsilon:0.656
# Episode 85, Score:600, MaxTile:64, Epsilon:0.653
# Episode 86, Score:504, MaxTile:64, Epsilon:0.650
# Episode 87, Score:1804, MaxTile:256, Epsilon:0.647
# Episode 88, Score:744, MaxTile:64, Epsilon:0.643
# Episode 89, Score:920, MaxTile:64, Epsilon:0.640
# Episode 90, Score:576, MaxTile:64, Epsilon:0.637
# Episode 91, Score:872, MaxTile:128, Epsilon:0.634
# Episode 92, Score:1416, MaxTile:128, Epsilon:0.631
# Episode 93, Score:540, MaxTile:64, Epsilon:0.627
# Episode 94, Score:1348, MaxTile:128, Epsilon:0.624
# Episode 95, Score:576, MaxTile:64, Epsilon:0.621
# Episode 96, Score:664, MaxTile:64, Epsilon:0.618
# Episode 97, Score:1440, MaxTile:128, Epsilon:0.615
# Episode 98, Score:1472, MaxTile:128, Epsilon:0.612
# Episode 99, Score:856, MaxTile:64, Epsilon:0.609
# Episode 100, Score:660, MaxTile:64, Epsilon:0.606
# Episode 101, Score:1500, MaxTile:128, Epsilon:0.603
# Episode 102, Score:1452, MaxTile:128, Epsilon:0.600
# Episode 103, Score:1484, MaxTile:128, Epsilon:0.597
# Episode 104, Score:680, MaxTile:64, Epsilon:0.594
# Episode 105, Score:1268, MaxTile:128, Epsilon:0.591
# Episode 106, Score:1008, MaxTile:128, Epsilon:0.588
# Episode 107, Score:1600, MaxTile:128, Epsilon:0.585
# Episode 108, Score:1324, MaxTile:128, Epsilon:0.582
# Episode 109, Score:1564, MaxTile:128, Epsilon:0.579
# Episode 110, Score:824, MaxTile:64, Epsilon:0.576
# Episode 111, Score:1756, MaxTile:128, Epsilon:0.573
# Episode 112, Score:476, MaxTile:64, Epsilon:0.570
# Episode 113, Score:1000, MaxTile:128, Epsilon:0.568
# Episode 114, Score:1128, MaxTile:128, Epsilon:0.565
# Episode 115, Score:2192, MaxTile:256, Epsilon:0.562
# Episode 116, Score:1140, MaxTile:128, Epsilon:0.559
# Episode 117, Score:616, MaxTile:64, Epsilon:0.556
# Episode 118, Score:2072, MaxTile:128, Epsilon:0.554
# Episode 119, Score:1220, MaxTile:128, Epsilon:0.551
# Episode 120, Score:444, MaxTile:64, Epsilon:0.548
# Episode 121, Score:1312, MaxTile:128, Epsilon:0.545
# Episode 122, Score:1124, MaxTile:128, Epsilon:0.543
# Episode 123, Score:2348, MaxTile:256, Epsilon:0.540
# Episode 124, Score:824, MaxTile:64, Epsilon:0.537
# Episode 125, Score:644, MaxTile:64, Epsilon:0.534
# Episode 126, Score:1280, MaxTile:128, Epsilon:0.532
# Episode 127, Score:2336, MaxTile:256, Epsilon:0.529
# Episode 128, Score:1120, MaxTile:128, Epsilon:0.526
# Episode 129, Score:956, MaxTile:128, Epsilon:0.524
# Episode 130, Score:620, MaxTile:64, Epsilon:0.521
# Episode 131, Score:700, MaxTile:64, Epsilon:0.519
# Episode 132, Score:1040, MaxTile:128, Epsilon:0.516
# Episode 133, Score:1344, MaxTile:128, Epsilon:0.513
# Episode 134, Score:1352, MaxTile:128, Epsilon:0.511
# Episode 135, Score:1272, MaxTile:128, Epsilon:0.508
# Episode 136, Score:372, MaxTile:32, Epsilon:0.506
# Episode 137, Score:1040, MaxTile:128, Epsilon:0.503
# Episode 138, Score:988, MaxTile:128, Epsilon:0.501
# Episode 139, Score:1444, MaxTile:128, Epsilon:0.498
# Episode 140, Score:2060, MaxTile:256, Epsilon:0.496
# Episode 141, Score:1324, MaxTile:128, Epsilon:0.493
# Episode 142, Score:664, MaxTile:64, Epsilon:0.491
# Episode 143, Score:1108, MaxTile:128, Epsilon:0.488
# Episode 144, Score:1456, MaxTile:128, Epsilon:0.486
# Episode 145, Score:1288, MaxTile:128, Epsilon:0.483
# Episode 146, Score:1168, MaxTile:128, Epsilon:0.481
# Episode 147, Score:1436, MaxTile:128, Epsilon:0.479
# Episode 148, Score:340, MaxTile:32, Epsilon:0.476
# Episode 149, Score:616, MaxTile:64, Epsilon:0.474
# Episode 150, Score:1360, MaxTile:128, Epsilon:0.471
# Episode 151, Score:1288, MaxTile:128, Epsilon:0.469
# Episode 152, Score:588, MaxTile:32, Epsilon:0.467
# Episode 153, Score:952, MaxTile:64, Epsilon:0.464
# Episode 154, Score:1272, MaxTile:128, Epsilon:0.462
# Episode 155, Score:1824, MaxTile:256, Epsilon:0.460
# Episode 156, Score:612, MaxTile:64, Epsilon:0.458
# Episode 157, Score:1192, MaxTile:128, Epsilon:0.455
# Episode 158, Score:616, MaxTile:64, Epsilon:0.453
# Episode 159, Score:580, MaxTile:64, Epsilon:0.451
# Episode 160, Score:1172, MaxTile:128, Epsilon:0.448
# Episode 161, Score:908, MaxTile:128, Epsilon:0.446
# Episode 162, Score:628, MaxTile:64, Epsilon:0.444
# Episode 163, Score:660, MaxTile:64, Epsilon:0.442
# Episode 164, Score:1012, MaxTile:128, Epsilon:0.440
# Episode 165, Score:2072, MaxTile:256, Epsilon:0.437
# Episode 166, Score:2516, MaxTile:256, Epsilon:0.435
# Episode 167, Score:716, MaxTile:64, Epsilon:0.433
# Episode 168, Score:1400, MaxTile:128, Epsilon:0.431
# Episode 169, Score:1200, MaxTile:128, Epsilon:0.429
# Episode 170, Score:496, MaxTile:64, Epsilon:0.427
# Episode 171, Score:724, MaxTile:64, Epsilon:0.424
# Episode 172, Score:1764, MaxTile:256, Epsilon:0.422
# Episode 173, Score:1384, MaxTile:128, Epsilon:0.420
# Episode 174, Score:984, MaxTile:64, Epsilon:0.418
# Episode 175, Score:1752, MaxTile:256, Epsilon:0.416
# Episode 176, Score:1212, MaxTile:128, Epsilon:0.414
# Episode 177, Score:532, MaxTile:64, Epsilon:0.412
# Episode 178, Score:608, MaxTile:64, Epsilon:0.410
# Episode 179, Score:956, MaxTile:64, Epsilon:0.408
# Episode 180, Score:1188, MaxTile:128, Epsilon:0.406
# Episode 181, Score:1388, MaxTile:128, Epsilon:0.404
# Episode 182, Score:1128, MaxTile:128, Epsilon:0.402
# Episode 183, Score:348, MaxTile:32, Epsilon:0.400
# Episode 184, Score:1284, MaxTile:128, Epsilon:0.398
# Episode 185, Score:1408, MaxTile:128, Epsilon:0.396
# Episode 186, Score:828, MaxTile:64, Epsilon:0.394
# Episode 187, Score:936, MaxTile:64, Epsilon:0.392
# Episode 188, Score:2764, MaxTile:256, Epsilon:0.390
# Episode 189, Score:1248, MaxTile:128, Epsilon:0.388
# Episode 190, Score:568, MaxTile:64, Epsilon:0.386
# Episode 191, Score:656, MaxTile:64, Epsilon:0.384
# Episode 192, Score:1120, MaxTile:128, Epsilon:0.382
# Episode 193, Score:444, MaxTile:32, Epsilon:0.380
# Episode 194, Score:1436, MaxTile:128, Epsilon:0.378
# Episode 195, Score:1364, MaxTile:128, Epsilon:0.376
# Episode 196, Score:620, MaxTile:64, Epsilon:0.374
# Episode 197, Score:1344, MaxTile:128, Epsilon:0.373
# Episode 198, Score:888, MaxTile:64, Epsilon:0.371
# Episode 199, Score:592, MaxTile:64, Epsilon:0.369
# Episode 200, Score:808, MaxTile:64, Epsilon:0.367
# Episode 201, Score:456, MaxTile:64, Epsilon:0.365
# Episode 202, Score:1148, MaxTile:128, Epsilon:0.363
# Episode 203, Score:1340, MaxTile:128, Epsilon:0.361
# Episode 204, Score:524, MaxTile:64, Epsilon:0.360
# Episode 205, Score:1484, MaxTile:128, Epsilon:0.358
# Episode 206, Score:1300, MaxTile:128, Epsilon:0.356
# Episode 207, Score:1324, MaxTile:128, Epsilon:0.354
# Episode 208, Score:880, MaxTile:64, Epsilon:0.353
# Episode 209, Score:1156, MaxTile:128, Epsilon:0.351
# Episode 210, Score:1812, MaxTile:256, Epsilon:0.349
# Episode 211, Score:792, MaxTile:64, Epsilon:0.347
# Episode 212, Score:1128, MaxTile:128, Epsilon:0.346
# Episode 213, Score:484, MaxTile:64, Epsilon:0.344
# Episode 214, Score:616, MaxTile:64, Epsilon:0.342
# Episode 215, Score:1032, MaxTile:128, Epsilon:0.340
# Episode 216, Score:680, MaxTile:64, Epsilon:0.339
# Episode 217, Score:1580, MaxTile:128, Epsilon:0.337
# Episode 218, Score:2308, MaxTile:256, Epsilon:0.335
# Episode 219, Score:1244, MaxTile:128, Epsilon:0.334
# Episode 220, Score:1212, MaxTile:128, Epsilon:0.332
# Episode 221, Score:816, MaxTile:64, Epsilon:0.330
# Episode 222, Score:980, MaxTile:64, Epsilon:0.329
# Episode 223, Score:776, MaxTile:64, Epsilon:0.327
# Episode 224, Score:1032, MaxTile:64, Epsilon:0.325
# Episode 225, Score:1104, MaxTile:128, Epsilon:0.324
# Episode 226, Score:748, MaxTile:64, Epsilon:0.322
# Episode 227, Score:544, MaxTile:64, Epsilon:0.321
# Episode 228, Score:316, MaxTile:32, Epsilon:0.319
# Episode 229, Score:884, MaxTile:64, Epsilon:0.317
# Episode 230, Score:620, MaxTile:64, Epsilon:0.316
# Episode 231, Score:1400, MaxTile:128, Epsilon:0.314
# Episode 232, Score:1296, MaxTile:128, Epsilon:0.313
# Episode 233, Score:1248, MaxTile:128, Epsilon:0.311
# Episode 234, Score:1444, MaxTile:128, Epsilon:0.309
# Episode 235, Score:288, MaxTile:32, Epsilon:0.308
# Episode 236, Score:404, MaxTile:32, Epsilon:0.306
# Episode 237, Score:1320, MaxTile:128, Epsilon:0.305
# Episode 238, Score:1000, MaxTile:128, Epsilon:0.303
# Episode 239, Score:740, MaxTile:64, Epsilon:0.302
# Episode 240, Score:656, MaxTile:64, Epsilon:0.300
# Episode 241, Score:1368, MaxTile:128, Epsilon:0.299
# Episode 242, Score:696, MaxTile:64, Epsilon:0.297
# Episode 243, Score:1444, MaxTile:128, Epsilon:0.296
# Episode 244, Score:288, MaxTile:32, Epsilon:0.294
# Episode 245, Score:408, MaxTile:32, Epsilon:0.293
# Episode 246, Score:1484, MaxTile:128, Epsilon:0.291
# Episode 247, Score:200, MaxTile:16, Epsilon:0.290
# Episode 248, Score:1920, MaxTile:256, Epsilon:0.288
# Episode 249, Score:1020, MaxTile:128, Epsilon:0.287
# Episode 250, Score:888, MaxTile:64, Epsilon:0.286
# Episode 251, Score:1368, MaxTile:128, Epsilon:0.284
# Episode 252, Score:2436, MaxTile:256, Epsilon:0.283
# Episode 253, Score:1468, MaxTile:128, Epsilon:0.281
# Episode 254, Score:1032, MaxTile:128, Epsilon:0.280
# Episode 255, Score:1412, MaxTile:128, Epsilon:0.279
# Episode 256, Score:1476, MaxTile:128, Epsilon:0.277
# Episode 257, Score:1252, MaxTile:128, Epsilon:0.276
# Episode 258, Score:744, MaxTile:64, Epsilon:0.274
# Episode 259, Score:996, MaxTile:128, Epsilon:0.273
# Episode 260, Score:1308, MaxTile:128, Epsilon:0.272
# Episode 261, Score:1340, MaxTile:128, Epsilon:0.270
# Episode 262, Score:184, MaxTile:16, Epsilon:0.269
# Episode 263, Score:1132, MaxTile:128, Epsilon:0.268
# Episode 264, Score:1224, MaxTile:128, Epsilon:0.266
# Episode 265, Score:1356, MaxTile:128, Epsilon:0.265
# Episode 266, Score:1112, MaxTile:128, Epsilon:0.264
# Episode 267, Score:1348, MaxTile:128, Epsilon:0.262
# Episode 268, Score:1272, MaxTile:128, Epsilon:0.261
# Episode 269, Score:1292, MaxTile:128, Epsilon:0.260
# Episode 270, Score:1544, MaxTile:128, Epsilon:0.258
# Episode 271, Score:1052, MaxTile:128, Epsilon:0.257
# Episode 272, Score:1228, MaxTile:128, Epsilon:0.256
# Episode 273, Score:788, MaxTile:64, Epsilon:0.255
# Episode 274, Score:460, MaxTile:64, Epsilon:0.253
# Episode 275, Score:1676, MaxTile:128, Epsilon:0.252
# Episode 276, Score:1412, MaxTile:128, Epsilon:0.251
# Episode 277, Score:1176, MaxTile:128, Epsilon:0.249
# Episode 278, Score:420, MaxTile:32, Epsilon:0.248
# Episode 279, Score:1376, MaxTile:128, Epsilon:0.247
# Episode 280, Score:652, MaxTile:64, Epsilon:0.246
# Episode 281, Score:1408, MaxTile:128, Epsilon:0.245
# Episode 282, Score:1132, MaxTile:128, Epsilon:0.243
# Episode 283, Score:732, MaxTile:64, Epsilon:0.242
# Episode 284, Score:1688, MaxTile:128, Epsilon:0.241
# Episode 285, Score:528, MaxTile:64, Epsilon:0.240
# Episode 286, Score:1332, MaxTile:128, Epsilon:0.238
# Episode 287, Score:564, MaxTile:64, Epsilon:0.237
# Episode 288, Score:600, MaxTile:64, Epsilon:0.236
# Episode 289, Score:672, MaxTile:64, Epsilon:0.235
# Episode 290, Score:912, MaxTile:64, Epsilon:0.234
# Episode 291, Score:748, MaxTile:64, Epsilon:0.233
# Episode 292, Score:760, MaxTile:64, Epsilon:0.231
# Episode 293, Score:1316, MaxTile:128, Epsilon:0.230
# Episode 294, Score:752, MaxTile:64, Epsilon:0.229
# Episode 295, Score:932, MaxTile:64, Epsilon:0.228
# Episode 296, Score:1140, MaxTile:128, Epsilon:0.227
# Episode 297, Score:972, MaxTile:128, Epsilon:0.226
# Episode 298, Score:1448, MaxTile:128, Epsilon:0.225
# Episode 299, Score:1500, MaxTile:128, Epsilon:0.223
# Episode 300, Score:1260, MaxTile:128, Epsilon:0.222
# Episode 301, Score:640, MaxTile:64, Epsilon:0.221
# Episode 302, Score:1376, MaxTile:128, Epsilon:0.220
# Episode 303, Score:1720, MaxTile:128, Epsilon:0.219
# Episode 304, Score:816, MaxTile:64, Epsilon:0.218
# Episode 305, Score:536, MaxTile:64, Epsilon:0.217
# Episode 306, Score:680, MaxTile:64, Epsilon:0.216
# Episode 307, Score:1132, MaxTile:128, Epsilon:0.215
# Episode 308, Score:2204, MaxTile:256, Epsilon:0.214
# Episode 309, Score:472, MaxTile:64, Epsilon:0.212
# Episode 310, Score:1312, MaxTile:128, Epsilon:0.211
# Episode 311, Score:1016, MaxTile:64, Epsilon:0.210
# Episode 312, Score:740, MaxTile:64, Epsilon:0.209
# Episode 313, Score:1248, MaxTile:128, Epsilon:0.208
# Episode 314, Score:764, MaxTile:64, Epsilon:0.207
# Episode 315, Score:1904, MaxTile:256, Epsilon:0.206
# Episode 316, Score:576, MaxTile:64, Epsilon:0.205
# Episode 317, Score:1524, MaxTile:128, Epsilon:0.204
# Episode 318, Score:1608, MaxTile:128, Epsilon:0.203
# Episode 319, Score:916, MaxTile:64, Epsilon:0.202
# Episode 320, Score:1284, MaxTile:128, Epsilon:0.201
# Episode 321, Score:748, MaxTile:64, Epsilon:0.200
# Episode 322, Score:632, MaxTile:64, Epsilon:0.199
# Episode 323, Score:764, MaxTile:64, Epsilon:0.198
# Episode 324, Score:696, MaxTile:64, Epsilon:0.197
# Episode 325, Score:552, MaxTile:64, Epsilon:0.196
# Episode 326, Score:1320, MaxTile:128, Epsilon:0.195
# Episode 327, Score:1036, MaxTile:128, Epsilon:0.194
# Episode 328, Score:388, MaxTile:32, Epsilon:0.193
# Episode 329, Score:624, MaxTile:64, Epsilon:0.192
# Episode 330, Score:940, MaxTile:128, Epsilon:0.191
# Episode 331, Score:1452, MaxTile:128, Epsilon:0.190
# Episode 332, Score:1500, MaxTile:128, Epsilon:0.189
# Episode 333, Score:1336, MaxTile:128, Epsilon:0.188
# Episode 334, Score:1032, MaxTile:128, Epsilon:0.187
# Episode 335, Score:2048, MaxTile:128, Epsilon:0.187
# Episode 336, Score:940, MaxTile:64, Epsilon:0.186
# Episode 337, Score:1888, MaxTile:256, Epsilon:0.185
# Episode 338, Score:780, MaxTile:64, Epsilon:0.184
# Episode 339, Score:344, MaxTile:32, Epsilon:0.183
# Episode 340, Score:756, MaxTile:64, Epsilon:0.182
# Episode 341, Score:676, MaxTile:64, Epsilon:0.181
# Episode 342, Score:1496, MaxTile:128, Epsilon:0.180
# Episode 343, Score:1548, MaxTile:128, Epsilon:0.179
# Episode 344, Score:416, MaxTile:32, Epsilon:0.178
# Episode 345, Score:296, MaxTile:32, Epsilon:0.177
# Episode 346, Score:1900, MaxTile:256, Epsilon:0.177
# Episode 347, Score:1100, MaxTile:128, Epsilon:0.176
# Episode 348, Score:636, MaxTile:64, Epsilon:0.175
# Episode 349, Score:696, MaxTile:64, Epsilon:0.174
# Episode 350, Score:892, MaxTile:64, Epsilon:0.173
# Episode 351, Score:472, MaxTile:32, Epsilon:0.172
# Episode 352, Score:388, MaxTile:32, Epsilon:0.171
# Episode 353, Score:532, MaxTile:64, Epsilon:0.170
# Episode 354, Score:1696, MaxTile:128, Epsilon:0.170
# Episode 355, Score:820, MaxTile:64, Epsilon:0.169
# Episode 356, Score:548, MaxTile:64, Epsilon:0.168
# Episode 357, Score:668, MaxTile:64, Epsilon:0.167
# Episode 358, Score:2412, MaxTile:256, Epsilon:0.166
# Episode 359, Score:1016, MaxTile:64, Epsilon:0.165
# Episode 360, Score:388, MaxTile:32, Epsilon:0.165
# Episode 361, Score:544, MaxTile:64, Epsilon:0.164
# Episode 362, Score:888, MaxTile:64, Epsilon:0.163
# Episode 363, Score:724, MaxTile:64, Epsilon:0.162
# Episode 364, Score:572, MaxTile:64, Epsilon:0.161
# Episode 365, Score:1260, MaxTile:128, Epsilon:0.160
# Episode 366, Score:580, MaxTile:64, Epsilon:0.160
# Episode 367, Score:1332, MaxTile:128, Epsilon:0.159
# Episode 368, Score:1072, MaxTile:128, Epsilon:0.158
# Episode 369, Score:660, MaxTile:64, Epsilon:0.157
# Episode 370, Score:1328, MaxTile:128, Epsilon:0.157
# Episode 371, Score:392, MaxTile:32, Epsilon:0.156
# Episode 372, Score:1092, MaxTile:128, Epsilon:0.155
# Episode 373, Score:1164, MaxTile:128, Epsilon:0.154
# Episode 374, Score:1232, MaxTile:128, Epsilon:0.153
# Episode 375, Score:1548, MaxTile:128, Epsilon:0.153
# Episode 376, Score:948, MaxTile:64, Epsilon:0.152
# Episode 377, Score:1936, MaxTile:256, Epsilon:0.151
# Episode 378, Score:716, MaxTile:64, Epsilon:0.150
# Episode 379, Score:1264, MaxTile:128, Epsilon:0.150
# Episode 380, Score:676, MaxTile:64, Epsilon:0.149
# Episode 381, Score:1436, MaxTile:128, Epsilon:0.148
# Episode 382, Score:1404, MaxTile:128, Epsilon:0.147
# Episode 383, Score:1276, MaxTile:128, Epsilon:0.147
# Episode 384, Score:1312, MaxTile:128, Epsilon:0.146
# Episode 385, Score:1856, MaxTile:256, Epsilon:0.145
# Episode 386, Score:316, MaxTile:32, Epsilon:0.144
# Episode 387, Score:492, MaxTile:32, Epsilon:0.144
# Episode 388, Score:980, MaxTile:128, Epsilon:0.143
# Episode 389, Score:1364, MaxTile:128, Epsilon:0.142
# Episode 390, Score:852, MaxTile:64, Epsilon:0.142
# Episode 391, Score:1240, MaxTile:128, Epsilon:0.141
# Episode 392, Score:956, MaxTile:64, Epsilon:0.140
# Episode 393, Score:1320, MaxTile:128, Epsilon:0.139
# Episode 394, Score:1344, MaxTile:128, Epsilon:0.139
# Episode 395, Score:712, MaxTile:64, Epsilon:0.138
# Episode 396, Score:1176, MaxTile:128, Epsilon:0.137
# Episode 397, Score:524, MaxTile:64, Epsilon:0.137
# Episode 398, Score:1436, MaxTile:128, Epsilon:0.136
# Episode 399, Score:296, MaxTile:32, Epsilon:0.135
# Episode 400, Score:936, MaxTile:64, Epsilon:0.135
# Episode 401, Score:836, MaxTile:64, Epsilon:0.134
# Episode 402, Score:988, MaxTile:64, Epsilon:0.133
# Episode 403, Score:656, MaxTile:64, Epsilon:0.133
# Episode 404, Score:1360, MaxTile:128, Epsilon:0.132
# Episode 405, Score:1164, MaxTile:128, Epsilon:0.131
# Episode 406, Score:476, MaxTile:32, Epsilon:0.131
# Episode 407, Score:912, MaxTile:128, Epsilon:0.130
# Episode 408, Score:680, MaxTile:64, Epsilon:0.129
# Episode 409, Score:1308, MaxTile:128, Epsilon:0.129
# Episode 410, Score:736, MaxTile:64, Epsilon:0.128
# Episode 411, Score:1044, MaxTile:64, Epsilon:0.127
# Episode 412, Score:996, MaxTile:128, Epsilon:0.127
# Episode 413, Score:2276, MaxTile:256, Epsilon:0.126
# Episode 414, Score:692, MaxTile:64, Epsilon:0.126
# Episode 415, Score:648, MaxTile:64, Epsilon:0.125
# Episode 416, Score:408, MaxTile:32, Epsilon:0.124
# Episode 417, Score:1752, MaxTile:128, Epsilon:0.124
# Episode 418, Score:716, MaxTile:64, Epsilon:0.123
# Episode 419, Score:840, MaxTile:64, Epsilon:0.122
# Episode 420, Score:1220, MaxTile:128, Epsilon:0.122
# Episode 421, Score:1320, MaxTile:128, Epsilon:0.121
# Episode 422, Score:1456, MaxTile:128, Epsilon:0.121
# Episode 423, Score:1216, MaxTile:128, Epsilon:0.120
# Episode 424, Score:1384, MaxTile:128, Epsilon:0.119
# Episode 425, Score:748, MaxTile:64, Epsilon:0.119
# Episode 426, Score:592, MaxTile:64, Epsilon:0.118
# Episode 427, Score:1408, MaxTile:128, Epsilon:0.118
# Episode 428, Score:1292, MaxTile:128, Epsilon:0.117
# Episode 429, Score:1416, MaxTile:128, Epsilon:0.116
# Episode 430, Score:1808, MaxTile:256, Epsilon:0.116
# Episode 431, Score:1432, MaxTile:128, Epsilon:0.115
# Episode 432, Score:976, MaxTile:128, Epsilon:0.115
# Episode 433, Score:556, MaxTile:64, Epsilon:0.114
# Episode 434, Score:432, MaxTile:32, Epsilon:0.114
# Episode 435, Score:1844, MaxTile:256, Epsilon:0.113
# Episode 436, Score:736, MaxTile:64, Epsilon:0.112
# Episode 437, Score:1700, MaxTile:128, Epsilon:0.112
# Episode 438, Score:2648, MaxTile:256, Epsilon:0.111
# Episode 439, Score:1768, MaxTile:128, Epsilon:0.111
# Episode 440, Score:1388, MaxTile:128, Epsilon:0.110
# Episode 441, Score:2716, MaxTile:256, Epsilon:0.110
# Episode 442, Score:1456, MaxTile:128, Epsilon:0.109
# Episode 443, Score:544, MaxTile:64, Epsilon:0.109
# Episode 444, Score:1392, MaxTile:128, Epsilon:0.108
# Episode 445, Score:476, MaxTile:32, Epsilon:0.107
# Episode 446, Score:580, MaxTile:64, Epsilon:0.107
# Episode 447, Score:1460, MaxTile:128, Epsilon:0.106
# Episode 448, Score:800, MaxTile:64, Epsilon:0.106
# Episode 449, Score:660, MaxTile:64, Epsilon:0.105
# Episode 450, Score:1636, MaxTile:128, Epsilon:0.105
# Episode 451, Score:660, MaxTile:64, Epsilon:0.104
# Episode 452, Score:1164, MaxTile:128, Epsilon:0.104
# Episode 453, Score:1156, MaxTile:128, Epsilon:0.103
# Episode 454, Score:1268, MaxTile:128, Epsilon:0.103
# Episode 455, Score:1544, MaxTile:128, Epsilon:0.102
# Episode 456, Score:376, MaxTile:32, Epsilon:0.102
# Episode 457, Score:2296, MaxTile:256, Epsilon:0.101
# Episode 458, Score:736, MaxTile:64, Epsilon:0.101
# Episode 459, Score:1580, MaxTile:128, Epsilon:0.100
# Episode 460, Score:820, MaxTile:64, Epsilon:0.100
# Episode 461, Score:1060, MaxTile:128, Epsilon:0.099
# Episode 462, Score:616, MaxTile:64, Epsilon:0.099
# Episode 463, Score:600, MaxTile:64, Epsilon:0.098
# Episode 464, Score:1620, MaxTile:128, Epsilon:0.098
# Episode 465, Score:356, MaxTile:32, Epsilon:0.097
# Episode 466, Score:740, MaxTile:64, Epsilon:0.097
# Episode 467, Score:880, MaxTile:64, Epsilon:0.096
# Episode 468, Score:612, MaxTile:64, Epsilon:0.096
# Episode 469, Score:820, MaxTile:64, Epsilon:0.095
# Episode 470, Score:1364, MaxTile:128, Epsilon:0.095
# Episode 471, Score:944, MaxTile:64, Epsilon:0.094
# Episode 472, Score:628, MaxTile:64, Epsilon:0.094
# Episode 473, Score:1356, MaxTile:128, Epsilon:0.093
# Episode 474, Score:376, MaxTile:32, Epsilon:0.093
# Episode 475, Score:768, MaxTile:64, Epsilon:0.092
# Episode 476, Score:792, MaxTile:64, Epsilon:0.092
# Episode 477, Score:912, MaxTile:128, Epsilon:0.092
# Episode 478, Score:1096, MaxTile:128, Epsilon:0.091
# Episode 479, Score:708, MaxTile:64, Epsilon:0.091
# Episode 480, Score:464, MaxTile:32, Epsilon:0.090
# Episode 481, Score:668, MaxTile:64, Epsilon:0.090
# Episode 482, Score:620, MaxTile:64, Epsilon:0.089
# Episode 483, Score:1256, MaxTile:128, Epsilon:0.089
# Episode 484, Score:1108, MaxTile:128, Epsilon:0.088
# Episode 485, Score:1044, MaxTile:128, Epsilon:0.088
# Episode 486, Score:1780, MaxTile:256, Epsilon:0.088
# Episode 487, Score:1076, MaxTile:128, Epsilon:0.087
# Episode 488, Score:1440, MaxTile:128, Epsilon:0.087
# Episode 489, Score:420, MaxTile:32, Epsilon:0.086
# Episode 490, Score:1388, MaxTile:128, Epsilon:0.086
# Episode 491, Score:1084, MaxTile:64, Epsilon:0.085
# Episode 492, Score:1048, MaxTile:128, Epsilon:0.085
# Episode 493, Score:1080, MaxTile:128, Epsilon:0.084
# Episode 494, Score:1192, MaxTile:128, Epsilon:0.084
# Episode 495, Score:716, MaxTile:64, Epsilon:0.084
# Episode 496, Score:372, MaxTile:32, Epsilon:0.083
# Episode 497, Score:1368, MaxTile:128, Epsilon:0.083
# Episode 498, Score:612, MaxTile:64, Epsilon:0.082
# Episode 499, Score:1364, MaxTile:128, Epsilon:0.082
# Episode 500, Score:388, MaxTile:32, Epsilon:0.082
# Episode 501, Score:1064, MaxTile:128, Epsilon:0.081
# Episode 502, Score:1528, MaxTile:128, Epsilon:0.081
# Episode 503, Score:604, MaxTile:64, Epsilon:0.080
# Episode 504, Score:460, MaxTile:64, Epsilon:0.080
# Episode 505, Score:1852, MaxTile:256, Epsilon:0.080
# Episode 506, Score:592, MaxTile:64, Epsilon:0.079
# Episode 507, Score:1352, MaxTile:128, Epsilon:0.079
# Episode 508, Score:452, MaxTile:32, Epsilon:0.078
# Episode 509, Score:852, MaxTile:64, Epsilon:0.078
# Episode 510, Score:452, MaxTile:32, Epsilon:0.078
# Episode 511, Score:444, MaxTile:32, Epsilon:0.077
# Episode 512, Score:200, MaxTile:16, Epsilon:0.077
# Episode 513, Score:608, MaxTile:64, Epsilon:0.076
# Episode 514, Score:368, MaxTile:32, Epsilon:0.076
# Episode 515, Score:484, MaxTile:32, Epsilon:0.076
# Episode 516, Score:888, MaxTile:128, Epsilon:0.075
# Episode 517, Score:744, MaxTile:64, Epsilon:0.075
# Episode 518, Score:1168, MaxTile:128, Epsilon:0.075
# Episode 519, Score:640, MaxTile:64, Epsilon:0.074
# Episode 520, Score:572, MaxTile:64, Epsilon:0.074
# Episode 521, Score:520, MaxTile:64, Epsilon:0.073
# Episode 522, Score:780, MaxTile:64, Epsilon:0.073
# Episode 523, Score:672, MaxTile:64, Epsilon:0.073
# Episode 524, Score:492, MaxTile:64, Epsilon:0.072
# Episode 525, Score:1116, MaxTile:128, Epsilon:0.072
# Episode 526, Score:632, MaxTile:64, Epsilon:0.072
# Episode 527, Score:848, MaxTile:64, Epsilon:0.071
# Episode 528, Score:416, MaxTile:64, Epsilon:0.071
# Episode 529, Score:1632, MaxTile:128, Epsilon:0.071
# Episode 530, Score:1112, MaxTile:128, Epsilon:0.070
# Episode 531, Score:1224, MaxTile:128, Epsilon:0.070
# Episode 532, Score:244, MaxTile:32, Epsilon:0.069
# Episode 533, Score:560, MaxTile:64, Epsilon:0.069
# Episode 534, Score:784, MaxTile:64, Epsilon:0.069
# Episode 535, Score:652, MaxTile:64, Epsilon:0.068
# Episode 536, Score:1344, MaxTile:128, Epsilon:0.068
# Episode 537, Score:1412, MaxTile:128, Epsilon:0.068
# Episode 538, Score:1160, MaxTile:128, Epsilon:0.067
# Episode 539, Score:708, MaxTile:64, Epsilon:0.067
# Episode 540, Score:2276, MaxTile:128, Epsilon:0.067
# Episode 541, Score:1324, MaxTile:128, Epsilon:0.066
# Episode 542, Score:1772, MaxTile:128, Epsilon:0.066
# Episode 543, Score:1332, MaxTile:128, Epsilon:0.066
# Episode 544, Score:1112, MaxTile:128, Epsilon:0.065
# Episode 545, Score:676, MaxTile:64, Epsilon:0.065
# Episode 546, Score:740, MaxTile:64, Epsilon:0.065
# Episode 547, Score:488, MaxTile:64, Epsilon:0.064
# Episode 548, Score:604, MaxTile:64, Epsilon:0.064
# Episode 549, Score:816, MaxTile:64, Epsilon:0.064
# Episode 550, Score:1216, MaxTile:128, Epsilon:0.063
# Episode 551, Score:1344, MaxTile:128, Epsilon:0.063
# Episode 552, Score:1020, MaxTile:64, Epsilon:0.063
# Episode 553, Score:800, MaxTile:64, Epsilon:0.063
# Episode 554, Score:256, MaxTile:32, Epsilon:0.062
# Episode 555, Score:1720, MaxTile:128, Epsilon:0.062
# Episode 556, Score:1220, MaxTile:128, Epsilon:0.062
# Episode 557, Score:772, MaxTile:64, Epsilon:0.061
# Episode 558, Score:924, MaxTile:64, Epsilon:0.061
# Episode 559, Score:1808, MaxTile:256, Epsilon:0.061
# Episode 560, Score:684, MaxTile:64, Epsilon:0.060
# Episode 561, Score:1460, MaxTile:128, Epsilon:0.060
# Episode 562, Score:512, MaxTile:64, Epsilon:0.060
# Episode 563, Score:1356, MaxTile:128, Epsilon:0.059
# Episode 564, Score:692, MaxTile:64, Epsilon:0.059
# Episode 565, Score:1064, MaxTile:64, Epsilon:0.059
# Episode 566, Score:644, MaxTile:64, Epsilon:0.059
# Episode 567, Score:2136, MaxTile:256, Epsilon:0.058
# Episode 568, Score:656, MaxTile:64, Epsilon:0.058
# Episode 569, Score:1108, MaxTile:128, Epsilon:0.058
# Episode 570, Score:840, MaxTile:64, Epsilon:0.057
# Episode 571, Score:620, MaxTile:64, Epsilon:0.057
# Episode 572, Score:1248, MaxTile:128, Epsilon:0.057
# Episode 573, Score:1452, MaxTile:128, Epsilon:0.057
# Episode 574, Score:344, MaxTile:32, Epsilon:0.056
# Episode 575, Score:700, MaxTile:64, Epsilon:0.056
# Episode 576, Score:1304, MaxTile:128, Epsilon:0.056
# Episode 577, Score:1316, MaxTile:128, Epsilon:0.055
# Episode 578, Score:756, MaxTile:64, Epsilon:0.055
# Episode 579, Score:1072, MaxTile:128, Epsilon:0.055
# Episode 580, Score:624, MaxTile:64, Epsilon:0.055
# Episode 581, Score:728, MaxTile:64, Epsilon:0.054
# Episode 582, Score:1372, MaxTile:128, Epsilon:0.054
# Episode 583, Score:388, MaxTile:32, Epsilon:0.054
# Episode 584, Score:1820, MaxTile:128, Epsilon:0.054
# Episode 585, Score:1644, MaxTile:128, Epsilon:0.053
# Episode 586, Score:2116, MaxTile:256, Epsilon:0.053
# Episode 587, Score:1032, MaxTile:128, Epsilon:0.053
# Episode 588, Score:928, MaxTile:128, Epsilon:0.052
# Episode 589, Score:1736, MaxTile:256, Epsilon:0.052
# Episode 590, Score:1720, MaxTile:128, Epsilon:0.052
# Episode 591, Score:860, MaxTile:64, Epsilon:0.052
# Episode 592, Score:304, MaxTile:32, Epsilon:0.051
# Episode 593, Score:1156, MaxTile:128, Epsilon:0.051
# Episode 594, Score:2132, MaxTile:256, Epsilon:0.051
# Episode 595, Score:1772, MaxTile:128, Epsilon:0.051
# Episode 596, Score:1896, MaxTile:128, Epsilon:0.050
# Episode 597, Score:1340, MaxTile:128, Epsilon:0.050
# Episode 598, Score:1464, MaxTile:128, Epsilon:0.050
# Episode 599, Score:1560, MaxTile:128, Epsilon:0.050
# Episode 600, Score:1280, MaxTile:128, Epsilon:0.050
# Episode 601, Score:1444, MaxTile:128, Epsilon:0.050
# Episode 602, Score:1484, MaxTile:128, Epsilon:0.050
# Episode 603, Score:1340, MaxTile:128, Epsilon:0.050
# Episode 604, Score:408, MaxTile:32, Epsilon:0.050
# Episode 605, Score:368, MaxTile:32, Epsilon:0.050
# Episode 606, Score:1548, MaxTile:128, Epsilon:0.050
# Episode 607, Score:824, MaxTile:64, Epsilon:0.050
# Episode 608, Score:364, MaxTile:32, Epsilon:0.050
# Episode 609, Score:1036, MaxTile:128, Epsilon:0.050
# Episode 610, Score:700, MaxTile:64, Epsilon:0.050
# Episode 611, Score:900, MaxTile:64, Epsilon:0.050
# Episode 612, Score:1632, MaxTile:128, Epsilon:0.050
# Episode 613, Score:892, MaxTile:64, Epsilon:0.050
# Episode 614, Score:1448, MaxTile:128, Epsilon:0.050
# Episode 615, Score:640, MaxTile:64, Epsilon:0.050
# Episode 616, Score:1292, MaxTile:128, Epsilon:0.050
# Episode 617, Score:1568, MaxTile:128, Epsilon:0.050
# Episode 618, Score:968, MaxTile:64, Epsilon:0.050
# Episode 619, Score:816, MaxTile:64, Epsilon:0.050
# Episode 620, Score:1456, MaxTile:128, Epsilon:0.050
# Episode 621, Score:520, MaxTile:64, Epsilon:0.050
# Episode 622, Score:1164, MaxTile:128, Epsilon:0.050
# Episode 623, Score:1248, MaxTile:128, Epsilon:0.050
# Episode 624, Score:1472, MaxTile:128, Epsilon:0.050
# Episode 625, Score:2116, MaxTile:256, Epsilon:0.050
# Episode 626, Score:1324, MaxTile:128, Epsilon:0.050
# Episode 627, Score:1820, MaxTile:256, Epsilon:0.050
# Episode 628, Score:1900, MaxTile:128, Epsilon:0.050
# Episode 629, Score:1256, MaxTile:128, Epsilon:0.050
# Episode 630, Score:656, MaxTile:64, Epsilon:0.050
# Episode 631, Score:692, MaxTile:64, Epsilon:0.050
# Episode 632, Score:1260, MaxTile:128, Epsilon:0.050
# Episode 633, Score:1304, MaxTile:128, Epsilon:0.050
# Episode 634, Score:1436, MaxTile:128, Epsilon:0.050
# Episode 635, Score:1532, MaxTile:128, Epsilon:0.050
# Episode 636, Score:884, MaxTile:128, Epsilon:0.050
# Episode 637, Score:1412, MaxTile:128, Epsilon:0.050
# Episode 638, Score:1068, MaxTile:128, Epsilon:0.050
# Episode 639, Score:684, MaxTile:64, Epsilon:0.050
# Episode 640, Score:1752, MaxTile:128, Epsilon:0.050
# Episode 641, Score:1300, MaxTile:128, Epsilon:0.050
# Episode 642, Score:1776, MaxTile:256, Epsilon:0.050
# Episode 643, Score:756, MaxTile:64, Epsilon:0.050
# Episode 644, Score:500, MaxTile:32, Epsilon:0.050
# Episode 645, Score:1244, MaxTile:128, Epsilon:0.050
# Episode 646, Score:1840, MaxTile:256, Epsilon:0.050
# Episode 647, Score:1660, MaxTile:128, Epsilon:0.050
# Episode 648, Score:380, MaxTile:32, Epsilon:0.050
# Episode 649, Score:812, MaxTile:64, Epsilon:0.050
# Episode 650, Score:1072, MaxTile:128, Epsilon:0.050
# Episode 651, Score:1296, MaxTile:128, Epsilon:0.050
# Episode 652, Score:868, MaxTile:64, Epsilon:0.050
# Episode 653, Score:320, MaxTile:32, Epsilon:0.050
# Episode 654, Score:1748, MaxTile:128, Epsilon:0.050
# Episode 655, Score:1356, MaxTile:128, Epsilon:0.050
# Episode 656, Score:1540, MaxTile:128, Epsilon:0.050
# Episode 657, Score:764, MaxTile:64, Epsilon:0.050
# Episode 658, Score:1076, MaxTile:128, Epsilon:0.050
# Episode 659, Score:476, MaxTile:32, Epsilon:0.050
# Episode 660, Score:1344, MaxTile:128, Epsilon:0.050
# Episode 661, Score:632, MaxTile:64, Epsilon:0.050
# Episode 662, Score:1280, MaxTile:128, Epsilon:0.050
# Episode 663, Score:440, MaxTile:32, Epsilon:0.050
# Episode 664, Score:1632, MaxTile:128, Epsilon:0.050
# Episode 665, Score:1852, MaxTile:256, Epsilon:0.050
# Episode 666, Score:1216, MaxTile:128, Epsilon:0.050
# Episode 667, Score:508, MaxTile:32, Epsilon:0.050
# Episode 668, Score:1300, MaxTile:128, Epsilon:0.050
# Episode 669, Score:976, MaxTile:64, Epsilon:0.050
# Episode 670, Score:580, MaxTile:64, Epsilon:0.050
# Episode 671, Score:904, MaxTile:64, Epsilon:0.050
# Episode 672, Score:1180, MaxTile:64, Epsilon:0.050
# Episode 673, Score:1284, MaxTile:128, Epsilon:0.050
# Episode 674, Score:1420, MaxTile:128, Epsilon:0.050
# Episode 675, Score:824, MaxTile:64, Epsilon:0.050
# Episode 676, Score:672, MaxTile:64, Epsilon:0.050
# Episode 677, Score:920, MaxTile:64, Epsilon:0.050
# Episode 678, Score:1156, MaxTile:128, Epsilon:0.050
# Episode 679, Score:2108, MaxTile:256, Epsilon:0.050
# Episode 680, Score:1664, MaxTile:128, Epsilon:0.050
# Episode 681, Score:580, MaxTile:64, Epsilon:0.050
# Episode 682, Score:1444, MaxTile:128, Epsilon:0.050
# Episode 683, Score:992, MaxTile:128, Epsilon:0.050
# Episode 684, Score:2240, MaxTile:256, Epsilon:0.050
# Episode 685, Score:1360, MaxTile:128, Epsilon:0.050
# Episode 686, Score:640, MaxTile:64, Epsilon:0.050
# Episode 687, Score:700, MaxTile:64, Epsilon:0.050
# Episode 688, Score:532, MaxTile:64, Epsilon:0.050
# Episode 689, Score:1260, MaxTile:128, Epsilon:0.050
# Episode 690, Score:1108, MaxTile:64, Epsilon:0.050
# Episode 691, Score:804, MaxTile:64, Epsilon:0.050
# Episode 692, Score:1568, MaxTile:128, Epsilon:0.050
# Episode 693, Score:636, MaxTile:64, Epsilon:0.050
# Episode 694, Score:1060, MaxTile:128, Epsilon:0.050
# Episode 695, Score:1460, MaxTile:128, Epsilon:0.050
# Episode 696, Score:1844, MaxTile:128, Epsilon:0.050
# Episode 697, Score:2048, MaxTile:256, Epsilon:0.050
# Episode 698, Score:2132, MaxTile:256, Epsilon:0.050
# Episode 699, Score:628, MaxTile:64, Epsilon:0.050
# Episode 700, Score:812, MaxTile:64, Epsilon:0.050
# Episode 701, Score:608, MaxTile:64, Epsilon:0.050
# Episode 702, Score:2100, MaxTile:256, Epsilon:0.050
# Episode 703, Score:1812, MaxTile:256, Epsilon:0.050
# Episode 704, Score:280, MaxTile:32, Epsilon:0.050
# Episode 705, Score:1252, MaxTile:128, Epsilon:0.050
# Episode 706, Score:1116, MaxTile:128, Epsilon:0.050
# Episode 707, Score:2300, MaxTile:256, Epsilon:0.050
# Episode 708, Score:564, MaxTile:64, Epsilon:0.050
# Episode 709, Score:1620, MaxTile:128, Epsilon:0.050
# Episode 710, Score:1288, MaxTile:128, Epsilon:0.050
# Episode 711, Score:1848, MaxTile:128, Epsilon:0.050
# Episode 712, Score:2012, MaxTile:256, Epsilon:0.050
# Episode 713, Score:1436, MaxTile:128, Epsilon:0.050
# Episode 714, Score:1424, MaxTile:128, Epsilon:0.050
# Episode 715, Score:740, MaxTile:64, Epsilon:0.050
# Episode 716, Score:304, MaxTile:32, Epsilon:0.050
# Episode 717, Score:784, MaxTile:64, Epsilon:0.050
# Episode 718, Score:1732, MaxTile:256, Epsilon:0.050
# Episode 719, Score:1012, MaxTile:64, Epsilon:0.050
# Episode 720, Score:1124, MaxTile:64, Epsilon:0.050
# Episode 721, Score:668, MaxTile:64, Epsilon:0.050
# Episode 722, Score:760, MaxTile:64, Epsilon:0.050
# Episode 723, Score:1752, MaxTile:128, Epsilon:0.050
# Episode 724, Score:1296, MaxTile:128, Epsilon:0.050
# Episode 725, Score:372, MaxTile:32, Epsilon:0.050
# Episode 726, Score:1096, MaxTile:128, Epsilon:0.050
# Episode 727, Score:612, MaxTile:64, Epsilon:0.050
# Episode 728, Score:1796, MaxTile:128, Epsilon:0.050
# Episode 729, Score:1188, MaxTile:128, Epsilon:0.050
# Episode 730, Score:1828, MaxTile:128, Epsilon:0.050
# Episode 731, Score:700, MaxTile:64, Epsilon:0.050
# Episode 732, Score:1168, MaxTile:128, Epsilon:0.050
# Episode 733, Score:636, MaxTile:64, Epsilon:0.050
# Episode 734, Score:1040, MaxTile:128, Epsilon:0.050
# Episode 735, Score:1416, MaxTile:128, Epsilon:0.050
# Episode 736, Score:2132, MaxTile:128, Epsilon:0.050
# Episode 737, Score:1424, MaxTile:128, Epsilon:0.050
# Episode 738, Score:716, MaxTile:64, Epsilon:0.050
# Episode 739, Score:2040, MaxTile:256, Epsilon:0.050
# Episode 740, Score:692, MaxTile:64, Epsilon:0.050
# Episode 741, Score:1424, MaxTile:128, Epsilon:0.050
# Episode 742, Score:1008, MaxTile:128, Epsilon:0.050
# Episode 743, Score:952, MaxTile:64, Epsilon:0.050
# Episode 744, Score:1584, MaxTile:128, Epsilon:0.050
# Episode 745, Score:548, MaxTile:64, Epsilon:0.050
# Episode 746, Score:1672, MaxTile:128, Epsilon:0.050
# Episode 747, Score:1384, MaxTile:128, Epsilon:0.050
# Episode 748, Score:720, MaxTile:64, Epsilon:0.050
# Episode 749, Score:1548, MaxTile:128, Epsilon:0.050
# Episode 750, Score:928, MaxTile:64, Epsilon:0.050
# Episode 751, Score:1628, MaxTile:128, Epsilon:0.050
# Episode 752, Score:1028, MaxTile:128, Epsilon:0.050
# Episode 753, Score:1516, MaxTile:128, Epsilon:0.050
# Episode 754, Score:1396, MaxTile:128, Epsilon:0.050
# Episode 755, Score:1028, MaxTile:128, Epsilon:0.050
# Episode 756, Score:1220, MaxTile:128, Epsilon:0.050
# Episode 757, Score:1488, MaxTile:128, Epsilon:0.050
# Episode 758, Score:632, MaxTile:64, Epsilon:0.050
# Episode 759, Score:476, MaxTile:64, Epsilon:0.050
# Episode 760, Score:660, MaxTile:64, Epsilon:0.050
# Episode 761, Score:1532, MaxTile:128, Epsilon:0.050
# Episode 762, Score:596, MaxTile:64, Epsilon:0.050
# Episode 763, Score:532, MaxTile:64, Epsilon:0.050
# Episode 764, Score:376, MaxTile:32, Epsilon:0.050
# Episode 765, Score:260, MaxTile:32, Epsilon:0.050
# Episode 766, Score:1428, MaxTile:128, Epsilon:0.050
# Episode 767, Score:852, MaxTile:64, Epsilon:0.050
# Episode 768, Score:1076, MaxTile:64, Epsilon:0.050
# Episode 769, Score:1008, MaxTile:64, Epsilon:0.050
# Episode 770, Score:800, MaxTile:64, Epsilon:0.050
# Episode 771, Score:1292, MaxTile:128, Epsilon:0.050
# Episode 772, Score:1520, MaxTile:128, Epsilon:0.050
# Episode 773, Score:1336, MaxTile:128, Epsilon:0.050
# Episode 774, Score:1088, MaxTile:128, Epsilon:0.050
# Episode 775, Score:2576, MaxTile:256, Epsilon:0.050
# Episode 776, Score:804, MaxTile:64, Epsilon:0.050
# Episode 777, Score:2952, MaxTile:256, Epsilon:0.050
# Episode 778, Score:652, MaxTile:64, Epsilon:0.050
# Episode 779, Score:1140, MaxTile:128, Epsilon:0.050
# Episode 780, Score:2260, MaxTile:256, Epsilon:0.050
# Episode 781, Score:988, MaxTile:128, Epsilon:0.050
# Episode 782, Score:1888, MaxTile:128, Epsilon:0.050
# Episode 783, Score:1384, MaxTile:128, Epsilon:0.050
# Episode 784, Score:2776, MaxTile:256, Epsilon:0.050
# Episode 785, Score:708, MaxTile:64, Epsilon:0.050
# Episode 786, Score:972, MaxTile:128, Epsilon:0.050
# Episode 787, Score:780, MaxTile:64, Epsilon:0.050
# Episode 788, Score:1256, MaxTile:128, Epsilon:0.050
# Episode 789, Score:1716, MaxTile:128, Epsilon:0.050
# Episode 790, Score:2448, MaxTile:256, Epsilon:0.050
# Episode 791, Score:1764, MaxTile:128, Epsilon:0.050
# Episode 792, Score:748, MaxTile:64, Epsilon:0.050
# Episode 793, Score:1396, MaxTile:128, Epsilon:0.050
# Episode 794, Score:1408, MaxTile:128, Epsilon:0.050
# Episode 795, Score:836, MaxTile:64, Epsilon:0.050
# Episode 796, Score:700, MaxTile:64, Epsilon:0.050
# Episode 797, Score:1408, MaxTile:128, Epsilon:0.050
# Episode 798, Score:2948, MaxTile:256, Epsilon:0.050
# Episode 799, Score:2420, MaxTile:256, Epsilon:0.050
# Episode 800, Score:800, MaxTile:64, Epsilon:0.050
# Episode 801, Score:1936, MaxTile:256, Epsilon:0.050
# Episode 802, Score:1444, MaxTile:128, Epsilon:0.050
# Episode 803, Score:936, MaxTile:128, Epsilon:0.050
# Episode 804, Score:1368, MaxTile:128, Epsilon:0.050
# Episode 805, Score:1396, MaxTile:128, Epsilon:0.050
# Episode 806, Score:576, MaxTile:64, Epsilon:0.050
# Episode 807, Score:908, MaxTile:64, Epsilon:0.050
# Episode 808, Score:1016, MaxTile:128, Epsilon:0.050
# Episode 809, Score:1088, MaxTile:128, Epsilon:0.050
# Episode 810, Score:608, MaxTile:64, Epsilon:0.050
# Episode 811, Score:1468, MaxTile:128, Epsilon:0.050
# Episode 812, Score:532, MaxTile:32, Epsilon:0.050
# Episode 813, Score:1220, MaxTile:128, Epsilon:0.050
# Episode 814, Score:1508, MaxTile:128, Epsilon:0.050
# Episode 815, Score:352, MaxTile:32, Epsilon:0.050
# Episode 816, Score:516, MaxTile:32, Epsilon:0.050
# Episode 817, Score:2120, MaxTile:256, Epsilon:0.050
# Episode 818, Score:1284, MaxTile:128, Epsilon:0.050
# Episode 819, Score:868, MaxTile:64, Epsilon:0.050
# Episode 820, Score:1432, MaxTile:128, Epsilon:0.050
# Episode 821, Score:1516, MaxTile:128, Epsilon:0.050
# Episode 822, Score:820, MaxTile:64, Epsilon:0.050
# Episode 823, Score:520, MaxTile:32, Epsilon:0.050
# Episode 824, Score:712, MaxTile:64, Epsilon:0.050
# Episode 825, Score:1324, MaxTile:128, Epsilon:0.050
# Episode 826, Score:1372, MaxTile:128, Epsilon:0.050
# Episode 827, Score:1480, MaxTile:128, Epsilon:0.050
# Episode 828, Score:1360, MaxTile:128, Epsilon:0.050
# Episode 829, Score:880, MaxTile:64, Epsilon:0.050
# Episode 830, Score:1428, MaxTile:128, Epsilon:0.050
# Episode 831, Score:1308, MaxTile:128, Epsilon:0.050
# Episode 832, Score:1168, MaxTile:128, Epsilon:0.050
# Episode 833, Score:512, MaxTile:64, Epsilon:0.050
# Episode 834, Score:1264, MaxTile:128, Epsilon:0.050
# Episode 835, Score:1916, MaxTile:256, Epsilon:0.050
# Episode 836, Score:1468, MaxTile:128, Epsilon:0.050
# Episode 837, Score:592, MaxTile:64, Epsilon:0.050
# Episode 838, Score:600, MaxTile:64, Epsilon:0.050
# Episode 839, Score:964, MaxTile:64, Epsilon:0.050
# Episode 840, Score:864, MaxTile:64, Epsilon:0.050
# Episode 841, Score:1296, MaxTile:128, Epsilon:0.050
# Episode 842, Score:1780, MaxTile:128, Epsilon:0.050
# Episode 843, Score:1536, MaxTile:128, Epsilon:0.050
# Episode 844, Score:660, MaxTile:64, Epsilon:0.050
# Episode 845, Score:880, MaxTile:64, Epsilon:0.050
# Episode 846, Score:1084, MaxTile:128, Epsilon:0.050
# Episode 847, Score:1572, MaxTile:128, Epsilon:0.050
# Episode 848, Score:1148, MaxTile:64, Epsilon:0.050
# Episode 849, Score:736, MaxTile:64, Epsilon:0.050
# Episode 850, Score:684, MaxTile:64, Epsilon:0.050
# Episode 851, Score:1048, MaxTile:128, Epsilon:0.050
# Episode 852, Score:1444, MaxTile:128, Epsilon:0.050
# Episode 853, Score:1028, MaxTile:64, Epsilon:0.050
# Episode 854, Score:1544, MaxTile:128, Epsilon:0.050
# Episode 855, Score:1512, MaxTile:128, Epsilon:0.050
# Episode 856, Score:196, MaxTile:16, Epsilon:0.050
# Episode 857, Score:1004, MaxTile:128, Epsilon:0.050
# Episode 858, Score:612, MaxTile:64, Epsilon:0.050
# Episode 859, Score:844, MaxTile:128, Epsilon:0.050
# Episode 860, Score:744, MaxTile:64, Epsilon:0.050
# Episode 861, Score:2036, MaxTile:128, Epsilon:0.050
# Episode 862, Score:1864, MaxTile:256, Epsilon:0.050
# Episode 863, Score:580, MaxTile:64, Epsilon:0.050
# Episode 864, Score:824, MaxTile:128, Epsilon:0.050
# Episode 865, Score:1320, MaxTile:128, Epsilon:0.050
# Episode 866, Score:624, MaxTile:64, Epsilon:0.050
# Episode 867, Score:1916, MaxTile:256, Epsilon:0.050
# Episode 868, Score:468, MaxTile:32, Epsilon:0.050
# Episode 869, Score:1036, MaxTile:64, Epsilon:0.050
# Episode 870, Score:308, MaxTile:32, Epsilon:0.050
# Episode 871, Score:1140, MaxTile:128, Epsilon:0.050
# Episode 872, Score:516, MaxTile:64, Epsilon:0.050
# Episode 873, Score:1924, MaxTile:256, Epsilon:0.050
# Episode 874, Score:416, MaxTile:32, Epsilon:0.050
# Episode 875, Score:1380, MaxTile:128, Epsilon:0.050
# Episode 876, Score:608, MaxTile:64, Epsilon:0.050
# Episode 877, Score:1212, MaxTile:128, Epsilon:0.050
# Episode 878, Score:1144, MaxTile:128, Epsilon:0.050
# Episode 879, Score:976, MaxTile:128, Epsilon:0.050
# Episode 880, Score:276, MaxTile:32, Epsilon:0.050
# Episode 881, Score:1392, MaxTile:128, Epsilon:0.050
# Episode 882, Score:684, MaxTile:64, Epsilon:0.050
# Episode 883, Score:1280, MaxTile:128, Epsilon:0.050
# Episode 884, Score:1240, MaxTile:128, Epsilon:0.050
# Episode 885, Score:704, MaxTile:64, Epsilon:0.050
# Episode 886, Score:960, MaxTile:64, Epsilon:0.050
# Episode 887, Score:716, MaxTile:64, Epsilon:0.050
# Episode 888, Score:1140, MaxTile:128, Epsilon:0.050
# Episode 889, Score:1424, MaxTile:128, Epsilon:0.050
# Episode 890, Score:2024, MaxTile:128, Epsilon:0.050
# Episode 891, Score:1104, MaxTile:64, Epsilon:0.050
# Episode 892, Score:1460, MaxTile:128, Epsilon:0.050
# Episode 893, Score:900, MaxTile:64, Epsilon:0.050
# Episode 894, Score:640, MaxTile:64, Epsilon:0.050
# Episode 895, Score:1800, MaxTile:256, Epsilon:0.050
# Episode 896, Score:1268, MaxTile:128, Epsilon:0.050
# Episode 897, Score:640, MaxTile:64, Epsilon:0.050
# Episode 898, Score:424, MaxTile:32, Epsilon:0.050
# Episode 899, Score:1404, MaxTile:128, Epsilon:0.050
# Episode 900, Score:1152, MaxTile:128, Epsilon:0.050
# Episode 901, Score:584, MaxTile:64, Epsilon:0.050
# Episode 902, Score:916, MaxTile:64, Epsilon:0.050
# Episode 903, Score:1000, MaxTile:128, Epsilon:0.050
# Episode 904, Score:1528, MaxTile:128, Epsilon:0.050
# Episode 905, Score:976, MaxTile:128, Epsilon:0.050
# Episode 906, Score:704, MaxTile:64, Epsilon:0.050
# Episode 907, Score:624, MaxTile:64, Epsilon:0.050
# Episode 908, Score:864, MaxTile:64, Epsilon:0.050
# Episode 909, Score:1076, MaxTile:128, Epsilon:0.050
# Episode 910, Score:824, MaxTile:64, Epsilon:0.050
# Episode 911, Score:644, MaxTile:64, Epsilon:0.050
# Episode 912, Score:1000, MaxTile:128, Epsilon:0.050
# Episode 913, Score:660, MaxTile:64, Epsilon:0.050
# Episode 914, Score:716, MaxTile:64, Epsilon:0.050
# Episode 915, Score:1344, MaxTile:128, Epsilon:0.050
# Episode 916, Score:1364, MaxTile:128, Epsilon:0.050
# Episode 917, Score:1396, MaxTile:128, Epsilon:0.050
# Episode 918, Score:620, MaxTile:64, Epsilon:0.050
# Episode 919, Score:736, MaxTile:64, Epsilon:0.050
# Episode 920, Score:1520, MaxTile:128, Epsilon:0.050
# Episode 921, Score:1112, MaxTile:128, Epsilon:0.050
# Episode 922, Score:600, MaxTile:64, Epsilon:0.050
# Episode 923, Score:480, MaxTile:32, Epsilon:0.050
# Episode 924, Score:520, MaxTile:64, Epsilon:0.050
# Episode 925, Score:896, MaxTile:128, Epsilon:0.050
# Episode 926, Score:756, MaxTile:64, Epsilon:0.050
# Episode 927, Score:1220, MaxTile:128, Epsilon:0.050
# Episode 928, Score:1340, MaxTile:128, Epsilon:0.050
# Episode 929, Score:668, MaxTile:64, Epsilon:0.050
# Episode 930, Score:604, MaxTile:64, Epsilon:0.050
# Episode 931, Score:1068, MaxTile:128, Epsilon:0.050
# Episode 932, Score:1504, MaxTile:128, Epsilon:0.050
# Episode 933, Score:1484, MaxTile:128, Epsilon:0.050
# Episode 934, Score:184, MaxTile:16, Epsilon:0.050
# Episode 935, Score:1700, MaxTile:128, Epsilon:0.050
# Episode 936, Score:764, MaxTile:64, Epsilon:0.050
# ...
# Episode 9695, Score:2228, MaxTile:128, Epsilon:0.050
# Episode 9696, Score:2132, MaxTile:256, Epsilon:0.050
# Episode 9697, Score:456, MaxTile:64, Epsilon:0.050
# Episode 9698, Score:1636, MaxTile:128, Epsilon:0.050
# Episode 9699, Score:1220, MaxTile:128, Epsilon:0.050
# Episode 9700, Score:1264, MaxTile:128, Epsilon:0.050
# Episode 9701, Score:1224, MaxTile:128, Epsilon:0.050
# Episode 9702, Score:848, MaxTile:64, Epsilon:0.050
# Episode 9703, Score:1328, MaxTile:128, Epsilon:0.050
# Episode 9704, Score:2688, MaxTile:256, Epsilon:0.050
# Episode 9705, Score:1692, MaxTile:128, Epsilon:0.050
# Episode 9706, Score:1904, MaxTile:128, Epsilon:0.050
# Episode 9707, Score:780, MaxTile:64, Epsilon:0.050
# Episode 9708, Score:1076, MaxTile:128, Epsilon:0.050
# Episode 9709, Score:700, MaxTile:64, Epsilon:0.050
# Episode 9710, Score:716, MaxTile:64, Epsilon:0.050
# Episode 9711, Score:636, MaxTile:64, Epsilon:0.050
# Episode 9712, Score:1140, MaxTile:128, Epsilon:0.050
# Episode 9713, Score:1332, MaxTile:128, Epsilon:0.050
# Episode 9714, Score:1472, MaxTile:128, Epsilon:0.050
# Episode 9715, Score:1240, MaxTile:128, Epsilon:0.050
# Episode 9716, Score:1240, MaxTile:128, Epsilon:0.050
# Episode 9717, Score:1104, MaxTile:64, Epsilon:0.050
# Episode 9718, Score:1596, MaxTile:128, Epsilon:0.050
# Episode 9719, Score:972, MaxTile:64, Epsilon:0.050
# Episode 9720, Score:864, MaxTile:64, Epsilon:0.050
# Episode 9721, Score:2176, MaxTile:256, Epsilon:0.050
# Episode 9722, Score:1820, MaxTile:128, Epsilon:0.050
# Episode 9723, Score:1344, MaxTile:128, Epsilon:0.050
# Episode 9724, Score:988, MaxTile:128, Epsilon:0.050
# Episode 9725, Score:1584, MaxTile:128, Epsilon:0.050
# Episode 9726, Score:708, MaxTile:64, Epsilon:0.050
# Episode 9727, Score:2496, MaxTile:128, Epsilon:0.050
# Episode 9728, Score:1608, MaxTile:128, Epsilon:0.050
# Episode 9729, Score:2604, MaxTile:256, Epsilon:0.050
# Episode 9730, Score:1776, MaxTile:128, Epsilon:0.050
# Episode 9731, Score:2764, MaxTile:256, Epsilon:0.050
# Episode 9732, Score:2084, MaxTile:256, Epsilon:0.050
# Episode 9733, Score:928, MaxTile:64, Epsilon:0.050
# Episode 9734, Score:1176, MaxTile:128, Epsilon:0.050
# Episode 9735, Score:952, MaxTile:64, Epsilon:0.050
# Episode 9736, Score:628, MaxTile:64, Epsilon:0.050
# Episode 9737, Score:1328, MaxTile:128, Epsilon:0.050
# Episode 9738, Score:716, MaxTile:64, Epsilon:0.050
# Episode 9739, Score:284, MaxTile:32, Epsilon:0.050
# Episode 9740, Score:488, MaxTile:64, Epsilon:0.050
# Episode 9741, Score:1344, MaxTile:128, Epsilon:0.050
# Episode 9742, Score:1380, MaxTile:128, Epsilon:0.050
# Episode 9743, Score:1396, MaxTile:128, Epsilon:0.050
# Episode 9744, Score:248, MaxTile:16, Epsilon:0.050
# Episode 9745, Score:1896, MaxTile:128, Epsilon:0.050
# Episode 9746, Score:2540, MaxTile:256, Epsilon:0.050
# Episode 9747, Score:448, MaxTile:32, Epsilon:0.050
# Episode 9748, Score:1472, MaxTile:128, Epsilon:0.050
# Episode 9749, Score:2988, MaxTile:256, Epsilon:0.050
# Episode 9750, Score:1176, MaxTile:128, Epsilon:0.050
# Episode 9751, Score:1664, MaxTile:128, Epsilon:0.050
# Episode 9752, Score:644, MaxTile:64, Epsilon:0.050
# Episode 9753, Score:800, MaxTile:64, Epsilon:0.050
# Episode 9754, Score:772, MaxTile:64, Epsilon:0.050
# Episode 9755, Score:772, MaxTile:64, Epsilon:0.050
# Episode 9756, Score:892, MaxTile:64, Epsilon:0.050
# Episode 9757, Score:368, MaxTile:32, Epsilon:0.050
# Episode 9758, Score:1396, MaxTile:128, Epsilon:0.050
# Episode 9759, Score:680, MaxTile:64, Epsilon:0.050
# Episode 9760, Score:420, MaxTile:32, Epsilon:0.050
# Episode 9761, Score:600, MaxTile:64, Epsilon:0.050
# Episode 9762, Score:560, MaxTile:64, Epsilon:0.050
# Episode 9763, Score:2836, MaxTile:256, Epsilon:0.050
# Episode 9764, Score:1004, MaxTile:64, Epsilon:0.050
# Episode 9765, Score:1356, MaxTile:128, Epsilon:0.050
# Episode 9766, Score:1584, MaxTile:128, Epsilon:0.050
# Episode 9767, Score:1480, MaxTile:128, Epsilon:0.050
# Episode 9768, Score:1024, MaxTile:64, Epsilon:0.050
# Episode 9769, Score:392, MaxTile:32, Epsilon:0.050
# Episode 9770, Score:500, MaxTile:64, Epsilon:0.050
# Episode 9771, Score:644, MaxTile:64, Epsilon:0.050
# Episode 9772, Score:1300, MaxTile:128, Epsilon:0.050
# Episode 9773, Score:1040, MaxTile:128, Epsilon:0.050
# Episode 9774, Score:464, MaxTile:32, Epsilon:0.050
# Episode 9775, Score:2384, MaxTile:256, Epsilon:0.050
# Episode 9776, Score:1344, MaxTile:128, Epsilon:0.050
# Episode 9777, Score:1044, MaxTile:128, Epsilon:0.050
# Episode 9778, Score:696, MaxTile:64, Epsilon:0.050
# Episode 9779, Score:1512, MaxTile:128, Epsilon:0.050
# Episode 9780, Score:260, MaxTile:32, Epsilon:0.050
# Episode 9781, Score:768, MaxTile:64, Epsilon:0.050
# Episode 9782, Score:444, MaxTile:32, Epsilon:0.050
# Episode 9783, Score:1360, MaxTile:128, Epsilon:0.050
# Episode 9784, Score:700, MaxTile:64, Epsilon:0.050
# Episode 9785, Score:1680, MaxTile:128, Epsilon:0.050
# Episode 9786, Score:836, MaxTile:64, Epsilon:0.050
# Episode 9787, Score:1352, MaxTile:128, Epsilon:0.050
# Episode 9788, Score:2248, MaxTile:128, Epsilon:0.050
# Episode 9789, Score:1540, MaxTile:128, Epsilon:0.050
# Episode 9790, Score:1564, MaxTile:128, Epsilon:0.050
# Episode 9791, Score:2012, MaxTile:128, Epsilon:0.050
# Episode 9792, Score:1272, MaxTile:128, Epsilon:0.050
# Episode 9793, Score:880, MaxTile:64, Epsilon:0.050
# Episode 9794, Score:236, MaxTile:16, Epsilon:0.050
# Episode 9795, Score:492, MaxTile:64, Epsilon:0.050
# Episode 9796, Score:624, MaxTile:64, Epsilon:0.050
# Episode 9797, Score:1660, MaxTile:128, Epsilon:0.050
# Episode 9798, Score:444, MaxTile:64, Epsilon:0.050
# Episode 9799, Score:656, MaxTile:64, Epsilon:0.050
# Episode 9800, Score:868, MaxTile:64, Epsilon:0.050
# Episode 9801, Score:1040, MaxTile:128, Epsilon:0.050
# Episode 9802, Score:904, MaxTile:64, Epsilon:0.050
# Episode 9803, Score:1912, MaxTile:128, Epsilon:0.050
# Episode 9804, Score:1560, MaxTile:128, Epsilon:0.050
# Episode 9805, Score:628, MaxTile:64, Epsilon:0.050
# Episode 9806, Score:1140, MaxTile:128, Epsilon:0.050
# Episode 9807, Score:1152, MaxTile:128, Epsilon:0.050
# Episode 9808, Score:760, MaxTile:64, Epsilon:0.050
# Episode 9809, Score:2028, MaxTile:128, Epsilon:0.050
# Episode 9810, Score:1460, MaxTile:128, Epsilon:0.050
# Episode 9811, Score:2628, MaxTile:256, Epsilon:0.050
# Episode 9812, Score:1676, MaxTile:128, Epsilon:0.050
# Episode 9813, Score:656, MaxTile:64, Epsilon:0.050
# Episode 9814, Score:1416, MaxTile:128, Epsilon:0.050
# Episode 9815, Score:1440, MaxTile:128, Epsilon:0.050
# Episode 9816, Score:1548, MaxTile:128, Epsilon:0.050
# Episode 9817, Score:1584, MaxTile:128, Epsilon:0.050
# Episode 9818, Score:624, MaxTile:64, Epsilon:0.050
# Episode 9819, Score:1200, MaxTile:64, Epsilon:0.050
# Episode 9820, Score:1456, MaxTile:128, Epsilon:0.050
# Episode 9821, Score:1620, MaxTile:128, Epsilon:0.050
# Episode 9822, Score:992, MaxTile:128, Epsilon:0.050
# Episode 9823, Score:1784, MaxTile:128, Epsilon:0.050
# Episode 9824, Score:2220, MaxTile:256, Epsilon:0.050
# Episode 9825, Score:1788, MaxTile:128, Epsilon:0.050
# Episode 9826, Score:1564, MaxTile:128, Epsilon:0.050
# Episode 9827, Score:780, MaxTile:64, Epsilon:0.050
# Episode 9828, Score:1032, MaxTile:64, Epsilon:0.050
# Episode 9829, Score:1596, MaxTile:128, Epsilon:0.050
# Episode 9830, Score:1876, MaxTile:256, Epsilon:0.050
# Episode 9831, Score:804, MaxTile:64, Epsilon:0.050
# Episode 9832, Score:680, MaxTile:64, Epsilon:0.050
# Episode 9833, Score:364, MaxTile:32, Epsilon:0.050
# Episode 9834, Score:700, MaxTile:64, Epsilon:0.050
# Episode 9835, Score:1044, MaxTile:128, Epsilon:0.050
# Episode 9836, Score:1168, MaxTile:128, Epsilon:0.050
# Episode 9837, Score:1388, MaxTile:128, Epsilon:0.050
# Episode 9838, Score:1000, MaxTile:64, Epsilon:0.050
# Episode 9839, Score:576, MaxTile:64, Epsilon:0.050
# Episode 9840, Score:1036, MaxTile:128, Epsilon:0.050
# Episode 9841, Score:424, MaxTile:32, Epsilon:0.050
# Episode 9842, Score:652, MaxTile:64, Epsilon:0.050
# Episode 9843, Score:1444, MaxTile:128, Epsilon:0.050
# Episode 9844, Score:732, MaxTile:64, Epsilon:0.050
# Episode 9845, Score:2248, MaxTile:256, Epsilon:0.050
# Episode 9846, Score:1488, MaxTile:128, Epsilon:0.050
# Episode 9847, Score:2160, MaxTile:256, Epsilon:0.050
# Episode 9848, Score:1384, MaxTile:128, Epsilon:0.050
# Episode 9849, Score:556, MaxTile:64, Epsilon:0.050
# Episode 9850, Score:876, MaxTile:64, Epsilon:0.050
# Episode 9851, Score:1392, MaxTile:128, Epsilon:0.050
# Episode 9852, Score:1636, MaxTile:256, Epsilon:0.050
# Episode 9853, Score:960, MaxTile:64, Epsilon:0.050
# Episode 9854, Score:876, MaxTile:64, Epsilon:0.050
# Episode 9855, Score:920, MaxTile:64, Epsilon:0.050
# Episode 9856, Score:1544, MaxTile:128, Epsilon:0.050
# Episode 9857, Score:1472, MaxTile:128, Epsilon:0.050
# Episode 9858, Score:908, MaxTile:64, Epsilon:0.050
# Episode 9859, Score:1092, MaxTile:128, Epsilon:0.050
# Episode 9860, Score:1388, MaxTile:128, Epsilon:0.050
# Episode 9861, Score:656, MaxTile:64, Epsilon:0.050
# Episode 9862, Score:2436, MaxTile:256, Epsilon:0.050
# Episode 9863, Score:672, MaxTile:64, Epsilon:0.050
# Episode 9864, Score:1484, MaxTile:128, Epsilon:0.050
# Episode 9865, Score:1116, MaxTile:128, Epsilon:0.050
# Episode 9866, Score:1636, MaxTile:128, Epsilon:0.050
# Episode 9867, Score:720, MaxTile:64, Epsilon:0.050
# Episode 9868, Score:1628, MaxTile:128, Epsilon:0.050
# Episode 9869, Score:1260, MaxTile:128, Epsilon:0.050
# Episode 9870, Score:376, MaxTile:32, Epsilon:0.050
# Episode 9871, Score:1220, MaxTile:128, Epsilon:0.050
# Episode 9872, Score:1184, MaxTile:128, Epsilon:0.050
# Episode 9873, Score:724, MaxTile:64, Epsilon:0.050
# Episode 9874, Score:1432, MaxTile:128, Epsilon:0.050
# Episode 9875, Score:1840, MaxTile:128, Epsilon:0.050
# Episode 9876, Score:1992, MaxTile:128, Epsilon:0.050
# Episode 9877, Score:1508, MaxTile:128, Epsilon:0.050
# Episode 9878, Score:1276, MaxTile:128, Epsilon:0.050
# Episode 9879, Score:920, MaxTile:64, Epsilon:0.050
# Episode 9880, Score:452, MaxTile:32, Epsilon:0.050
# Episode 9881, Score:528, MaxTile:32, Epsilon:0.050
# Episode 9882, Score:1080, MaxTile:64, Epsilon:0.050
# Episode 9883, Score:408, MaxTile:32, Epsilon:0.050
# Episode 9884, Score:604, MaxTile:64, Epsilon:0.050
# Episode 9885, Score:1752, MaxTile:128, Epsilon:0.050
# Episode 9886, Score:516, MaxTile:32, Epsilon:0.050
# Episode 9887, Score:1596, MaxTile:128, Epsilon:0.050
# Episode 9888, Score:872, MaxTile:64, Epsilon:0.050
# Episode 9889, Score:948, MaxTile:64, Epsilon:0.050
# Episode 9890, Score:1368, MaxTile:128, Epsilon:0.050
# Episode 9891, Score:700, MaxTile:64, Epsilon:0.050
# Episode 9892, Score:1004, MaxTile:128, Epsilon:0.050
# Episode 9893, Score:1172, MaxTile:128, Epsilon:0.050
# Episode 9894, Score:1420, MaxTile:128, Epsilon:0.050
# Episode 9895, Score:848, MaxTile:64, Epsilon:0.050
# Episode 9896, Score:1060, MaxTile:128, Epsilon:0.050
# Episode 9897, Score:1256, MaxTile:128, Epsilon:0.050
# Episode 9898, Score:656, MaxTile:64, Epsilon:0.050
# Episode 9899, Score:492, MaxTile:64, Epsilon:0.050
# Episode 9900, Score:1872, MaxTile:128, Epsilon:0.050
# Episode 9901, Score:656, MaxTile:64, Epsilon:0.050
# Episode 9902, Score:1572, MaxTile:128, Epsilon:0.050
# Episode 9903, Score:392, MaxTile:32, Epsilon:0.050
# Episode 9904, Score:972, MaxTile:128, Epsilon:0.050
# Episode 9905, Score:1536, MaxTile:128, Epsilon:0.050
# Episode 9906, Score:1820, MaxTile:128, Epsilon:0.050
# Episode 9907, Score:584, MaxTile:64, Epsilon:0.050
# Episode 9908, Score:2836, MaxTile:256, Epsilon:0.050
# Episode 9909, Score:1524, MaxTile:128, Epsilon:0.050
# Episode 9910, Score:1444, MaxTile:128, Epsilon:0.050
# Episode 9911, Score:2692, MaxTile:256, Epsilon:0.050
# Episode 9912, Score:2572, MaxTile:256, Epsilon:0.050
# Episode 9913, Score:1220, MaxTile:128, Epsilon:0.050
# Episode 9914, Score:280, MaxTile:32, Epsilon:0.050
# Episode 9915, Score:1004, MaxTile:128, Epsilon:0.050
# Episode 9916, Score:684, MaxTile:64, Epsilon:0.050
# Episode 9917, Score:648, MaxTile:64, Epsilon:0.050
# Episode 9918, Score:676, MaxTile:64, Epsilon:0.050
# Episode 9919, Score:1024, MaxTile:128, Epsilon:0.050
# Episode 9920, Score:772, MaxTile:64, Epsilon:0.050
# Episode 9921, Score:1792, MaxTile:128, Epsilon:0.050
# Episode 9922, Score:264, MaxTile:32, Epsilon:0.050
# Episode 9923, Score:892, MaxTile:64, Epsilon:0.050
# Episode 9924, Score:1420, MaxTile:128, Epsilon:0.050
# Episode 9925, Score:976, MaxTile:64, Epsilon:0.050
# Episode 9926, Score:1588, MaxTile:128, Epsilon:0.050
# Episode 9927, Score:808, MaxTile:64, Epsilon:0.050
# Episode 9928, Score:608, MaxTile:64, Epsilon:0.050
# Episode 9929, Score:1452, MaxTile:128, Epsilon:0.050
# Episode 9930, Score:1044, MaxTile:128, Epsilon:0.050
# Episode 9931, Score:1512, MaxTile:128, Epsilon:0.050
# Episode 9932, Score:1460, MaxTile:128, Epsilon:0.050
# Episode 9933, Score:1016, MaxTile:64, Epsilon:0.050
# Episode 9934, Score:1056, MaxTile:64, Epsilon:0.050
# Episode 9935, Score:1500, MaxTile:128, Epsilon:0.050
# Episode 9936, Score:1588, MaxTile:128, Epsilon:0.050
# Episode 9937, Score:596, MaxTile:64, Epsilon:0.050
# Episode 9938, Score:1352, MaxTile:128, Epsilon:0.050
# Episode 9939, Score:1852, MaxTile:128, Epsilon:0.050
# Episode 9940, Score:2280, MaxTile:128, Epsilon:0.050
# Episode 9941, Score:652, MaxTile:64, Epsilon:0.050
# Episode 9942, Score:840, MaxTile:64, Epsilon:0.050
# Episode 9943, Score:492, MaxTile:64, Epsilon:0.050
# Episode 9944, Score:168, MaxTile:16, Epsilon:0.050
# Episode 9945, Score:2120, MaxTile:256, Epsilon:0.050
# Episode 9946, Score:1440, MaxTile:128, Epsilon:0.050
# Episode 9947, Score:1264, MaxTile:128, Epsilon:0.050
# Episode 9948, Score:580, MaxTile:64, Epsilon:0.050
# Episode 9949, Score:1108, MaxTile:128, Epsilon:0.050
# Episode 9950, Score:2204, MaxTile:128, Epsilon:0.050
# Episode 9951, Score:1192, MaxTile:128, Epsilon:0.050
# Episode 9952, Score:760, MaxTile:64, Epsilon:0.050
# Episode 9953, Score:2412, MaxTile:256, Epsilon:0.050
# Episode 9954, Score:724, MaxTile:64, Epsilon:0.050
# Episode 9955, Score:1612, MaxTile:128, Epsilon:0.050
# Episode 9956, Score:624, MaxTile:64, Epsilon:0.050
# Episode 9957, Score:1188, MaxTile:128, Epsilon:0.050
# Episode 9958, Score:476, MaxTile:32, Epsilon:0.050
# Episode 9959, Score:1160, MaxTile:64, Epsilon:0.050
# Episode 9960, Score:1400, MaxTile:128, Epsilon:0.050
# Episode 9961, Score:1636, MaxTile:128, Epsilon:0.050
# Episode 9962, Score:1264, MaxTile:128, Epsilon:0.050
# Episode 9963, Score:660, MaxTile:64, Epsilon:0.050
# Episode 9964, Score:448, MaxTile:32, Epsilon:0.050
# Episode 9965, Score:2776, MaxTile:256, Epsilon:0.050
# Episode 9966, Score:1592, MaxTile:128, Epsilon:0.050
# Episode 9967, Score:2020, MaxTile:256, Epsilon:0.050
# Episode 9968, Score:1632, MaxTile:128, Epsilon:0.050
# Episode 9969, Score:408, MaxTile:32, Epsilon:0.050
# Episode 9970, Score:384, MaxTile:32, Epsilon:0.050
# Episode 9971, Score:1224, MaxTile:128, Epsilon:0.050
# Episode 9972, Score:2136, MaxTile:256, Epsilon:0.050
# Episode 9973, Score:1208, MaxTile:128, Epsilon:0.050
# Episode 9974, Score:1632, MaxTile:128, Epsilon:0.050
# Episode 9975, Score:324, MaxTile:32, Epsilon:0.050
# Episode 9976, Score:752, MaxTile:64, Epsilon:0.050
# Episode 9977, Score:1044, MaxTile:64, Epsilon:0.050
# Episode 9978, Score:616, MaxTile:64, Epsilon:0.050
# Episode 9979, Score:1864, MaxTile:128, Epsilon:0.050
# Episode 9980, Score:1584, MaxTile:128, Epsilon:0.050
# Episode 9981, Score:2052, MaxTile:256, Epsilon:0.050
# Episode 9982, Score:1624, MaxTile:128, Epsilon:0.050
# Episode 9983, Score:404, MaxTile:32, Epsilon:0.050
# Episode 9984, Score:1060, MaxTile:128, Epsilon:0.050
# Episode 9985, Score:988, MaxTile:64, Epsilon:0.050
# Episode 9986, Score:1448, MaxTile:128, Epsilon:0.050
# Episode 9987, Score:1028, MaxTile:128, Epsilon:0.050
# Episode 9988, Score:1548, MaxTile:128, Epsilon:0.050
# Episode 9989, Score:780, MaxTile:64, Epsilon:0.050
# Episode 9990, Score:2100, MaxTile:128, Epsilon:0.050
# Episode 9991, Score:1104, MaxTile:128, Epsilon:0.050
# Episode 9992, Score:1324, MaxTile:128, Epsilon:0.050
# Episode 9993, Score:2504, MaxTile:256, Epsilon:0.050
# Episode 9994, Score:884, MaxTile:64, Epsilon:0.050
# Episode 9995, Score:1960, MaxTile:256, Epsilon:0.050
# Episode 9996, Score:1392, MaxTile:128, Epsilon:0.050
# Episode 9997, Score:1056, MaxTile:128, Epsilon:0.050
# Episode 9998, Score:1436, MaxTile:128, Epsilon:0.050
# Episode 9999, Score:2668, MaxTile:256, Epsilon:0.050
# 🏆 Best MaxTile over all episodes: 512

# %%
# --- Final Stats ---
print("\n=== Move Frequencies Overall ===")
for m in ACTION_MAP.values():
    print(f"{m}: {move_counter_global[m]}")

# --- Evaluation (greedy, uncapped) ---
eval_scores, tile_counts, move_counter_eval = [], Counter(), defaultdict(int)
eval_max_tiles = []
for _ in range(100):
    obs, _ = env.reset()
    state = preprocess(obs)
    total = 0
    episode_max_tile = 0
    while True:
        action = sample_action(state, obs, explore=False)
        if action is None:
            break
        move_counter_eval[ACTION_MAP[action]] += 1

        old_board = decode_obs(obs)
        obs, r, term, trunc, _ = env.step(action)
        state = preprocess(obs)
        total = int(total) + int(r)
        
        # update episode max tile
        board = decode_obs(obs)
        episode_max_tile = max(episode_max_tile, int(board.max()))

        # stop only on true terminal
        if term or trunc or np.array_equal(decode_obs(obs), old_board):
            break

    eval_scores.append(int(total))
    tile_counts[2**int(np.max(decode_obs(obs)))] += 1
    eval_max_tiles.append(episode_max_tile)

best_tile = max(eval_max_tiles)
print(f"Eval Avg: {np.mean(eval_scores):.2f}, Max: {np.max(eval_scores)}")
print("Eval Tiles:", tile_counts)
print("Eval Moves:", move_counter_eval)
print("Per-Game MaxTiles:", eval_max_tiles)
print("Best MaxTile over 100 games:", best_tile)
# Out:
# === Move Frequencies Overall ===
# Up: 299912
# Right: 315868
# Down: 317975
# Left: 309964
# Eval Avg: 1442.64, Max: 3988
# Eval Tiles: Counter({340282366920938463463374607431768211456: 51, 18446744073709551616: 28, 115792089237316195423570985008687907853269984665640564039457584007913129639936: 13, 4294967296: 6, 65536: 2})
# Eval Moves: defaultdict(<class 'int'>, {'Down': 6919, 'Left': 3046, 'Up': 2282, 'Right': 2849})
# Per-Game MaxTiles: [128, 64, 64, 256, 64, 128, 128, 32, 16, 128, 128, 64, 256, 128, 64, 64, 128, 128, 128, 128, 128, 16, 256, 32, 128, 256, 128, 128, 64, 32, 128, 128, 64, 128, 128, 32, 32, 64, 128, 64, 128, 128, 128, 128, 64, 64, 128, 128, 64, 64, 128, 128, 256, 64, 128, 128, 128, 128, 256, 64, 128, 128, 64, 256, 64, 128, 64, 256, 128, 128, 256, 32, 128, 64, 256, 128, 128, 256, 128, 256, 64, 128, 64, 128, 128, 128, 128, 128, 128, 64, 64, 256, 64, 128, 64, 64, 64, 128, 128, 128]
# Best MaxTile over 100 games: 256

# %% [markdown]
# du_ma = np.convolve(dqn_scores, np.ones(100)/100, mode='valid')
# print(du_ma.max())
