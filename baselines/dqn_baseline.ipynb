# %%
import gymnasium as gym
import gymnasium_2048
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque, defaultdict, Counter
import random

# --- Setup ---
env = gym.make("gymnasium_2048/TwentyFortyEight-v0")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Hyperparameters ---
GAMMA = 0.99
LR = 1e-3
EPSILON_START = 1.0
EPSILON_END = 0.05
EPSILON_DECAY = 0.995
BATCH_SIZE = 64
MEMORY_SIZE = 10000
TARGET_UPDATE_FREQ = 10
ROLLING_WINDOW = 20
CONVERGENCE_SCORE = 500
MAX_EPISODES = 500

ACTION_MAP = {0: "Up", 1: "Right", 2: "Down", 3: "Left"}

# --- DQN Model ---
class DQN(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 4)
        )
    def forward(self, x):
        return self.net(x)

def preprocess(state):
    return torch.tensor(np.reshape(state, -1), dtype=torch.float32).to(device)

policy_net = DQN().to(device)
target_net = DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=LR)
memory = deque(maxlen=MEMORY_SIZE)

epsilon = EPSILON_START
score_history = []
move_counter_global = defaultdict(int)
episode_bucket_counts = []

def sample_action(state, explore=True):
    if explore and np.random.rand() < epsilon:
        return env.action_space.sample()
    with torch.no_grad():
        return torch.argmax(policy_net(state)).item()

def optimize():
    if len(memory) < BATCH_SIZE:
        return
    batch = random.sample(memory, BATCH_SIZE)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.stack(states)
    actions = torch.tensor(actions).unsqueeze(1).to(device)
    rewards = torch.tensor(rewards).float().to(device)
    next_states = torch.stack(next_states)
    dones = torch.tensor(dones).float().to(device)

    q_values = policy_net(states).gather(1, actions).squeeze()
    next_q_values = target_net(next_states).max(1)[0].detach()
    target = rewards + GAMMA * next_q_values * (1 - dones)

    loss = nn.functional.mse_loss(q_values, target)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# --- Training Loop ---
episode = 0
while episode < MAX_EPISODES:
    obs, _ = env.reset()
    state = preprocess(obs)
    total_reward = 0
    move_counter_episode = defaultdict(int)

    while True:
        action = sample_action(state)
        move_name = ACTION_MAP[action]
        move_counter_global[move_name] += 1
        move_counter_episode[move_name] += 1

        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_state = preprocess(next_obs)
        memory.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward

        optimize()
        if done:
            break

    if episode % TARGET_UPDATE_FREQ == 0:
        target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
    score_history.append(total_reward)
    print(f"Episode {episode}, Score: {total_reward:.2f}, Epsilon: {epsilon:.3f}")

    # Check convergence
    if episode >= ROLLING_WINDOW:
        avg_score = np.mean(score_history[-ROLLING_WINDOW:])
        if avg_score >= CONVERGENCE_SCORE:
            print(f"\n✅ Training converged at episode {episode} with avg score {avg_score:.2f}")
            break

    if (episode + 1) % 100 == 0:
        episode_bucket_counts.append(dict(move_counter_global))

    episode += 1

# --- Final Move Stats ---
print("\n=== Final Move Frequency (Total) ===")
for move in ACTION_MAP.values():
    print(f"{move}: {move_counter_global[move]}")

print("\n=== Moves Per 100 Episodes ===")
for i, snapshot in enumerate(episode_bucket_counts):
    print(f"--- Episodes {i * 100 + 1} to {(i + 1) * 100} ---")
    if i == 0:
        base = snapshot
    else:
        base = {
            move: snapshot[move] - episode_bucket_counts[i - 1].get(move, 0)
            for move in ACTION_MAP.values()
        }
    for move in ACTION_MAP.values():
        print(f"{move}: {base[move]}")
    print()

# --- Evaluation ---
print("\n🔍 Running 100 Evaluation Episodes (no exploration)...")
eval_scores = []
tile_counts = Counter()
move_counter_eval = defaultdict(int)

for _ in range(100):
    obs, _ = env.reset()
    state = preprocess(obs)
    total_reward = 0
    while True:
        action = sample_action(state, explore=False)
        move_counter_eval[ACTION_MAP[action]] += 1
        next_obs, reward, terminated, truncated, _ = env.step(action)
        state = preprocess(next_obs)
        total_reward += reward
        if terminated or truncated:
            break
    eval_scores.append(total_reward)
    final_board = np.argmax(next_obs, axis=2)  # one-hot to tile value
    tile_counts[2 ** np.max(final_board)] += 1

print(f"\n✅ Evaluation complete. Results over 100 episodes:")
print(f"Average Score: {np.mean(eval_scores):.2f}")
print(f"Max Score: {np.max(eval_scores):.2f}")
print("\nMax Tile Achieved (frequency):")
for tile, count in sorted(tile_counts.items(), reverse=True):
    print(f"{tile}: {count} times")

print("\nEvaluation Move Distribution:")
for move in ACTION_MAP.values():
    print(f"{move}: {move_counter_eval[move]}")
# Out:
# C:\Users\XPS\AppData\Local\Temp\ipykernel_44200\2723684032.py:103: RuntimeWarning: overflow encountered in scalar add
#   total_reward += reward
# Episode 0, Score: 104.00, Epsilon: 0.995
# Episode 1, Score: 196.00, Epsilon: 0.990
# Episode 2, Score: 56.00, Epsilon: 0.985
# Episode 3, Score: 248.00, Epsilon: 0.980
# Episode 4, Score: 240.00, Epsilon: 0.975
# Episode 5, Score: 160.00, Epsilon: 0.970
# Episode 6, Score: 172.00, Epsilon: 0.966
# Episode 7, Score: 4.00, Epsilon: 0.961
# Episode 8, Score: 64.00, Epsilon: 0.956
# Episode 9, Score: 52.00, Epsilon: 0.951
# Episode 10, Score: 168.00, Epsilon: 0.946
# Episode 11, Score: 44.00, Epsilon: 0.942
# Episode 12, Score: 252.00, Epsilon: 0.937
# Episode 13, Score: 96.00, Epsilon: 0.932
# Episode 14, Score: 236.00, Epsilon: 0.928
# Episode 15, Score: 92.00, Epsilon: 0.923
# Episode 16, Score: 172.00, Epsilon: 0.918
# Episode 17, Score: 4.00, Epsilon: 0.914
# Episode 18, Score: 196.00, Epsilon: 0.909
# Episode 19, Score: 0.00, Epsilon: 0.905
# Episode 20, Score: 212.00, Epsilon: 0.900
# Episode 21, Score: 216.00, Epsilon: 0.896
# Episode 22, Score: 36.00, Epsilon: 0.891
# Episode 23, Score: 240.00, Epsilon: 0.887
# Episode 24, Score: 24.00, Epsilon: 0.882
# Episode 25, Score: 100.00, Epsilon: 0.878
# Episode 26, Score: 12.00, Epsilon: 0.873
# Episode 27, Score: 208.00, Epsilon: 0.869
# Episode 28, Score: 88.00, Epsilon: 0.865
# Episode 29, Score: 220.00, Epsilon: 0.860
# Episode 30, Score: 164.00, Epsilon: 0.856
# Episode 31, Score: 132.00, Epsilon: 0.852
# Episode 32, Score: 0.00, Epsilon: 0.848
# Episode 33, Score: 104.00, Epsilon: 0.843
# Episode 34, Score: 24.00, Epsilon: 0.839
# Episode 35, Score: 196.00, Epsilon: 0.835
# Episode 36, Score: 252.00, Epsilon: 0.831
# Episode 37, Score: 108.00, Epsilon: 0.827
# Episode 38, Score: 88.00, Epsilon: 0.822
# Episode 39, Score: 236.00, Epsilon: 0.818
# Episode 40, Score: 216.00, Epsilon: 0.814
# Episode 41, Score: 252.00, Epsilon: 0.810
# Episode 42, Score: 128.00, Epsilon: 0.806
# Episode 43, Score: 116.00, Epsilon: 0.802
# Episode 44, Score: 224.00, Epsilon: 0.798
# Episode 45, Score: 4.00, Epsilon: 0.794
# Episode 46, Score: 212.00, Epsilon: 0.790
# Episode 47, Score: 64.00, Epsilon: 0.786
# Episode 48, Score: 252.00, Epsilon: 0.782
# Episode 49, Score: 156.00, Epsilon: 0.778
# Episode 50, Score: 248.00, Epsilon: 0.774
# Episode 51, Score: 112.00, Epsilon: 0.771
# Episode 52, Score: 56.00, Epsilon: 0.767
# Episode 53, Score: 56.00, Epsilon: 0.763
# Episode 54, Score: 48.00, Epsilon: 0.759
# Episode 55, Score: 200.00, Epsilon: 0.755
# Episode 56, Score: 92.00, Epsilon: 0.751
# Episode 57, Score: 208.00, Epsilon: 0.748
# Episode 58, Score: 12.00, Epsilon: 0.744
# Episode 59, Score: 4.00, Epsilon: 0.740
# Episode 60, Score: 12.00, Epsilon: 0.737
# Episode 61, Score: 60.00, Epsilon: 0.733
# Episode 62, Score: 80.00, Epsilon: 0.729
# Episode 63, Score: 32.00, Epsilon: 0.726
# Episode 64, Score: 184.00, Epsilon: 0.722
# Episode 65, Score: 4.00, Epsilon: 0.718
# Episode 66, Score: 168.00, Epsilon: 0.715
# Episode 67, Score: 88.00, Epsilon: 0.711
# Episode 68, Score: 192.00, Epsilon: 0.708
# Episode 69, Score: 56.00, Epsilon: 0.704
# Episode 70, Score: 0.00, Epsilon: 0.701
# Episode 71, Score: 60.00, Epsilon: 0.697
# Episode 72, Score: 72.00, Epsilon: 0.694
# Episode 73, Score: 60.00, Epsilon: 0.690
# Episode 74, Score: 200.00, Epsilon: 0.687
# Episode 75, Score: 60.00, Epsilon: 0.683
# Episode 76, Score: 96.00, Epsilon: 0.680
# Episode 77, Score: 252.00, Epsilon: 0.676
# Episode 78, Score: 248.00, Epsilon: 0.673
# Episode 79, Score: 200.00, Epsilon: 0.670
# Episode 80, Score: 108.00, Epsilon: 0.666
# Episode 81, Score: 164.00, Epsilon: 0.663
# Episode 82, Score: 152.00, Epsilon: 0.660
# Episode 83, Score: 112.00, Epsilon: 0.656
# Episode 84, Score: 184.00, Epsilon: 0.653
# Episode 85, Score: 40.00, Epsilon: 0.650
# Episode 86, Score: 164.00, Epsilon: 0.647
# Episode 87, Score: 108.00, Epsilon: 0.643
# Episode 88, Score: 84.00, Epsilon: 0.640
# Episode 89, Score: 164.00, Epsilon: 0.637
# Episode 90, Score: 144.00, Epsilon: 0.634
# Episode 91, Score: 12.00, Epsilon: 0.631
# Episode 92, Score: 116.00, Epsilon: 0.627
# Episode 93, Score: 4.00, Epsilon: 0.624
# Episode 94, Score: 148.00, Epsilon: 0.621
# Episode 95, Score: 244.00, Epsilon: 0.618
# Episode 96, Score: 168.00, Epsilon: 0.615
# Episode 97, Score: 4.00, Epsilon: 0.612
# Episode 98, Score: 248.00, Epsilon: 0.609
# Episode 99, Score: 248.00, Epsilon: 0.606
# Episode 100, Score: 108.00, Epsilon: 0.603
# Episode 101, Score: 200.00, Epsilon: 0.600
# Episode 102, Score: 68.00, Epsilon: 0.597
# Episode 103, Score: 196.00, Epsilon: 0.594
# Episode 104, Score: 120.00, Epsilon: 0.591
# Episode 105, Score: 140.00, Epsilon: 0.588
# Episode 106, Score: 56.00, Epsilon: 0.585
# Episode 107, Score: 164.00, Epsilon: 0.582
# Episode 108, Score: 228.00, Epsilon: 0.579
# Episode 109, Score: 200.00, Epsilon: 0.576
# Episode 110, Score: 200.00, Epsilon: 0.573
# Episode 111, Score: 40.00, Epsilon: 0.570
# Episode 112, Score: 8.00, Epsilon: 0.568
# Episode 113, Score: 236.00, Epsilon: 0.565
# Episode 114, Score: 88.00, Epsilon: 0.562
# Episode 115, Score: 52.00, Epsilon: 0.559
# Episode 116, Score: 216.00, Epsilon: 0.556
# Episode 117, Score: 144.00, Epsilon: 0.554
# Episode 118, Score: 40.00, Epsilon: 0.551
# Episode 119, Score: 84.00, Epsilon: 0.548
# Episode 120, Score: 76.00, Epsilon: 0.545
# Episode 121, Score: 44.00, Epsilon: 0.543
# Episode 122, Score: 244.00, Epsilon: 0.540
# Episode 123, Score: 24.00, Epsilon: 0.537
# Episode 124, Score: 68.00, Epsilon: 0.534
# Episode 125, Score: 96.00, Epsilon: 0.532
# Episode 126, Score: 248.00, Epsilon: 0.529
# Episode 127, Score: 64.00, Epsilon: 0.526
# Episode 128, Score: 180.00, Epsilon: 0.524
# Episode 129, Score: 152.00, Epsilon: 0.521
# Episode 130, Score: 184.00, Epsilon: 0.519
# Episode 131, Score: 8.00, Epsilon: 0.516
# Episode 132, Score: 132.00, Epsilon: 0.513
# Episode 133, Score: 80.00, Epsilon: 0.511
# Episode 134, Score: 12.00, Epsilon: 0.508
# Episode 135, Score: 56.00, Epsilon: 0.506
# Episode 136, Score: 68.00, Epsilon: 0.503
# Episode 137, Score: 40.00, Epsilon: 0.501
# Episode 138, Score: 164.00, Epsilon: 0.498
# Episode 139, Score: 24.00, Epsilon: 0.496
# Episode 140, Score: 180.00, Epsilon: 0.493
# Episode 141, Score: 168.00, Epsilon: 0.491
# Episode 142, Score: 156.00, Epsilon: 0.488
# Episode 143, Score: 128.00, Epsilon: 0.486
# Episode 144, Score: 96.00, Epsilon: 0.483
# Episode 145, Score: 112.00, Epsilon: 0.481
# Episode 146, Score: 252.00, Epsilon: 0.479
# Episode 147, Score: 88.00, Epsilon: 0.476
# Episode 148, Score: 104.00, Epsilon: 0.474
# Episode 149, Score: 216.00, Epsilon: 0.471
# Episode 150, Score: 168.00, Epsilon: 0.469
# Episode 151, Score: 216.00, Epsilon: 0.467
# Episode 152, Score: 220.00, Epsilon: 0.464
# Episode 153, Score: 84.00, Epsilon: 0.462
# Episode 154, Score: 84.00, Epsilon: 0.460
# Episode 155, Score: 0.00, Epsilon: 0.458
# Episode 156, Score: 152.00, Epsilon: 0.455
# Episode 157, Score: 172.00, Epsilon: 0.453
# Episode 158, Score: 72.00, Epsilon: 0.451
# Episode 159, Score: 92.00, Epsilon: 0.448
# Episode 160, Score: 76.00, Epsilon: 0.446
# Episode 161, Score: 92.00, Epsilon: 0.444
# Episode 162, Score: 48.00, Epsilon: 0.442
# Episode 163, Score: 212.00, Epsilon: 0.440
# Episode 164, Score: 220.00, Epsilon: 0.437
# Episode 165, Score: 172.00, Epsilon: 0.435
# Episode 166, Score: 180.00, Epsilon: 0.433
# Episode 167, Score: 120.00, Epsilon: 0.431
# Episode 168, Score: 224.00, Epsilon: 0.429
# Episode 169, Score: 36.00, Epsilon: 0.427
# Episode 170, Score: 12.00, Epsilon: 0.424
# Episode 171, Score: 132.00, Epsilon: 0.422
# Episode 172, Score: 140.00, Epsilon: 0.420
# Episode 173, Score: 128.00, Epsilon: 0.418
# Episode 174, Score: 68.00, Epsilon: 0.416
# Episode 175, Score: 100.00, Epsilon: 0.414
# Episode 176, Score: 100.00, Epsilon: 0.412
# Episode 177, Score: 0.00, Epsilon: 0.410
# Episode 178, Score: 224.00, Epsilon: 0.408
# Episode 179, Score: 180.00, Epsilon: 0.406
# Episode 180, Score: 88.00, Epsilon: 0.404
# Episode 181, Score: 44.00, Epsilon: 0.402
# Episode 182, Score: 4.00, Epsilon: 0.400
# Episode 183, Score: 188.00, Epsilon: 0.398
# Episode 184, Score: 164.00, Epsilon: 0.396
# Episode 185, Score: 124.00, Epsilon: 0.394
# Episode 186, Score: 224.00, Epsilon: 0.392
# Episode 187, Score: 132.00, Epsilon: 0.390
# Episode 188, Score: 80.00, Epsilon: 0.388
# Episode 189, Score: 8.00, Epsilon: 0.386
# Episode 190, Score: 28.00, Epsilon: 0.384
# Episode 191, Score: 224.00, Epsilon: 0.382
# Episode 192, Score: 200.00, Epsilon: 0.380
# Episode 193, Score: 28.00, Epsilon: 0.378
# Episode 194, Score: 220.00, Epsilon: 0.376
# Episode 195, Score: 0.00, Epsilon: 0.374
# Episode 196, Score: 192.00, Epsilon: 0.373
# Episode 197, Score: 56.00, Epsilon: 0.371
# Episode 198, Score: 84.00, Epsilon: 0.369
# Episode 199, Score: 36.00, Epsilon: 0.367
# Episode 200, Score: 88.00, Epsilon: 0.365
# Episode 201, Score: 216.00, Epsilon: 0.363
# Episode 202, Score: 116.00, Epsilon: 0.361
# Episode 203, Score: 24.00, Epsilon: 0.360
# Episode 204, Score: 36.00, Epsilon: 0.358
# Episode 205, Score: 228.00, Epsilon: 0.356
# Episode 206, Score: 52.00, Epsilon: 0.354
# Episode 207, Score: 128.00, Epsilon: 0.353
# Episode 208, Score: 192.00, Epsilon: 0.351
# Episode 209, Score: 104.00, Epsilon: 0.349
# Episode 210, Score: 68.00, Epsilon: 0.347
# Episode 211, Score: 68.00, Epsilon: 0.346
# Episode 212, Score: 52.00, Epsilon: 0.344
# Episode 213, Score: 64.00, Epsilon: 0.342
# Episode 214, Score: 0.00, Epsilon: 0.340
# Episode 215, Score: 120.00, Epsilon: 0.339
# Episode 216, Score: 252.00, Epsilon: 0.337
# Episode 217, Score: 20.00, Epsilon: 0.335
# Episode 218, Score: 116.00, Epsilon: 0.334
# Episode 219, Score: 132.00, Epsilon: 0.332
# Episode 220, Score: 148.00, Epsilon: 0.330
# Episode 221, Score: 176.00, Epsilon: 0.329
# Episode 222, Score: 32.00, Epsilon: 0.327
# Episode 223, Score: 32.00, Epsilon: 0.325
# Episode 224, Score: 184.00, Epsilon: 0.324
# Episode 225, Score: 184.00, Epsilon: 0.322
# Episode 226, Score: 80.00, Epsilon: 0.321
# Episode 227, Score: 56.00, Epsilon: 0.319
# Episode 228, Score: 188.00, Epsilon: 0.317
# Episode 229, Score: 72.00, Epsilon: 0.316
# Episode 230, Score: 120.00, Epsilon: 0.314
# Episode 231, Score: 16.00, Epsilon: 0.313
# Episode 232, Score: 32.00, Epsilon: 0.311
# Episode 233, Score: 76.00, Epsilon: 0.309
# Episode 234, Score: 32.00, Epsilon: 0.308
# Episode 235, Score: 112.00, Epsilon: 0.306
# Episode 236, Score: 244.00, Epsilon: 0.305
# Episode 237, Score: 64.00, Epsilon: 0.303
# Episode 238, Score: 36.00, Epsilon: 0.302
# Episode 239, Score: 12.00, Epsilon: 0.300
# Episode 240, Score: 192.00, Epsilon: 0.299
# Episode 241, Score: 104.00, Epsilon: 0.297
# Episode 242, Score: 232.00, Epsilon: 0.296
# Episode 243, Score: 8.00, Epsilon: 0.294
# Episode 244, Score: 4.00, Epsilon: 0.293
# Episode 245, Score: 240.00, Epsilon: 0.291
# Episode 246, Score: 0.00, Epsilon: 0.290
# Episode 247, Score: 16.00, Epsilon: 0.288
# Episode 248, Score: 104.00, Epsilon: 0.287
# Episode 249, Score: 188.00, Epsilon: 0.286
# Episode 250, Score: 128.00, Epsilon: 0.284
# Episode 251, Score: 100.00, Epsilon: 0.283
# Episode 252, Score: 140.00, Epsilon: 0.281
# Episode 253, Score: 212.00, Epsilon: 0.280
# Episode 254, Score: 240.00, Epsilon: 0.279
# Episode 255, Score: 164.00, Epsilon: 0.277
# Episode 256, Score: 220.00, Epsilon: 0.276
# Episode 257, Score: 64.00, Epsilon: 0.274
# Episode 258, Score: 40.00, Epsilon: 0.273
# Episode 259, Score: 136.00, Epsilon: 0.272
# Episode 260, Score: 52.00, Epsilon: 0.270
# Episode 261, Score: 48.00, Epsilon: 0.269
# Episode 262, Score: 180.00, Epsilon: 0.268
# Episode 263, Score: 164.00, Epsilon: 0.266
# Episode 264, Score: 144.00, Epsilon: 0.265
# Episode 265, Score: 240.00, Epsilon: 0.264
# Episode 266, Score: 160.00, Epsilon: 0.262
# Episode 267, Score: 168.00, Epsilon: 0.261
# Episode 268, Score: 168.00, Epsilon: 0.260
# Episode 269, Score: 204.00, Epsilon: 0.258
# Episode 270, Score: 84.00, Epsilon: 0.257
# Episode 271, Score: 156.00, Epsilon: 0.256
# Episode 272, Score: 144.00, Epsilon: 0.255
# Episode 273, Score: 248.00, Epsilon: 0.253
# Episode 274, Score: 96.00, Epsilon: 0.252
# Episode 275, Score: 164.00, Epsilon: 0.251
# Episode 276, Score: 48.00, Epsilon: 0.249
# Episode 277, Score: 16.00, Epsilon: 0.248
# Episode 278, Score: 128.00, Epsilon: 0.247
# Episode 279, Score: 80.00, Epsilon: 0.246
# Episode 280, Score: 64.00, Epsilon: 0.245
# Episode 281, Score: 44.00, Epsilon: 0.243
# Episode 282, Score: 16.00, Epsilon: 0.242
# Episode 283, Score: 76.00, Epsilon: 0.241
# Episode 284, Score: 48.00, Epsilon: 0.240
# Episode 285, Score: 84.00, Epsilon: 0.238
# Episode 286, Score: 84.00, Epsilon: 0.237
# Episode 287, Score: 88.00, Epsilon: 0.236
# Episode 288, Score: 76.00, Epsilon: 0.235
# Episode 289, Score: 68.00, Epsilon: 0.234
# Episode 290, Score: 56.00, Epsilon: 0.233
# Episode 291, Score: 104.00, Epsilon: 0.231
# Episode 292, Score: 164.00, Epsilon: 0.230
# Episode 293, Score: 184.00, Epsilon: 0.229
# Episode 294, Score: 68.00, Epsilon: 0.228
# Episode 295, Score: 212.00, Epsilon: 0.227
# Episode 296, Score: 12.00, Epsilon: 0.226
# Episode 297, Score: 60.00, Epsilon: 0.225
# Episode 298, Score: 48.00, Epsilon: 0.223
# Episode 299, Score: 184.00, Epsilon: 0.222
# Episode 300, Score: 40.00, Epsilon: 0.221
# Episode 301, Score: 104.00, Epsilon: 0.220
# Episode 302, Score: 84.00, Epsilon: 0.219
# Episode 303, Score: 44.00, Epsilon: 0.218
# Episode 304, Score: 252.00, Epsilon: 0.217
# Episode 305, Score: 132.00, Epsilon: 0.216
# Episode 306, Score: 76.00, Epsilon: 0.215
# Episode 307, Score: 52.00, Epsilon: 0.214
# Episode 308, Score: 48.00, Epsilon: 0.212
# Episode 309, Score: 52.00, Epsilon: 0.211
# Episode 310, Score: 40.00, Epsilon: 0.210
# Episode 311, Score: 144.00, Epsilon: 0.209
# Episode 312, Score: 144.00, Epsilon: 0.208
# Episode 313, Score: 252.00, Epsilon: 0.207
# Episode 314, Score: 128.00, Epsilon: 0.206
# Episode 315, Score: 224.00, Epsilon: 0.205
# Episode 316, Score: 200.00, Epsilon: 0.204
# Episode 317, Score: 216.00, Epsilon: 0.203
# Episode 318, Score: 200.00, Epsilon: 0.202
# Episode 319, Score: 4.00, Epsilon: 0.201
# Episode 320, Score: 248.00, Epsilon: 0.200
# Episode 321, Score: 224.00, Epsilon: 0.199
# Episode 322, Score: 68.00, Epsilon: 0.198
# Episode 323, Score: 60.00, Epsilon: 0.197
# Episode 324, Score: 32.00, Epsilon: 0.196
# Episode 325, Score: 240.00, Epsilon: 0.195
# Episode 326, Score: 92.00, Epsilon: 0.194
# Episode 327, Score: 96.00, Epsilon: 0.193
# Episode 328, Score: 144.00, Epsilon: 0.192
# Episode 329, Score: 108.00, Epsilon: 0.191
# Episode 330, Score: 120.00, Epsilon: 0.190
# Episode 331, Score: 164.00, Epsilon: 0.189
# Episode 332, Score: 204.00, Epsilon: 0.188
# Episode 333, Score: 80.00, Epsilon: 0.187
# Episode 334, Score: 44.00, Epsilon: 0.187
# Episode 335, Score: 88.00, Epsilon: 0.186
# Episode 336, Score: 188.00, Epsilon: 0.185
# Episode 337, Score: 104.00, Epsilon: 0.184
# Episode 338, Score: 92.00, Epsilon: 0.183
# Episode 339, Score: 28.00, Epsilon: 0.182
# Episode 340, Score: 68.00, Epsilon: 0.181
# Episode 341, Score: 0.00, Epsilon: 0.180
# Episode 342, Score: 204.00, Epsilon: 0.179
# Episode 343, Score: 196.00, Epsilon: 0.178
# Episode 344, Score: 208.00, Epsilon: 0.177
# Episode 345, Score: 196.00, Epsilon: 0.177
# Episode 346, Score: 60.00, Epsilon: 0.176
# Episode 347, Score: 124.00, Epsilon: 0.175
# Episode 348, Score: 148.00, Epsilon: 0.174
# Episode 349, Score: 220.00, Epsilon: 0.173
# Episode 350, Score: 16.00, Epsilon: 0.172
# Episode 351, Score: 168.00, Epsilon: 0.171
# Episode 352, Score: 188.00, Epsilon: 0.170
# Episode 353, Score: 224.00, Epsilon: 0.170
# Episode 354, Score: 84.00, Epsilon: 0.169
# Episode 355, Score: 168.00, Epsilon: 0.168
# Episode 356, Score: 176.00, Epsilon: 0.167
# Episode 357, Score: 128.00, Epsilon: 0.166
# Episode 358, Score: 108.00, Epsilon: 0.165
# Episode 359, Score: 96.00, Epsilon: 0.165
# Episode 360, Score: 132.00, Epsilon: 0.164
# Episode 361, Score: 220.00, Epsilon: 0.163
# Episode 362, Score: 84.00, Epsilon: 0.162
# Episode 363, Score: 108.00, Epsilon: 0.161
# Episode 364, Score: 72.00, Epsilon: 0.160
# Episode 365, Score: 108.00, Epsilon: 0.160
# Episode 366, Score: 200.00, Epsilon: 0.159
# Episode 367, Score: 36.00, Epsilon: 0.158
# Episode 368, Score: 112.00, Epsilon: 0.157
# Episode 369, Score: 164.00, Epsilon: 0.157
# Episode 370, Score: 100.00, Epsilon: 0.156
# Episode 371, Score: 160.00, Epsilon: 0.155
# Episode 372, Score: 104.00, Epsilon: 0.154
# Episode 373, Score: 112.00, Epsilon: 0.153
# Episode 374, Score: 232.00, Epsilon: 0.153
# Episode 375, Score: 220.00, Epsilon: 0.152
# Episode 376, Score: 64.00, Epsilon: 0.151
# Episode 377, Score: 40.00, Epsilon: 0.150
# Episode 378, Score: 124.00, Epsilon: 0.150
# Episode 379, Score: 220.00, Epsilon: 0.149
# Episode 380, Score: 232.00, Epsilon: 0.148
# Episode 381, Score: 188.00, Epsilon: 0.147
# Episode 382, Score: 0.00, Epsilon: 0.147
# Episode 383, Score: 32.00, Epsilon: 0.146
# Episode 384, Score: 0.00, Epsilon: 0.145
# Episode 385, Score: 152.00, Epsilon: 0.144
# Episode 386, Score: 12.00, Epsilon: 0.144
# Episode 387, Score: 108.00, Epsilon: 0.143
# Episode 388, Score: 108.00, Epsilon: 0.142
# Episode 389, Score: 100.00, Epsilon: 0.142
# Episode 390, Score: 172.00, Epsilon: 0.141
# Episode 391, Score: 212.00, Epsilon: 0.140
# Episode 392, Score: 168.00, Epsilon: 0.139
# Episode 393, Score: 56.00, Epsilon: 0.139
# Episode 394, Score: 212.00, Epsilon: 0.138
# Episode 395, Score: 56.00, Epsilon: 0.137
# Episode 396, Score: 76.00, Epsilon: 0.137
# Episode 397, Score: 244.00, Epsilon: 0.136
# Episode 398, Score: 24.00, Epsilon: 0.135
# Episode 399, Score: 228.00, Epsilon: 0.135
# Episode 400, Score: 196.00, Epsilon: 0.134
# Episode 401, Score: 0.00, Epsilon: 0.133
# Episode 402, Score: 252.00, Epsilon: 0.133
# Episode 403, Score: 24.00, Epsilon: 0.132
# Episode 404, Score: 168.00, Epsilon: 0.131
# Episode 405, Score: 40.00, Epsilon: 0.131
# Episode 406, Score: 28.00, Epsilon: 0.130
# Episode 407, Score: 96.00, Epsilon: 0.129
# Episode 408, Score: 108.00, Epsilon: 0.129
# Episode 409, Score: 128.00, Epsilon: 0.128
# Episode 410, Score: 204.00, Epsilon: 0.127
# Episode 411, Score: 56.00, Epsilon: 0.127
# Episode 412, Score: 132.00, Epsilon: 0.126
# Episode 413, Score: 36.00, Epsilon: 0.126
# Episode 414, Score: 228.00, Epsilon: 0.125
# Episode 415, Score: 12.00, Epsilon: 0.124
# Episode 416, Score: 128.00, Epsilon: 0.124
# Episode 417, Score: 124.00, Epsilon: 0.123
# Episode 418, Score: 72.00, Epsilon: 0.122
# Episode 419, Score: 112.00, Epsilon: 0.122
# Episode 420, Score: 224.00, Epsilon: 0.121
# Episode 421, Score: 8.00, Epsilon: 0.121
# Episode 422, Score: 108.00, Epsilon: 0.120
# Episode 423, Score: 4.00, Epsilon: 0.119
# Episode 424, Score: 72.00, Epsilon: 0.119
# Episode 425, Score: 88.00, Epsilon: 0.118
# Episode 426, Score: 164.00, Epsilon: 0.118
# Episode 427, Score: 60.00, Epsilon: 0.117
# Episode 428, Score: 80.00, Epsilon: 0.116
# Episode 429, Score: 36.00, Epsilon: 0.116
# Episode 430, Score: 76.00, Epsilon: 0.115
# Episode 431, Score: 24.00, Epsilon: 0.115
# Episode 432, Score: 8.00, Epsilon: 0.114
# Episode 433, Score: 32.00, Epsilon: 0.114
# Episode 434, Score: 192.00, Epsilon: 0.113
# Episode 435, Score: 16.00, Epsilon: 0.112
# Episode 436, Score: 28.00, Epsilon: 0.112
# Episode 437, Score: 80.00, Epsilon: 0.111
# Episode 438, Score: 176.00, Epsilon: 0.111
# Episode 439, Score: 168.00, Epsilon: 0.110
# Episode 440, Score: 200.00, Epsilon: 0.110
# Episode 441, Score: 80.00, Epsilon: 0.109
# Episode 442, Score: 128.00, Epsilon: 0.109
# Episode 443, Score: 88.00, Epsilon: 0.108
# Episode 444, Score: 100.00, Epsilon: 0.107
# Episode 445, Score: 72.00, Epsilon: 0.107
# Episode 446, Score: 204.00, Epsilon: 0.106
# Episode 447, Score: 228.00, Epsilon: 0.106
# Episode 448, Score: 124.00, Epsilon: 0.105
# Episode 449, Score: 156.00, Epsilon: 0.105
# Episode 450, Score: 160.00, Epsilon: 0.104
# Episode 451, Score: 104.00, Epsilon: 0.104
# Episode 452, Score: 136.00, Epsilon: 0.103
# Episode 453, Score: 0.00, Epsilon: 0.103
# Episode 454, Score: 100.00, Epsilon: 0.102
# Episode 455, Score: 40.00, Epsilon: 0.102
# Episode 456, Score: 32.00, Epsilon: 0.101
# Episode 457, Score: 64.00, Epsilon: 0.101
# Episode 458, Score: 192.00, Epsilon: 0.100
# Episode 459, Score: 64.00, Epsilon: 0.100
# Episode 460, Score: 12.00, Epsilon: 0.099
# Episode 461, Score: 40.00, Epsilon: 0.099
# Episode 462, Score: 20.00, Epsilon: 0.098
# Episode 463, Score: 200.00, Epsilon: 0.098
# Episode 464, Score: 100.00, Epsilon: 0.097
# Episode 465, Score: 124.00, Epsilon: 0.097
# Episode 466, Score: 244.00, Epsilon: 0.096
# Episode 467, Score: 16.00, Epsilon: 0.096
# Episode 468, Score: 96.00, Epsilon: 0.095
# Episode 469, Score: 100.00, Epsilon: 0.095
# Episode 470, Score: 32.00, Epsilon: 0.094
# Episode 471, Score: 64.00, Epsilon: 0.094
# Episode 472, Score: 164.00, Epsilon: 0.093
# Episode 473, Score: 244.00, Epsilon: 0.093
# Episode 474, Score: 212.00, Epsilon: 0.092
# Episode 475, Score: 12.00, Epsilon: 0.092
# Episode 476, Score: 160.00, Epsilon: 0.092
# Episode 477, Score: 36.00, Epsilon: 0.091
# Episode 478, Score: 152.00, Epsilon: 0.091
# Episode 479, Score: 124.00, Epsilon: 0.090
# Episode 480, Score: 84.00, Epsilon: 0.090
# Episode 481, Score: 132.00, Epsilon: 0.089
# Episode 482, Score: 232.00, Epsilon: 0.089
# Episode 483, Score: 20.00, Epsilon: 0.088
# Episode 484, Score: 200.00, Epsilon: 0.088
# Episode 485, Score: 164.00, Epsilon: 0.088
# Episode 486, Score: 108.00, Epsilon: 0.087
# Episode 487, Score: 228.00, Epsilon: 0.087
# Episode 488, Score: 4.00, Epsilon: 0.086
# Episode 489, Score: 148.00, Epsilon: 0.086
# Episode 490, Score: 108.00, Epsilon: 0.085
# Episode 491, Score: 156.00, Epsilon: 0.085
# Episode 492, Score: 20.00, Epsilon: 0.084
# Episode 493, Score: 68.00, Epsilon: 0.084
# Episode 494, Score: 208.00, Epsilon: 0.084
# Episode 495, Score: 152.00, Epsilon: 0.083
# Episode 496, Score: 84.00, Epsilon: 0.083
# Episode 497, Score: 224.00, Epsilon: 0.082
# Episode 498, Score: 224.00, Epsilon: 0.082
# Episode 499, Score: 232.00, Epsilon: 0.082
#
# === Final Move Frequency (Total) ===
# Up: 24194
# Right: 22054
# Down: 22969
# Left: 22140
#
# === Moves Per 100 Episodes ===
# --- Episodes 1 to 100 ---
# Up: 3744
# Right: 3533
# Down: 3694
# Left: 3420
#
# --- Episodes 101 to 200 ---
# Up: 3948
# Right: 3705
# Down: 4096
# Left: 3410
#
# --- Episodes 201 to 300 ---
# Up: 5029
# Right: 4080
# Down: 3961
# Left: 4479
#
# --- Episodes 301 to 400 ---
# Up: 4969
# Right: 5135
# Down: 4687
# Left: 4837
#
# --- Episodes 401 to 500 ---
# Up: 6504
# Right: 5601
# Down: 6531
# Left: 5994
#
#
# 🔍 Running 100 Evaluation Episodes (no exploration)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 161
#     159 move_counter_eval[ACTION_MAP[action]] += 1
#     160 next_obs, reward, terminated, truncated, _ = env.step(action)
# --> 161 state = preprocess(next_obs)
#     162 total_reward += reward
#     163 if terminated or truncated:
#
# Cell In[5], line 44, in preprocess(state)
#      43 def preprocess(state):
# ---> 44     return torch.tensor(np.reshape(state, -1), dtype=torch.float32).to(device)
#
# KeyboardInterrupt:
