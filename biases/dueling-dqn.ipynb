# %%
# === Cell 1: All Definitions & Instantiation ===

# 1) Standard imports
import gymnasium as gym
import gymnasium_2048
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque, defaultdict, Counter
import random

# 2) Hyperparameters & device/env
GAMMA               = 0.99
LR                  = 1e-3
EPSILON_START       = 1.0
EPSILON_END         = 0.05
EPSILON_DECAY       = 0.9995
BATCH_SIZE          = 128
MEMORY_SIZE         = 100_000
TARGET_UPDATE_FREQ  = 10
ROLLING_WINDOW      = 20
CONVERGENCE_SCORE   = 2000
MAX_EPISODES        = 10000
WARMUP_MEMORY       = 10_000
ACTION_MAP          = {0:"Up",1:"Right",2:"Down",3:"Left"}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env    = gym.make("gymnasium_2048/TwentyFortyEight-v0").unwrapped

# 3) DQN network definition
# class DQN(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.net = nn.Sequential(
#             nn.Linear(16,256),
#             nn.ReLU(),
#             nn.Linear(256,256),
#             nn.ReLU(),
#             nn.Linear(256,4)
#         )
#     def forward(self, x):
#         return self.net(x)
class DuelingDQN(nn.Module):
    def __init__(self):
        super().__init__()
        # shared feature extractor
        self.feature = nn.Sequential(
            nn.Linear(16, 256),
            nn.ReLU(),
        )
        # advantage branch
        self.adv = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 4),
        )
        # value branch
        self.val = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 1),
        )

    def forward(self, x):
        f = self.feature(x)
        A = self.adv(f)                   # shape [B,4]
        V = self.val(f).expand_as(A)      # shape [B,4]
        # combine into Q
        return V + (A - A.mean(dim=1, keepdim=True))

# 4) Preprocess & decode helpers
def preprocess(state):
    if state.ndim == 3:
        exp = np.argmax(state,axis=2)
        board = exp.astype(np.float32)
    else:
        board = np.where(state==0,0,np.log2(state)).astype(np.float32)
    return torch.tensor(board.flatten(),dtype=torch.float32,device=device)

def decode_obs(obs):
    if obs.ndim==3:
        exp = np.argmax(obs,axis=2)
        return np.where(exp==0,0,2**exp).astype(np.int32)
    return obs.astype(np.int32)

# 5) Slide & valid‐actions logic
def slide_row(row):
    nz, merged, i = [int(v) for v in row if v], [], 0
    while i < len(nz):
        if i+1<len(nz) and nz[i]==nz[i+1]:
            merged.append(nz[i]*2); i+=2
        else:
            merged.append(nz[i]); i+=1
    merged += [0]*(len(row)-len(merged))
    return merged

def slide(board, action):
    b = board.copy().astype(np.int32)
    if action == 0:            # Up
        b = b.T
        for i in range(4): b[i] = slide_row(b[i])
        b = b.T
    elif action == 2:          # Down
        b = b.T
        for i in range(4):
            rev = list(reversed(b[i]))
            b[i] = list(reversed(slide_row(rev)))
        b = b.T
    elif action == 3:          # Left
        for i in range(4): b[i] = slide_row(b[i])
    else:                       # Right
        for i in range(4):
            rev = list(reversed(b[i]))
            b[i] = list(reversed(slide_row(rev)))
    return b                  # <-- return the new board!

def valid_actions(obs):
    board = decode_obs(obs)
    return [a for a in range(4) if not np.array_equal(board, slide(board, a))]

# 6) Epsilon‐greedy action selector
def sample_action(state, obs, explore=True):
    valids = valid_actions(obs)
    if not valids:
        return None

    if explore and random.random() < epsilon:
        return random.choice(valids)

    with torch.no_grad():
        # make it [1,16] instead of [16]
        state_batched = state.unsqueeze(0)                # shape [1,16]
        q_vals = policy_net(state_batched)                # shape [1,4]
        q_vals = q_vals.cpu().numpy()[0]                  # shape [4]
    return max(valids, key=lambda a: q_vals[a])

# 7) Symmetry replay‐buffer
def transform_action(a: int, k: int, flipped: bool) -> int:
    # first rotate k×90°
    a_rot = (a + k) % 4
    # then if we flipped horizontally, Left<->Right swap
    if flipped:
        if a_rot == 1:   a_rot = 3
        elif a_rot == 3: a_rot = 1
    return a_rot

# --- SumTree helper for PER ---
class SumTree:
    def __init__(self, capacity: int):
        self.capacity = capacity
        self.tree = np.zeros(2*capacity - 1)
        self.data = [None]*capacity
        self.write = 0
        self.n_entries = 0

    def _propagate(self, idx, change):
        parent = (idx - 1)//2
        self.tree[parent] += change
        if parent != 0:
            self._propagate(parent, change)

    def update(self, idx, priority):
        change = priority - self.tree[idx]
        self.tree[idx] = priority
        self._propagate(idx, change)

    def add(self, priority, data):
        idx = self.write + self.capacity - 1
        self.data[self.write] = data
        self.update(idx, priority)
        self.write = (self.write + 1) % self.capacity
        self.n_entries = min(self.n_entries + 1, self.capacity)

    def get(self, s: float):
        idx = 0
        while True:
            left = 2*idx + 1
            right = left + 1
            if left >= len(self.tree):
                leaf = idx
                break
            if s <= self.tree[left]:
                idx = left
            else:
                s -= self.tree[left]
                idx = right
        data_idx = leaf - self.capacity + 1
        return leaf, self.tree[leaf], self.data[data_idx]

    @property
    def total(self):
        return self.tree[0]


# --- Prioritized Replay Buffer ---
class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=0.4, beta_start=0.4, beta_frames=500_000):
        self.tree = SumTree(capacity)
        self.alpha = alpha
        self.beta_start = beta_start
        self.beta_frames = beta_frames
        self.frame = 1
        self.eps = 1e-6

    def add(self, state, action, reward, next_state, done):
        max_p = np.max(self.tree.tree[-self.tree.capacity:])
        if max_p == 0: max_p = 1.0
        self.tree.add(max_p, (state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch, idxs, priors = [], [], []
        segment = self.tree.total / batch_size
        for i in range(batch_size):
            a, b = segment*i, segment*(i+1)
            s = random.uniform(a, b)
            idx, p, data = self.tree.get(s)
            batch.append(data)
            idxs.append(idx)
            priors.append(p)

        probs = np.array(priors) / self.tree.total
        beta = min(1.0, self.beta_start + (1.0 - self.beta_start)*(self.frame/self.beta_frames))
        self.frame += 1
        weights = (self.tree.n_entries * probs)**(-beta)
        weights /= weights.max()

        S, A, R, S2, D = zip(*batch)
        return (
            torch.stack([preprocess(s) for s in S]),
            torch.tensor(A, dtype=torch.long,   device=device),
            torch.tensor(R, dtype=torch.float,  device=device),
            torch.stack([preprocess(s2) for s2 in S2]),
            torch.tensor(D, dtype=torch.float,  device=device),
            idxs,
            torch.tensor(weights, dtype=torch.float, device=device)
        )

    def update_priorities(self, idxs, td_errors):
        for idx, err in zip(idxs, td_errors):
            p = (abs(err) + self.eps)**self.alpha
            self.tree.update(idx, p)

    def __len__(self):
        return self.tree.n_entries

# --- Now subclass to combine symmetry + PER ---
class SymmetricPERBuffer(PrioritizedReplayBuffer):
    def add(self, state, action, reward, next_state, done):
        # state & next_state are raw board (4×4 int arrays)
        for k in range(4):
            rot_s  = np.rot90(state,  k)
            rot_ns = np.rot90(next_state, k)
            a_rot  = transform_action(action, k, False)
            # append the k-rotation
            super().add(rot_s, a_rot, reward, rot_ns, done)

            # now mirror horizontally
            f_s  = np.fliplr(rot_s)
            f_ns = np.fliplr(rot_ns)
            a_fl = transform_action(action, k, True)
            super().add(f_s, a_fl, reward, f_ns, done)

# --- N-Step Wrapper ---
class NStepWrapper:
    def __init__(self, buffer, n=3, gamma=0.99):
        self.buf, self.n, self.gamma = buffer, n, gamma
        self.nq = deque()

    def add(self, s, a, r, s2, done):
        self.nq.append((s, a, r))
        if len(self.nq) < self.n:
            return
        R = sum(self.nq[i][2] * (self.gamma**i) for i in range(self.n))
        s0, a0, _ = self.nq[0]
        self.buf.add(s0, a0, R, s2, done)
        self.nq.popleft()

    def sample(self, *args): 
        return self.buf.sample(*args)

    def __len__(self):
        return len(self.buf)
    
    def update_priorities(self, idxs, td_errors):
        # delegate priority updates
        self.buf.update_priorities(idxs, td_errors)

# 8) Instantiate nets, optimizer & buffer
# policy_net = DQN().to(device)
# target_net = DQN().to(device)
# target_net.load_state_dict(policy_net.state_dict())
policy_net = DuelingDQN().to(device)
target_net = DuelingDQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
optimizer   = optim.Adam(policy_net.parameters(), lr=LR)
base_buf = SymmetricPERBuffer(capacity=MEMORY_SIZE, alpha=0.6, beta_start=0.3, beta_frames=500_000)
memory   = NStepWrapper(base_buf, n=3, gamma=GAMMA)

# 9) Initialize training state
epsilon             = EPSILON_START
score_history       = []
move_counter_global = defaultdict(int)

# %%
# --- 3) Training Loop (with enhanced eval & smoothing) ---
global_max_tile = 0  # track the single largest tile we’ve ever seen (either during training or eval)

for episode in range(MAX_EPISODES):
    obs, _ = env.reset()
    state = preprocess(obs)
    running_score = 0

    # reset per-episode max
    max_tile_in_episode = int(np.max(decode_obs(obs)))

    # rolling‐window train‐score smoothing
    if len(score_history) >= 50:
        ma50 = np.mean(score_history[-50:])
    else:
        ma50 = np.mean(score_history) if score_history else 0

    while True:
        # select action
        action = sample_action(state, obs, explore=True)
        if action is None:
            break

        move_counter_global[ACTION_MAP[action]] += 1

        # step env
        next_obs, reward, term, trunc, info = env.step(action)
        done = term or trunc
        next_state = preprocess(next_obs)

        # let the buffer do its 8‐way augmentation
        memory.add(decode_obs(obs), action, reward, decode_obs(next_obs), done)

        state, obs = next_state, next_obs
        running_score += int(reward)

        # update episode max
        t = int(np.max(decode_obs(next_obs)))
        max_tile_in_episode = max(max_tile_in_episode, t)

        # also update the global max
        global_max_tile = max(global_max_tile, max_tile_in_episode)

        # optimize
        if len(memory) > WARMUP_MEMORY:
            s_b, a_b, r_b, ns_b, d_b, idxs, is_weights = memory.sample(BATCH_SIZE)

            # current Q and next Q
            q = policy_net(s_b).gather(1, a_b.unsqueeze(1)).squeeze()
            
            # 1) select next‐actions via the *policy* net
            next_actions = policy_net(ns_b).argmax(dim=1, keepdim=True)      # shape [B,1]
            # 2) evaluate those actions under the *target* net
            q_next = target_net(ns_b).gather(1, next_actions).squeeze()     # shape [B]
            # 3) standard TD target
            target = r_b + GAMMA * q_next * (1 - d_b)

            # compute TD-errors for priority update
            td_errors = (q - target).detach().abs().cpu().numpy()

            # weighted MSE loss
            loss = (is_weights * (q - target)**2).mean()

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(policy_net.parameters(), 1.0)
            optimizer.step()

            # update priorities in the tree
            memory.update_priorities(idxs, td_errors)

        if done:
            break

    # end‐of‐episode housekeeping
    if episode % TARGET_UPDATE_FREQ == 0:
        target_net.load_state_dict(policy_net.state_dict())
    epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
    score_history.append(running_score)

    # 1) Training print + 50‐episode MA
    print(f"Episode {episode:4d} | Score {running_score:5d} | MaxTile {max_tile_in_episode:4d} | MA50 {ma50:6.1f} | ε {epsilon:.3f}")

    # 2) Enhanced periodic evaluation every 100 episodes
    if episode > 0 and episode % 100 == 0:
        eval_scores, tiles, move_counter_eval = [], [], defaultdict(int)
        for _ in range(100):  # run 100 greedy games
            o, _ = env.reset()
            s = preprocess(o)
            total = 0
            while True:
                a = sample_action(s, o, explore=False)
                if a is None: break
                o, r, term, trunc, _ = env.step(a)
                s = preprocess(o)
                total += int(r)
                if term or trunc: break
            eval_scores.append(total)
            tile = int(np.max(decode_obs(o)))  # true max tile
            tiles.append(tile)
            move_counter_eval[ACTION_MAP[a]] += 1

        # compute percentiles
        p25, p50, p75 = np.percentile(tiles, [25, 50, 75])

        print(f"  → Eval @ ep {episode}: Avg {np.mean(eval_scores):.1f}, Max {np.max(eval_scores)}")
        print(f"     Tile p25/p50/p75: {p25}/{p50}/{p75}")
        # optional full histogram
        hist = {t: tiles.count(t) for t in sorted(set(tiles))}
        print(f"     Tiles hist: {hist}")

    # 3) Convergence check
    if (episode >= ROLLING_WINDOW and 
        np.mean(score_history[-ROLLING_WINDOW:]) >= CONVERGENCE_SCORE):
        print(f"✅ Converged at ep {episode}")
        break

# --- 4) Final Evaluation & Logs ---
print("\n=== Move Frequencies Overall ===")
for m in ACTION_MAP.values():
    print(f"{m}: {move_counter_global[m]}")

eval_scores, tile_hist, move_counter_eval = [], Counter(), defaultdict(int)
for _ in range(100):
    obs, _ = env.reset()
    state = preprocess(obs)
    total = 0
    while True:
        a = sample_action(state, obs, explore=False)
        if a is None:
            break
        move_counter_eval[ACTION_MAP[a]] += 1
        old_board = decode_obs(obs)
        obs, r, term, trunc, _ = env.step(a)
        state = preprocess(obs)
        total += int(r)
        if term or trunc or np.array_equal(decode_obs(obs), old_board):
            break
    eval_scores.append(total)
    tile_hist[int(np.max(decode_obs(obs)))] += 1

# you already have tile_hist mapping each game’s max-tile to counts
eval_max_tile = max(tile_hist.keys()) if tile_hist else 0
global_max_tile = max(global_max_tile, eval_max_tile)

print(f"\n=== FINAL ===")
print(f"Highest tile over everything: {global_max_tile}")
print(f"Eval Avg: {np.mean(eval_scores):.2f}  |  Max Score: {np.max(eval_scores)}")
print("Eval Tiles:", tile_hist)
print("Eval Moves:", move_counter_eval)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cs224r-final-project/lib/python3.10/site-packages/gymnasium_2048/envs/twenty_forty_eight.py:250: RuntimeWarning: overflow encountered in scalar add
#   self.total_score += self.step_score
# Episode    0 | Score   532 | MaxTile   64 | MA50    0.0 | ε 1.000
# Episode    1 | Score   404 | MaxTile   32 | MA50  532.0 | ε 0.999
# Episode    2 | Score  1052 | MaxTile  128 | MA50  468.0 | ε 0.999
# Episode    3 | Score  1312 | MaxTile  128 | MA50  662.7 | ε 0.998
# Episode    4 | Score   976 | MaxTile   64 | MA50  825.0 | ε 0.998
# Episode    5 | Score  1904 | MaxTile  128 | MA50  855.2 | ε 0.997
# Episode    6 | Score  1308 | MaxTile  128 | MA50 1030.0 | ε 0.997
# Episode    7 | Score  1144 | MaxTile  128 | MA50 1069.7 | ε 0.996
# Episode    8 | Score   536 | MaxTile   64 | MA50 1079.0 | ε 0.996
# Episode    9 | Score   652 | MaxTile   64 | MA50 1018.7 | ε 0.995
# Episode   10 | Score   644 | MaxTile   64 | MA50  982.0 | ε 0.995
# /var/folders/__/3mnlb1114135zsp0r6ncg4280000gn/T/ipykernel_23387/3981964628.py:78: RuntimeWarning: divide by zero encountered in log2
#   board = np.where(state==0,0,np.log2(state)).astype(np.float32)
# Episode   11 | Score  1416 | MaxTile  128 | MA50  951.3 | ε 0.994
# Episode   12 | Score  1460 | MaxTile  128 | MA50  990.0 | ε 0.994
# Episode   13 | Score   680 | MaxTile   64 | MA50 1026.2 | ε 0.993
# Episode   14 | Score   668 | MaxTile   64 | MA50 1001.4 | ε 0.993
# Episode   15 | Score  3240 | MaxTile  256 | MA50  979.2 | ε 0.992
# Episode   16 | Score   676 | MaxTile   64 | MA50 1120.5 | ε 0.992
# Episode   17 | Score  1280 | MaxTile  128 | MA50 1094.4 | ε 0.991
# Episode   18 | Score   880 | MaxTile   64 | MA50 1104.7 | ε 0.991
# Episode   19 | Score  1072 | MaxTile  128 | MA50 1092.8 | ε 0.990
# Episode   20 | Score  2028 | MaxTile  128 | MA50 1091.8 | ε 0.990
# Episode   21 | Score   892 | MaxTile   64 | MA50 1136.4 | ε 0.989
# Episode   22 | Score  2040 | MaxTile  256 | MA50 1125.3 | ε 0.989
# Episode   23 | Score  1320 | MaxTile  128 | MA50 1165.0 | ε 0.988
# Episode   24 | Score   636 | MaxTile   64 | MA50 1171.5 | ε 0.988
# Episode   25 | Score   656 | MaxTile   64 | MA50 1150.1 | ε 0.987
# Episode   26 | Score   672 | MaxTile   64 | MA50 1131.1 | ε 0.987
# Episode   27 | Score  1308 | MaxTile  128 | MA50 1114.1 | ε 0.986
# Episode   28 | Score   712 | MaxTile   64 | MA50 1121.0 | ε 0.986
# Episode   29 | Score  1292 | MaxTile  128 | MA50 1106.9 | ε 0.985
# Episode   30 | Score  1284 | MaxTile  128 | MA50 1113.1 | ε 0.985
# Episode   31 | Score  1320 | MaxTile  128 | MA50 1118.6 | ε 0.984
# Episode   32 | Score   864 | MaxTile   64 | MA50 1124.9 | ε 0.984
# Episode   33 | Score  1344 | MaxTile  128 | MA50 1117.0 | ε 0.983
# Episode   34 | Score   508 | MaxTile   64 | MA50 1123.6 | ε 0.983
# Episode   35 | Score   440 | MaxTile   32 | MA50 1106.1 | ε 0.982
# Episode   36 | Score   656 | MaxTile   64 | MA50 1087.6 | ε 0.982
# Episode   37 | Score  1472 | MaxTile  128 | MA50 1075.9 | ε 0.981
# Episode   38 | Score  1312 | MaxTile  128 | MA50 1086.3 | ε 0.981
# Episode   39 | Score   772 | MaxTile   64 | MA50 1092.1 | ε 0.980
# Episode   40 | Score  1624 | MaxTile  128 | MA50 1084.1 | ε 0.980
# Episode   41 | Score   452 | MaxTile   64 | MA50 1097.3 | ε 0.979
# Episode   42 | Score   592 | MaxTile   64 | MA50 1081.9 | ε 0.979
# Episode   43 | Score  1084 | MaxTile  128 | MA50 1070.5 | ε 0.978
# Episode   44 | Score  1540 | MaxTile  128 | MA50 1070.8 | ε 0.978
# Episode   45 | Score  1236 | MaxTile  128 | MA50 1081.2 | ε 0.977
# Episode   46 | Score  1332 | MaxTile  128 | MA50 1084.6 | ε 0.977
# Episode   47 | Score  1548 | MaxTile  128 | MA50 1089.9 | ε 0.976
# Episode   48 | Score  1532 | MaxTile  128 | MA50 1099.4 | ε 0.976
# Episode   49 | Score  1368 | MaxTile  128 | MA50 1108.2 | ε 0.975
# Episode   50 | Score  1148 | MaxTile  128 | MA50 1113.4 | ε 0.975
# Episode   51 | Score  2072 | MaxTile  256 | MA50 1125.8 | ε 0.974
# Episode   52 | Score   728 | MaxTile   64 | MA50 1159.1 | ε 0.974
# Episode   53 | Score   596 | MaxTile   64 | MA50 1152.6 | ε 0.973
# Episode   54 | Score  1524 | MaxTile  128 | MA50 1138.3 | ε 0.973
# Episode   55 | Score   440 | MaxTile   64 | MA50 1149.3 | ε 0.972
# Episode   56 | Score   760 | MaxTile   64 | MA50 1120.0 | ε 0.972
# Episode   57 | Score  1296 | MaxTile  128 | MA50 1109.0 | ε 0.971
# Episode   58 | Score  1512 | MaxTile  128 | MA50 1112.1 | ε 0.971
# Episode   59 | Score  1356 | MaxTile  128 | MA50 1131.6 | ε 0.970
# Episode   60 | Score   572 | MaxTile   64 | MA50 1145.7 | ε 0.970
# Episode   61 | Score   868 | MaxTile   64 | MA50 1144.2 | ε 0.969
# Episode   62 | Score   832 | MaxTile   64 | MA50 1133.3 | ε 0.969
# Episode   63 | Score  1048 | MaxTile  128 | MA50 1120.7 | ε 0.968
# Episode   64 | Score  1944 | MaxTile  256 | MA50 1128.1 | ε 0.968
# Episode   65 | Score  1968 | MaxTile  256 | MA50 1153.6 | ε 0.968
# Episode   66 | Score  1492 | MaxTile  128 | MA50 1128.2 | ε 0.967
# Episode   67 | Score   860 | MaxTile   64 | MA50 1144.5 | ε 0.967
# Episode   68 | Score  1372 | MaxTile  128 | MA50 1136.1 | ε 0.966
# Episode   69 | Score   952 | MaxTile   64 | MA50 1145.9 | ε 0.966
# Episode   70 | Score  1576 | MaxTile  128 | MA50 1143.5 | ε 0.965
# Episode   71 | Score   800 | MaxTile   64 | MA50 1134.5 | ε 0.965
# Episode   72 | Score  1176 | MaxTile  128 | MA50 1132.6 | ε 0.964
# Episode   73 | Score  2092 | MaxTile  128 | MA50 1115.4 | ε 0.964
# Episode   74 | Score  1672 | MaxTile  128 | MA50 1130.8 | ε 0.963
# Episode   75 | Score  1192 | MaxTile  128 | MA50 1151.5 | ε 0.963
# Episode   76 | Score   664 | MaxTile   64 | MA50 1162.2 | ε 0.962
# Episode   77 | Score   728 | MaxTile   64 | MA50 1162.1 | ε 0.962
# Episode   78 | Score  1116 | MaxTile  128 | MA50 1150.5 | ε 0.961
# Episode   79 | Score  1788 | MaxTile  256 | MA50 1158.6 | ε 0.961
# Episode   80 | Score   400 | MaxTile   32 | MA50 1168.5 | ε 0.960
# Episode   81 | Score  1412 | MaxTile  128 | MA50 1150.8 | ε 0.960
# Episode   82 | Score  1052 | MaxTile   64 | MA50 1152.6 | ε 0.959
# Episode   83 | Score  1232 | MaxTile  128 | MA50 1156.4 | ε 0.959
# Episode   84 | Score  1176 | MaxTile  128 | MA50 1154.2 | ε 0.958
# Episode   85 | Score  1036 | MaxTile  128 | MA50 1167.5 | ε 0.958
# Episode   86 | Score   724 | MaxTile   64 | MA50 1179.4 | ε 0.957
# Episode   87 | Score  1184 | MaxTile  128 | MA50 1180.8 | ε 0.957
# Episode   88 | Score  1288 | MaxTile  128 | MA50 1175.0 | ε 0.956
# Episode   89 | Score  2800 | MaxTile  256 | MA50 1174.6 | ε 0.956
# Episode   90 | Score  1980 | MaxTile  256 | MA50 1215.1 | ε 0.956
# Episode   91 | Score  1624 | MaxTile  128 | MA50 1222.2 | ε 0.955
# Episode   92 | Score  1492 | MaxTile  128 | MA50 1245.7 | ε 0.955
# Episode   93 | Score   780 | MaxTile   64 | MA50 1263.7 | ε 0.954
# Episode   94 | Score   936 | MaxTile   64 | MA50 1257.6 | ε 0.954
# Episode   95 | Score  1416 | MaxTile  128 | MA50 1245.5 | ε 0.953
# Episode   96 | Score  1052 | MaxTile  128 | MA50 1249.1 | ε 0.953
# Episode   97 | Score  1476 | MaxTile  128 | MA50 1243.5 | ε 0.952
# Episode   98 | Score  1336 | MaxTile  128 | MA50 1242.1 | ε 0.952
# Episode   99 | Score  1152 | MaxTile  128 | MA50 1238.2 | ε 0.951
# Episode  100 | Score  1372 | MaxTile  128 | MA50 1233.8 | ε 0.951
#   → Eval @ ep 100: Avg 983.4, Max 2484
#      Tile p25/p50/p75: 64.0/128.0/128.0
#      Tiles hist: {16: 4, 32: 12, 64: 33, 128: 45, 256: 6}
# Episode  101 | Score  1304 | MaxTile  128 | MA50 1238.3 | ε 0.950
# Episode  102 | Score   588 | MaxTile   64 | MA50 1223.0 | ε 0.950
# Episode  103 | Score   264 | MaxTile   32 | MA50 1220.2 | ε 0.949
# Episode  104 | Score  2736 | MaxTile  256 | MA50 1213.5 | ε 0.949
# Episode  105 | Score  1340 | MaxTile  128 | MA50 1237.8 | ε 0.948
# Episode  106 | Score  1400 | MaxTile  128 | MA50 1255.8 | ε 0.948
# Episode  107 | Score   880 | MaxTile   64 | MA50 1268.6 | ε 0.947
# Episode  108 | Score  1416 | MaxTile  128 | MA50 1260.2 | ε 0.947
# Episode  109 | Score   720 | MaxTile   64 | MA50 1258.3 | ε 0.946
# Episode  110 | Score  1592 | MaxTile  128 | MA50 1245.6 | ε 0.946
# Episode  111 | Score   748 | MaxTile   64 | MA50 1266.0 | ε 0.946
# Episode  112 | Score  1456 | MaxTile  128 | MA50 1263.6 | ε 0.945
# Episode  113 | Score   272 | MaxTile   32 | MA50 1276.1 | ε 0.945
# Episode  114 | Score   600 | MaxTile   64 | MA50 1260.6 | ε 0.944
# Episode  115 | Score   908 | MaxTile   64 | MA50 1233.7 | ε 0.944
# Episode  116 | Score   644 | MaxTile   64 | MA50 1212.5 | ε 0.943
# Episode  117 | Score  1364 | MaxTile  128 | MA50 1195.5 | ε 0.943
# Episode  118 | Score   668 | MaxTile   64 | MA50 1205.6 | ε 0.942
# Episode  119 | Score   736 | MaxTile   64 | MA50 1191.5 | ε 0.942
# Episode  120 | Score  1148 | MaxTile  128 | MA50 1187.2 | ε 0.941
# Episode  121 | Score   616 | MaxTile   64 | MA50 1178.6 | ε 0.941
# Episode  122 | Score  1896 | MaxTile  256 | MA50 1175.0 | ε 0.940
# Episode  123 | Score   692 | MaxTile   64 | MA50 1189.4 | ε 0.940
# Episode  124 | Score  1512 | MaxTile  128 | MA50 1161.4 | ε 0.939
# Episode  125 | Score   636 | MaxTile   64 | MA50 1158.2 | ε 0.939
# Episode  126 | Score   900 | MaxTile   64 | MA50 1147.0 | ε 0.938
# Episode  127 | Score  2224 | MaxTile  256 | MA50 1151.8 | ε 0.938
# Episode  128 | Score   760 | MaxTile   64 | MA50 1181.7 | ε 0.938
# Episode  129 | Score   340 | MaxTile   32 | MA50 1174.6 | ε 0.937
# Episode  130 | Score  1564 | MaxTile  128 | MA50 1145.6 | ε 0.937
# Episode  131 | Score  1576 | MaxTile  128 | MA50 1168.9 | ε 0.936
# Episode  132 | Score  1600 | MaxTile  128 | MA50 1172.2 | ε 0.936
# Episode  133 | Score   744 | MaxTile   64 | MA50 1183.1 | ε 0.935
# Episode  134 | Score   740 | MaxTile   64 | MA50 1173.4 | ε 0.935
# Episode  135 | Score  1684 | MaxTile  256 | MA50 1164.6 | ε 0.934
# Episode  136 | Score   880 | MaxTile   64 | MA50 1177.6 | ε 0.934
# Episode  137 | Score  1084 | MaxTile  128 | MA50 1180.7 | ε 0.933
# Episode  138 | Score   940 | MaxTile  128 | MA50 1178.7 | ε 0.933
# Episode  139 | Score   940 | MaxTile   64 | MA50 1171.8 | ε 0.932
# Episode  140 | Score   532 | MaxTile   64 | MA50 1134.6 | ε 0.932
# Episode  141 | Score  1452 | MaxTile  128 | MA50 1105.6 | ε 0.931
# Episode  142 | Score  1312 | MaxTile  128 | MA50 1102.2 | ε 0.931
# Episode  143 | Score  1020 | MaxTile  128 | MA50 1098.6 | ε 0.931
# Episode  144 | Score   796 | MaxTile   64 | MA50 1103.4 | ε 0.930
# Episode  145 | Score   396 | MaxTile   32 | MA50 1100.6 | ε 0.930
# Episode  146 | Score   928 | MaxTile   64 | MA50 1080.2 | ε 0.929
# Episode  147 | Score  1292 | MaxTile  128 | MA50 1077.7 | ε 0.929
# Episode  148 | Score   784 | MaxTile   64 | MA50 1074.0 | ε 0.928
# Episode  149 | Score  1028 | MaxTile  128 | MA50 1063.0 | ε 0.928
# Episode  150 | Score  1088 | MaxTile  128 | MA50 1060.5 | ε 0.927
# Episode  151 | Score   616 | MaxTile   64 | MA50 1054.8 | ε 0.927
# Episode  152 | Score  2476 | MaxTile  256 | MA50 1041.0 | ε 0.926
# Episode  153 | Score  1180 | MaxTile  128 | MA50 1078.8 | ε 0.926
# Episode  154 | Score   580 | MaxTile   64 | MA50 1097.1 | ε 0.925
# Episode  155 | Score   388 | MaxTile   32 | MA50 1054.0 | ε 0.925
# Episode  156 | Score  1276 | MaxTile  128 | MA50 1035.0 | ε 0.924
# Episode  157 | Score  1284 | MaxTile  128 | MA50 1032.5 | ε 0.924
# Episode  158 | Score  1320 | MaxTile  128 | MA50 1040.6 | ε 0.924
# Episode  159 | Score  1284 | MaxTile  128 | MA50 1038.6 | ε 0.923
# Episode  160 | Score   628 | MaxTile   64 | MA50 1049.9 | ε 0.923
# Episode  161 | Score   620 | MaxTile   64 | MA50 1030.6 | ε 0.922
# Episode  162 | Score   896 | MaxTile  128 | MA50 1028.1 | ε 0.922
# Episode  163 | Score  1296 | MaxTile  128 | MA50 1016.9 | ε 0.921
# Episode  164 | Score  1304 | MaxTile  128 | MA50 1037.4 | ε 0.921
# Episode  165 | Score  2172 | MaxTile  256 | MA50 1051.4 | ε 0.920
# Episode  166 | Score  1368 | MaxTile  128 | MA50 1076.7 | ε 0.920
# Episode  167 | Score  1568 | MaxTile  128 | MA50 1091.2 | ε 0.919
# Episode  168 | Score  1484 | MaxTile  128 | MA50 1095.3 | ε 0.919
# Episode  169 | Score   612 | MaxTile   64 | MA50 1111.6 | ε 0.918
# Episode  170 | Score  1664 | MaxTile  128 | MA50 1109.1 | ε 0.918
# Episode  171 | Score  1220 | MaxTile  128 | MA50 1119.4 | ε 0.918
# Episode  172 | Score  1036 | MaxTile  128 | MA50 1131.5 | ε 0.917
# Episode  173 | Score   804 | MaxTile   64 | MA50 1114.3 | ε 0.917
# Episode  174 | Score  1360 | MaxTile  128 | MA50 1116.6 | ε 0.916
# Episode  175 | Score   924 | MaxTile   64 | MA50 1113.5 | ε 0.916
# Episode  176 | Score   440 | MaxTile   32 | MA50 1119.3 | ε 0.915
# Episode  177 | Score  1632 | MaxTile  128 | MA50 1110.1 | ε 0.915
# Episode  178 | Score   376 | MaxTile   32 | MA50 1098.2 | ε 0.914
# Episode  179 | Score   668 | MaxTile   64 | MA50 1090.6 | ε 0.914
# Episode  180 | Score  1540 | MaxTile  128 | MA50 1097.1 | ε 0.913
# Episode  181 | Score  1340 | MaxTile  128 | MA50 1096.6 | ε 0.913
# Episode  182 | Score  1336 | MaxTile  128 | MA50 1091.9 | ε 0.913
# Episode  183 | Score  1304 | MaxTile  128 | MA50 1086.6 | ε 0.912
# Episode  184 | Score  2220 | MaxTile  256 | MA50 1097.8 | ε 0.912
# Episode  185 | Score  1020 | MaxTile  128 | MA50 1127.4 | ε 0.911
# Episode  186 | Score   752 | MaxTile   64 | MA50 1114.2 | ε 0.911
# Episode  187 | Score   572 | MaxTile   64 | MA50 1111.6 | ε 0.910
# Episode  188 | Score  1352 | MaxTile  128 | MA50 1101.4 | ε 0.910
# Episode  189 | Score  1344 | MaxTile  128 | MA50 1109.6 | ε 0.909
# Episode  190 | Score   916 | MaxTile  128 | MA50 1117.7 | ε 0.909
# Episode  191 | Score   420 | MaxTile   32 | MA50 1125.4 | ε 0.908
# Episode  192 | Score   872 | MaxTile   64 | MA50 1104.7 | ε 0.908
# Episode  193 | Score  1228 | MaxTile  128 | MA50 1095.9 | ε 0.908
# Episode  194 | Score  1160 | MaxTile  128 | MA50 1100.1 | ε 0.907
# Episode  195 | Score   508 | MaxTile   64 | MA50 1107.4 | ε 0.907
# Episode  196 | Score   568 | MaxTile   64 | MA50 1109.6 | ε 0.906
# Episode  197 | Score  2072 | MaxTile  256 | MA50 1102.4 | ε 0.906
# Episode  198 | Score  1500 | MaxTile  128 | MA50 1118.0 | ε 0.905
# Episode  199 | Score  1432 | MaxTile  128 | MA50 1132.3 | ε 0.905
# Episode  200 | Score  1380 | MaxTile  128 | MA50 1140.4 | ε 0.904
#   → Eval @ ep 200: Avg 1039.0, Max 2176
#      Tile p25/p50/p75: 64.0/128.0/128.0
#      Tiles hist: {32: 10, 64: 39, 128: 50, 256: 1}
# Episode  201 | Score   804 | MaxTile   64 | MA50 1146.2 | ε 0.904
# Episode  202 | Score   712 | MaxTile   64 | MA50 1150.0 | ε 0.903
# Episode  203 | Score  1416 | MaxTile  128 | MA50 1114.7 | ε 0.903
# Episode  204 | Score  1176 | MaxTile  128 | MA50 1119.4 | ε 0.903
# Episode  205 | Score   592 | MaxTile   64 | MA50 1131.4 | ε 0.902
# Episode  206 | Score   996 | MaxTile  128 | MA50 1135.4 | ε 0.902
# Episode  207 | Score  1056 | MaxTile  128 | MA50 1129.8 | ε 0.901
# Episode  208 | Score   676 | MaxTile   64 | MA50 1125.3 | ε 0.901
# Episode  209 | Score  1372 | MaxTile  128 | MA50 1112.4 | ε 0.900
# Episode  210 | Score   620 | MaxTile   64 | MA50 1114.2 | ε 0.900
# Episode  211 | Score  1328 | MaxTile  128 | MA50 1114.0 | ε 0.899
# Episode  212 | Score  1124 | MaxTile  128 | MA50 1128.2 | ε 0.899
# Episode  213 | Score  1188 | MaxTile  128 | MA50 1132.7 | ε 0.899
# Episode  214 | Score   588 | MaxTile   64 | MA50 1130.6 | ε 0.898
# Episode  215 | Score   988 | MaxTile  128 | MA50 1116.2 | ε 0.898
# Episode  216 | Score   640 | MaxTile   64 | MA50 1092.6 | ε 0.897
# Episode  217 | Score  1340 | MaxTile  128 | MA50 1078.0 | ε 0.897
# Episode  218 | Score  2108 | MaxTile  128 | MA50 1073.4 | ε 0.896
# Episode  219 | Score  1232 | MaxTile  128 | MA50 1085.9 | ε 0.896
# Episode  220 | Score  1252 | MaxTile  128 | MA50 1098.3 | ε 0.895
# Episode  221 | Score   332 | MaxTile   32 | MA50 1090.1 | ε 0.895
# Episode  222 | Score   932 | MaxTile   64 | MA50 1072.3 | ε 0.894
# Episode  223 | Score   548 | MaxTile   64 | MA50 1070.2 | ε 0.894
# Episode  224 | Score   400 | MaxTile   32 | MA50 1065.1 | ε 0.894
# Episode  225 | Score   520 | MaxTile   64 | MA50 1045.9 | ε 0.893
# Episode  226 | Score   496 | MaxTile   32 | MA50 1037.8 | ε 0.893
# Episode  227 | Score  1616 | MaxTile  128 | MA50 1039.0 | ε 0.892
# Episode  228 | Score  1644 | MaxTile  128 | MA50 1038.6 | ε 0.892
# Episode  229 | Score   716 | MaxTile   64 | MA50 1064.0 | ε 0.891
# Episode  230 | Score  1240 | MaxTile  128 | MA50 1065.0 | ε 0.891
# Episode  231 | Score   300 | MaxTile   32 | MA50 1059.0 | ε 0.890
# Episode  232 | Score   696 | MaxTile   64 | MA50 1038.2 | ε 0.890
# Episode  233 | Score   636 | MaxTile   64 | MA50 1025.4 | ε 0.890
# Episode  234 | Score  1428 | MaxTile  128 | MA50 1012.0 | ε 0.889
# Episode  235 | Score  1380 | MaxTile  128 | MA50  996.2 | ε 0.889
# Episode  236 | Score  1440 | MaxTile  128 | MA50 1003.4 | ε 0.888
# Episode  237 | Score  1360 | MaxTile  128 | MA50 1017.1 | ε 0.888
# Episode  238 | Score  1444 | MaxTile  128 | MA50 1032.9 | ε 0.887
# Episode  239 | Score   692 | MaxTile   64 | MA50 1034.7 | ε 0.887
# Episode  240 | Score  2136 | MaxTile  256 | MA50 1021.7 | ε 0.886
# Episode  241 | Score   508 | MaxTile   32 | MA50 1046.1 | ε 0.886
# Episode  242 | Score  1336 | MaxTile  128 | MA50 1047.8 | ε 0.886
# Episode  243 | Score   456 | MaxTile   64 | MA50 1057.1 | ε 0.885
# Episode  244 | Score  1044 | MaxTile  128 | MA50 1041.7 | ε 0.885
# Episode  245 | Score  1532 | MaxTile  128 | MA50 1039.4 | ε 0.884
# Episode  246 | Score  1548 | MaxTile  128 | MA50 1059.8 | ε 0.884
# Episode  247 | Score   616 | MaxTile   64 | MA50 1079.4 | ε 0.883
# Episode  248 | Score   404 | MaxTile   32 | MA50 1050.3 | ε 0.883
# Episode  249 | Score   648 | MaxTile   64 | MA50 1028.4 | ε 0.882
# Episode  250 | Score  1160 | MaxTile  128 | MA50 1012.7 | ε 0.882
# Episode  251 | Score  1296 | MaxTile  128 | MA50 1008.3 | ε 0.882
# Episode  252 | Score  1084 | MaxTile  128 | MA50 1018.2 | ε 0.881
# Episode  253 | Score   480 | MaxTile   64 | MA50 1025.6 | ε 0.881
# Episode  254 | Score   820 | MaxTile   64 | MA50 1006.9 | ε 0.880
# Episode  255 | Score   896 | MaxTile  128 | MA50  999.8 | ε 0.880
# Episode  256 | Score  1288 | MaxTile  128 | MA50 1005.8 | ε 0.879
# Episode  257 | Score  1292 | MaxTile  128 | MA50 1011.7 | ε 0.879
# Episode  258 | Score   772 | MaxTile   64 | MA50 1016.4 | ε 0.879
# Episode  259 | Score   684 | MaxTile   64 | MA50 1018.3 | ε 0.878
# Episode  260 | Score   676 | MaxTile   64 | MA50 1004.6 | ε 0.878
# Episode  261 | Score  1376 | MaxTile  128 | MA50 1005.7 | ε 0.877
# Episode  262 | Score   812 | MaxTile   64 | MA50 1006.6 | ε 0.877
# Episode  263 | Score  1172 | MaxTile  128 | MA50 1000.4 | ε 0.876
# Episode  264 | Score   572 | MaxTile   64 | MA50 1000.1 | ε 0.876
# Episode  265 | Score  1584 | MaxTile  128 | MA50  999.8 | ε 0.875
# Episode  266 | Score   624 | MaxTile   64 | MA50 1011.7 | ε 0.875
# Episode  267 | Score   288 | MaxTile   32 | MA50 1011.4 | ε 0.875
# Episode  268 | Score   364 | MaxTile   32 | MA50  990.3 | ε 0.874
# Episode  269 | Score   424 | MaxTile   32 | MA50  955.4 | ε 0.874
# Episode  270 | Score  1904 | MaxTile  256 | MA50  939.3 | ε 0.873
# Episode  271 | Score  1500 | MaxTile  128 | MA50  952.3 | ε 0.873
# Episode  272 | Score   436 | MaxTile   32 | MA50  975.7 | ε 0.872
# Episode  273 | Score   644 | MaxTile   64 | MA50  965.8 | ε 0.872
# Episode  274 | Score  2016 | MaxTile  256 | MA50  967.7 | ε 0.872
# Episode  275 | Score   664 | MaxTile   64 | MA50 1000.0 | ε 0.871
# Episode  276 | Score  1496 | MaxTile  128 | MA50 1002.9 | ε 0.871
# Episode  277 | Score   532 | MaxTile   64 | MA50 1022.9 | ε 0.870
# Episode  278 | Score  1588 | MaxTile  128 | MA50 1001.2 | ε 0.870
# Episode  279 | Score  1404 | MaxTile  128 | MA50 1000.1 | ε 0.869
# Episode  280 | Score   348 | MaxTile   32 | MA50 1013.8 | ε 0.869
# Episode  281 | Score  1900 | MaxTile  256 | MA50  996.0 | ε 0.868
# Episode  282 | Score   720 | MaxTile   64 | MA50 1028.0 | ε 0.868
# Episode  283 | Score   636 | MaxTile   64 | MA50 1028.5 | ε 0.868
# Episode  284 | Score  1460 | MaxTile  128 | MA50 1028.5 | ε 0.867
# Episode  285 | Score  1556 | MaxTile  128 | MA50 1029.1 | ε 0.867
# Episode  286 | Score  1032 | MaxTile  128 | MA50 1032.6 | ε 0.866
# Episode  287 | Score  1360 | MaxTile  128 | MA50 1024.5 | ε 0.866
# Episode  288 | Score  1416 | MaxTile  128 | MA50 1024.5 | ε 0.865
# Episode  289 | Score   924 | MaxTile   64 | MA50 1023.9 | ε 0.865
# Episode  290 | Score  1676 | MaxTile  256 | MA50 1028.6 | ε 0.865
# Episode  291 | Score  1232 | MaxTile  128 | MA50 1019.4 | ε 0.864
# Episode  292 | Score  1480 | MaxTile  128 | MA50 1033.8 | ε 0.864
# Episode  293 | Score  1516 | MaxTile  128 | MA50 1036.7 | ε 0.863
# Episode  294 | Score  1344 | MaxTile  128 | MA50 1057.9 | ε 0.863
# Episode  295 | Score   516 | MaxTile   64 | MA50 1063.9 | ε 0.862
# Episode  296 | Score   920 | MaxTile  128 | MA50 1043.6 | ε 0.862
# Episode  297 | Score  1000 | MaxTile  128 | MA50 1031.0 | ε 0.862
# Episode  298 | Score   796 | MaxTile   64 | MA50 1038.7 | ε 0.861
# Episode  299 | Score   640 | MaxTile   64 | MA50 1046.6 | ε 0.861
# Episode  300 | Score   448 | MaxTile   64 | MA50 1046.4 | ε 0.860
#   → Eval @ ep 300: Avg 1041.8, Max 2920
#      Tile p25/p50/p75: 64.0/64.0/128.0
#      Tiles hist: {32: 7, 64: 47, 128: 40, 256: 6}
# Episode  301 | Score  1596 | MaxTile  128 | MA50 1032.2 | ε 0.860
# Episode  302 | Score   800 | MaxTile   64 | MA50 1038.2 | ε 0.859
# Episode  303 | Score   664 | MaxTile   64 | MA50 1032.5 | ε 0.859
# Episode  304 | Score   516 | MaxTile   64 | MA50 1036.2 | ε 0.859
# Episode  305 | Score   572 | MaxTile   64 | MA50 1030.1 | ε 0.858
# Episode  306 | Score  2516 | MaxTile  256 | MA50 1023.6 | ε 0.858
# Episode  307 | Score   600 | MaxTile   64 | MA50 1048.2 | ε 0.857
# Episode  308 | Score   804 | MaxTile   64 | MA50 1034.3 | ε 0.857
# Episode  309 | Score  1320 | MaxTile  128 | MA50 1035.0 | ε 0.856
# Episode  310 | Score   688 | MaxTile   64 | MA50 1047.7 | ε 0.856
# Episode  311 | Score  1136 | MaxTile  128 | MA50 1047.9 | ε 0.856
# Episode  312 | Score   968 | MaxTile  128 | MA50 1043.1 | ε 0.855
# Episode  313 | Score  1096 | MaxTile  128 | MA50 1046.2 | ε 0.855
# Episode  314 | Score   296 | MaxTile   32 | MA50 1044.7 | ε 0.854
# Episode  315 | Score   324 | MaxTile   32 | MA50 1039.2 | ε 0.854
# Episode  316 | Score   724 | MaxTile   64 | MA50 1014.0 | ε 0.853
# Episode  317 | Score   420 | MaxTile   64 | MA50 1016.0 | ε 0.853
# Episode  318 | Score  1428 | MaxTile  128 | MA50 1018.6 | ε 0.853
# Episode  319 | Score   984 | MaxTile  128 | MA50 1039.9 | ε 0.852
# Episode  320 | Score   656 | MaxTile   64 | MA50 1051.1 | ε 0.852
# Episode  321 | Score   976 | MaxTile   64 | MA50 1026.2 | ε 0.851
# Episode  322 | Score  1712 | MaxTile  128 | MA50 1015.7 | ε 0.851
# Episode  323 | Score   788 | MaxTile   64 | MA50 1041.2 | ε 0.850
# Episode  324 | Score   584 | MaxTile   64 | MA50 1044.1 | ε 0.850
# Episode  325 | Score   636 | MaxTile   64 | MA50 1015.4 | ε 0.850
# Episode  326 | Score   452 | MaxTile   32 | MA50 1014.9 | ε 0.849
# Episode  327 | Score   804 | MaxTile   64 | MA50  994.0 | ε 0.849
# Episode  328 | Score  1068 | MaxTile  128 | MA50  999.4 | ε 0.848
# Episode  329 | Score  1324 | MaxTile  128 | MA50  989.0 | ε 0.848
# Episode  330 | Score  1608 | MaxTile  128 | MA50  987.4 | ε 0.847
# Episode  331 | Score  1264 | MaxTile  128 | MA50 1012.6 | ε 0.847
# Episode  332 | Score   600 | MaxTile   64 | MA50  999.9 | ε 0.847
# Episode  333 | Score  1272 | MaxTile  128 | MA50  997.5 | ε 0.846
# Episode  334 | Score   792 | MaxTile   64 | MA50 1010.2 | ε 0.846
# Episode  335 | Score  1384 | MaxTile  128 | MA50  996.9 | ε 0.845
# Episode  336 | Score  2168 | MaxTile  256 | MA50  993.4 | ε 0.845
# Episode  337 | Score   612 | MaxTile   64 | MA50 1016.2 | ε 0.844
# Episode  338 | Score   592 | MaxTile   64 | MA50 1001.2 | ε 0.844
# Episode  339 | Score  1360 | MaxTile  128 | MA50  984.7 | ε 0.844
# Episode  340 | Score  1024 | MaxTile  128 | MA50  993.4 | ε 0.843
# Episode  341 | Score   768 | MaxTile   64 | MA50  980.4 | ε 0.843
# Episode  342 | Score   904 | MaxTile   64 | MA50  971.1 | ε 0.842
# Episode  343 | Score  2488 | MaxTile  256 | MA50  959.6 | ε 0.842
# Episode  344 | Score  1332 | MaxTile  128 | MA50  979.0 | ε 0.842
# Episode  345 | Score   512 | MaxTile   64 | MA50  978.8 | ε 0.841
# Episode  346 | Score  1348 | MaxTile  128 | MA50  978.7 | ε 0.841
# Episode  347 | Score  1232 | MaxTile  128 | MA50  987.3 | ε 0.840
# Episode  348 | Score   548 | MaxTile   64 | MA50  991.9 | ε 0.840
# Episode  349 | Score  1448 | MaxTile  128 | MA50  987.0 | ε 0.839
# Episode  350 | Score  1520 | MaxTile  128 | MA50 1003.1 | ε 0.839
# Episode  351 | Score  1036 | MaxTile  128 | MA50 1024.6 | ε 0.839
# Episode  352 | Score  1904 | MaxTile  256 | MA50 1013.4 | ε 0.838
# Episode  353 | Score  1204 | MaxTile  128 | MA50 1035.4 | ε 0.838
# Episode  354 | Score  1316 | MaxTile  128 | MA50 1046.2 | ε 0.837
# Episode  355 | Score   988 | MaxTile  128 | MA50 1062.2 | ε 0.837
# Episode  356 | Score  2440 | MaxTile  256 | MA50 1070.6 | ε 0.836
# Episode  357 | Score   640 | MaxTile   64 | MA50 1069.0 | ε 0.836
# Episode  358 | Score   968 | MaxTile  128 | MA50 1069.8 | ε 0.836
# Episode  359 | Score  1372 | MaxTile  128 | MA50 1073.1 | ε 0.835
# Episode  360 | Score   664 | MaxTile   64 | MA50 1074.2 | ε 0.835
# Episode  361 | Score   740 | MaxTile   64 | MA50 1073.7 | ε 0.834
# Episode  362 | Score   524 | MaxTile   64 | MA50 1065.8 | ε 0.834
# Episode  363 | Score   780 | MaxTile   64 | MA50 1056.9 | ε 0.834
# Episode  364 | Score   440 | MaxTile   32 | MA50 1050.6 | ε 0.833
# Episode  365 | Score  1348 | MaxTile  128 | MA50 1053.4 | ε 0.833
# Episode  366 | Score  1052 | MaxTile  128 | MA50 1073.9 | ε 0.832
# Episode  367 | Score  1360 | MaxTile  128 | MA50 1080.5 | ε 0.832
# Episode  368 | Score   540 | MaxTile   64 | MA50 1099.3 | ε 0.831
# Episode  369 | Score  1264 | MaxTile  128 | MA50 1081.5 | ε 0.831
# Episode  370 | Score  1296 | MaxTile  128 | MA50 1087.1 | ε 0.831
# Episode  371 | Score  1268 | MaxTile  128 | MA50 1099.9 | ε 0.830
# Episode  372 | Score   440 | MaxTile   32 | MA50 1105.8 | ε 0.830
# Episode  373 | Score   712 | MaxTile   64 | MA50 1080.3 | ε 0.829
# Episode  374 | Score   924 | MaxTile   64 | MA50 1078.8 | ε 0.829
# Episode  375 | Score  1280 | MaxTile  128 | MA50 1085.6 | ε 0.829
# Episode  376 | Score   900 | MaxTile  128 | MA50 1098.5 | ε 0.828
# Episode  377 | Score  1020 | MaxTile   64 | MA50 1107.4 | ε 0.828
# Episode  378 | Score  1308 | MaxTile  128 | MA50 1111.8 | ε 0.827
# Episode  379 | Score   760 | MaxTile   64 | MA50 1116.6 | ε 0.827
# Episode  380 | Score   704 | MaxTile   64 | MA50 1105.3 | ε 0.827
# Episode  381 | Score   680 | MaxTile   64 | MA50 1087.2 | ε 0.826
# Episode  382 | Score  1264 | MaxTile  128 | MA50 1075.5 | ε 0.826
# Episode  383 | Score   688 | MaxTile   64 | MA50 1088.8 | ε 0.825
# Episode  384 | Score  1428 | MaxTile  128 | MA50 1077.1 | ε 0.825
# Episode  385 | Score   628 | MaxTile   64 | MA50 1089.8 | ε 0.824
# Episode  386 | Score  1204 | MaxTile  128 | MA50 1074.7 | ε 0.824
# Episode  387 | Score  1092 | MaxTile  128 | MA50 1055.4 | ε 0.824
# Episode  388 | Score   656 | MaxTile   64 | MA50 1065.0 | ε 0.823
# Episode  389 | Score   564 | MaxTile   64 | MA50 1066.3 | ε 0.823
# Episode  390 | Score   552 | MaxTile   64 | MA50 1050.4 | ε 0.822
# Episode  391 | Score   692 | MaxTile   64 | MA50 1041.0 | ε 0.822
# Episode  392 | Score  1300 | MaxTile  128 | MA50 1039.4 | ε 0.822
# Episode  393 | Score  2292 | MaxTile  256 | MA50 1047.4 | ε 0.821
# Episode  394 | Score  1456 | MaxTile  128 | MA50 1043.4 | ε 0.821
# Episode  395 | Score  1096 | MaxTile  128 | MA50 1045.9 | ε 0.820
# Episode  396 | Score  1500 | MaxTile  128 | MA50 1057.6 | ε 0.820
# Episode  397 | Score  1176 | MaxTile  128 | MA50 1060.6 | ε 0.820
# Episode  398 | Score  1392 | MaxTile  128 | MA50 1059.5 | ε 0.819
# Episode  399 | Score   776 | MaxTile   64 | MA50 1076.4 | ε 0.819
# Episode  400 | Score   948 | MaxTile   64 | MA50 1063.0 | ε 0.818
#   → Eval @ ep 400: Avg 1055.4, Max 2580
#      Tile p25/p50/p75: 64.0/64.0/128.0
#      Tiles hist: {32: 6, 64: 46, 128: 44, 256: 4}
# Episode  401 | Score  1148 | MaxTile  128 | MA50 1051.5 | ε 0.818
# Episode  402 | Score  1156 | MaxTile  128 | MA50 1053.8 | ε 0.817
# Episode  403 | Score  1304 | MaxTile  128 | MA50 1038.8 | ε 0.817
# Episode  404 | Score   368 | MaxTile   32 | MA50 1040.8 | ε 0.817
# Episode  405 | Score   528 | MaxTile   64 | MA50 1021.8 | ε 0.816
# Episode  406 | Score   496 | MaxTile   64 | MA50 1012.6 | ε 0.816
# Episode  407 | Score  1184 | MaxTile  128 | MA50  973.8 | ε 0.815
# Episode  408 | Score   760 | MaxTile   64 | MA50  984.6 | ε 0.815
# Episode  409 | Score   808 | MaxTile   64 | MA50  980.5 | ε 0.815
# Episode  410 | Score   448 | MaxTile   64 | MA50  969.2 | ε 0.814
# Episode  411 | Score  1368 | MaxTile  128 | MA50  964.9 | ε 0.814
# Episode  412 | Score   592 | MaxTile   64 | MA50  977.4 | ε 0.813
# Episode  413 | Score  1380 | MaxTile  128 | MA50  978.8 | ε 0.813
# Episode  414 | Score  2108 | MaxTile  256 | MA50  990.8 | ε 0.813
# Episode  415 | Score  1084 | MaxTile  128 | MA50 1024.2 | ε 0.812
# Episode  416 | Score  1756 | MaxTile  128 | MA50 1018.9 | ε 0.812
# Episode  417 | Score  1308 | MaxTile  128 | MA50 1033.0 | ε 0.811
# Episode  418 | Score   652 | MaxTile   64 | MA50 1031.9 | ε 0.811
# Episode  419 | Score  1612 | MaxTile  128 | MA50 1034.2 | ε 0.811
# Episode  420 | Score   664 | MaxTile   64 | MA50 1041.1 | ε 0.810
# Episode  421 | Score  1644 | MaxTile  128 | MA50 1028.5 | ε 0.810
# Episode  422 | Score  1492 | MaxTile  128 | MA50 1036.0 | ε 0.809
# Episode  423 | Score   480 | MaxTile   64 | MA50 1057.0 | ε 0.809
# Episode  424 | Score  1012 | MaxTile   64 | MA50 1052.4 | ε 0.809
# Episode  425 | Score  1060 | MaxTile  128 | MA50 1054.2 | ε 0.808
# Episode  426 | Score   696 | MaxTile   64 | MA50 1049.8 | ε 0.808
# Episode  427 | Score   584 | MaxTile   64 | MA50 1045.7 | ε 0.807
# Episode  428 | Score   408 | MaxTile   32 | MA50 1037.0 | ε 0.807
# Episode  429 | Score   776 | MaxTile   64 | MA50 1019.0 | ε 0.806
# Episode  430 | Score   728 | MaxTile   64 | MA50 1019.3 | ε 0.806
# Episode  431 | Score   556 | MaxTile   64 | MA50 1019.8 | ε 0.806
# Episode  432 | Score  2148 | MaxTile  128 | MA50 1017.3 | ε 0.805
# Episode  433 | Score  1188 | MaxTile  128 | MA50 1035.0 | ε 0.805
# Episode  434 | Score   440 | MaxTile   64 | MA50 1045.0 | ε 0.804
# Episode  435 | Score  1020 | MaxTile  128 | MA50 1025.2 | ε 0.804
# Episode  436 | Score  1324 | MaxTile  128 | MA50 1033.0 | ε 0.804
# Episode  437 | Score   924 | MaxTile   64 | MA50 1035.4 | ε 0.803
# Episode  438 | Score   608 | MaxTile   64 | MA50 1032.1 | ε 0.803
# Episode  439 | Score  1280 | MaxTile  128 | MA50 1031.1 | ε 0.802
# Episode  440 | Score  1944 | MaxTile  256 | MA50 1045.4 | ε 0.802
# Episode  441 | Score  1304 | MaxTile  128 | MA50 1073.3 | ε 0.802
# Episode  442 | Score   588 | MaxTile   64 | MA50 1085.5 | ε 0.801
# Episode  443 | Score  1796 | MaxTile  256 | MA50 1071.3 | ε 0.801
# Episode  444 | Score  1584 | MaxTile  128 | MA50 1061.4 | ε 0.800
# Episode  445 | Score  1672 | MaxTile  128 | MA50 1063.9 | ε 0.800
# Episode  446 | Score  2480 | MaxTile  256 | MA50 1075.4 | ε 0.800
# Episode  447 | Score  1380 | MaxTile  128 | MA50 1095.0 | ε 0.799
# Episode  448 | Score  1484 | MaxTile  128 | MA50 1099.1 | ε 0.799
# Episode  449 | Score  2464 | MaxTile  256 | MA50 1101.0 | ε 0.798
# Episode  450 | Score  1236 | MaxTile  128 | MA50 1134.7 | ε 0.798
# Episode  451 | Score  1388 | MaxTile  128 | MA50 1140.5 | ε 0.798
# Episode  452 | Score  1144 | MaxTile  128 | MA50 1145.3 | ε 0.797
# Episode  453 | Score   572 | MaxTile   64 | MA50 1145.0 | ε 0.797
# Episode  454 | Score  1184 | MaxTile  128 | MA50 1130.4 | ε 0.796
# Episode  455 | Score  1072 | MaxTile  128 | MA50 1146.7 | ε 0.796
# Episode  456 | Score   396 | MaxTile   32 | MA50 1157.6 | ε 0.796
# Episode  457 | Score   348 | MaxTile   32 | MA50 1155.6 | ε 0.795
# Episode  458 | Score  1024 | MaxTile  128 | MA50 1138.9 | ε 0.795
# Episode  459 | Score   680 | MaxTile   64 | MA50 1144.2 | ε 0.794
# Episode  460 | Score  1064 | MaxTile  128 | MA50 1141.6 | ε 0.794
# Episode  461 | Score  1264 | MaxTile  128 | MA50 1153.9 | ε 0.794
# Episode  462 | Score   716 | MaxTile   64 | MA50 1151.8 | ε 0.793
# Episode  463 | Score   796 | MaxTile   64 | MA50 1154.3 | ε 0.793
# Episode  464 | Score  1432 | MaxTile  128 | MA50 1142.6 | ε 0.793
# Episode  465 | Score  1244 | MaxTile  128 | MA50 1129.1 | ε 0.792
# Episode  466 | Score   936 | MaxTile  128 | MA50 1132.3 | ε 0.792
# Episode  467 | Score   892 | MaxTile   64 | MA50 1115.9 | ε 0.791
# Episode  468 | Score   656 | MaxTile   64 | MA50 1107.6 | ε 0.791
# Episode  469 | Score  1192 | MaxTile  128 | MA50 1107.7 | ε 0.791
# Episode  470 | Score  1620 | MaxTile  128 | MA50 1099.3 | ε 0.790
# Episode  471 | Score  1440 | MaxTile  128 | MA50 1118.4 | ε 0.790
# Episode  472 | Score  1280 | MaxTile  128 | MA50 1114.3 | ε 0.789
# Episode  473 | Score   604 | MaxTile   64 | MA50 1110.1 | ε 0.789
# Episode  474 | Score  1304 | MaxTile  128 | MA50 1112.6 | ε 0.789
# Episode  475 | Score  2128 | MaxTile  256 | MA50 1118.4 | ε 0.788
# Episode  476 | Score   356 | MaxTile   32 | MA50 1139.8 | ε 0.788
# Episode  477 | Score   968 | MaxTile  128 | MA50 1133.0 | ε 0.787
# Episode  478 | Score  1176 | MaxTile  128 | MA50 1140.6 | ε 0.787
# Episode  479 | Score   520 | MaxTile   32 | MA50 1156.0 | ε 0.787
# Episode  480 | Score   492 | MaxTile   32 | MA50 1150.9 | ε 0.786
# Episode  481 | Score  1004 | MaxTile  128 | MA50 1146.2 | ε 0.786
# Episode  482 | Score  1024 | MaxTile  128 | MA50 1155.1 | ε 0.785
# Episode  483 | Score  1200 | MaxTile  128 | MA50 1132.6 | ε 0.785
# Episode  484 | Score  1400 | MaxTile  128 | MA50 1132.9 | ε 0.785
# Episode  485 | Score   748 | MaxTile   64 | MA50 1152.1 | ε 0.784
# Episode  486 | Score  1396 | MaxTile  128 | MA50 1146.6 | ε 0.784
# Episode  487 | Score  1008 | MaxTile  128 | MA50 1148.1 | ε 0.783
# Episode  488 | Score   732 | MaxTile   64 | MA50 1149.8 | ε 0.783
# Episode  489 | Score  1224 | MaxTile  128 | MA50 1152.2 | ε 0.783
# Episode  490 | Score   704 | MaxTile   64 | MA50 1151.1 | ε 0.782
# Episode  491 | Score  1028 | MaxTile  128 | MA50 1126.3 | ε 0.782
# Episode  492 | Score  1392 | MaxTile  128 | MA50 1120.8 | ε 0.781
# Episode  493 | Score  1124 | MaxTile  128 | MA50 1136.9 | ε 0.781
# Episode  494 | Score  1368 | MaxTile  128 | MA50 1123.4 | ε 0.781
# Episode  495 | Score  1168 | MaxTile  128 | MA50 1119.1 | ε 0.780
# Episode  496 | Score   512 | MaxTile   64 | MA50 1109.0 | ε 0.780
# Episode  497 | Score   744 | MaxTile   64 | MA50 1069.7 | ε 0.780
# Episode  498 | Score   392 | MaxTile   32 | MA50 1057.0 | ε 0.779
# Episode  499 | Score  1276 | MaxTile  128 | MA50 1035.1 | ε 0.779
# Episode  500 | Score  1384 | MaxTile  128 | MA50 1011.4 | ε 0.778
#   → Eval @ ep 500: Avg 1046.4, Max 2472
#      Tile p25/p50/p75: 64.0/96.0/128.0
#      Tiles hist: {32: 12, 64: 38, 128: 44, 256: 6}
# Episode  501 | Score  1772 | MaxTile  128 | MA50 1014.3 | ε 0.778
# Episode  502 | Score   712 | MaxTile   64 | MA50 1022.0 | ε 0.778
# Episode  503 | Score   640 | MaxTile   64 | MA50 1013.4 | ε 0.777
# Episode  504 | Score   572 | MaxTile   64 | MA50 1014.7 | ε 0.777
# Episode  505 | Score   948 | MaxTile  128 | MA50 1002.5 | ε 0.776
# Episode  506 | Score  1256 | MaxTile  128 | MA50 1000.0 | ε 0.776
# Episode  507 | Score  2044 | MaxTile  256 | MA50 1017.2 | ε 0.776
# Episode  508 | Score   488 | MaxTile   64 | MA50 1051.1 | ε 0.775
# Episode  509 | Score  1296 | MaxTile  128 | MA50 1040.4 | ε 0.775
# Episode  510 | Score  1288 | MaxTile  128 | MA50 1052.7 | ε 0.774
# Episode  511 | Score   492 | MaxTile   64 | MA50 1057.2 | ε 0.774
# Episode  512 | Score   996 | MaxTile  128 | MA50 1041.8 | ε 0.774
# Episode  513 | Score  1376 | MaxTile  128 | MA50 1047.4 | ε 0.773
# Episode  514 | Score  1016 | MaxTile  128 | MA50 1059.0 | ε 0.773
# Episode  515 | Score  1364 | MaxTile  128 | MA50 1050.6 | ε 0.773
# Episode  516 | Score  1356 | MaxTile  128 | MA50 1053.0 | ε 0.772
# Episode  517 | Score  1360 | MaxTile  128 | MA50 1061.4 | ε 0.772
# Episode  518 | Score   568 | MaxTile   64 | MA50 1070.8 | ε 0.771
# Episode  519 | Score   300 | MaxTile   32 | MA50 1069.0 | ε 0.771
# Episode  520 | Score   992 | MaxTile   64 | MA50 1051.2 | ε 0.771
# Episode  521 | Score  2520 | MaxTile  256 | MA50 1038.6 | ε 0.770
# Episode  522 | Score   628 | MaxTile   64 | MA50 1060.2 | ε 0.770
# Episode  523 | Score  1212 | MaxTile  128 | MA50 1047.2 | ε 0.769
# Episode  524 | Score   640 | MaxTile   64 | MA50 1059.4 | ε 0.769
# Episode  525 | Score   452 | MaxTile   32 | MA50 1046.1 | ε 0.769
# Episode  526 | Score   816 | MaxTile   64 | MA50 1012.6 | ε 0.768
# Episode  527 | Score  1944 | MaxTile  256 | MA50 1021.8 | ε 0.768
# Episode  528 | Score  1400 | MaxTile  128 | MA50 1041.3 | ε 0.768
# Episode  529 | Score  1364 | MaxTile  128 | MA50 1045.8 | ε 0.767
# Episode  530 | Score   448 | MaxTile   32 | MA50 1062.6 | ε 0.767
# Episode  531 | Score   704 | MaxTile   64 | MA50 1061.8 | ε 0.766
# Episode  532 | Score  1328 | MaxTile  128 | MA50 1055.8 | ε 0.766
# Episode  533 | Score   636 | MaxTile   64 | MA50 1061.8 | ε 0.766
# Episode  534 | Score   708 | MaxTile   64 | MA50 1050.6 | ε 0.765
# Episode  535 | Score  1324 | MaxTile  128 | MA50 1036.7 | ε 0.765
# Episode  536 | Score   752 | MaxTile   64 | MA50 1048.2 | ε 0.764
# Episode  537 | Score  1368 | MaxTile  128 | MA50 1035.4 | ε 0.764
# Episode  538 | Score   956 | MaxTile  128 | MA50 1042.6 | ε 0.764
# Episode  539 | Score  1320 | MaxTile  128 | MA50 1047.0 | ε 0.763
# Episode  540 | Score   668 | MaxTile   64 | MA50 1049.0 | ε 0.763
# Episode  541 | Score   592 | MaxTile   64 | MA50 1048.2 | ε 0.763
# Episode  542 | Score  1368 | MaxTile  128 | MA50 1039.5 | ε 0.762
# Episode  543 | Score   768 | MaxTile   64 | MA50 1039.0 | ε 0.762
# Episode  544 | Score   292 | MaxTile   32 | MA50 1031.9 | ε 0.761
# Episode  545 | Score  1408 | MaxTile  128 | MA50 1010.4 | ε 0.761
# Episode  546 | Score  1152 | MaxTile  128 | MA50 1015.2 | ε 0.761
# Episode  547 | Score  1044 | MaxTile  128 | MA50 1028.0 | ε 0.760
# Episode  548 | Score   556 | MaxTile   64 | MA50 1034.0 | ε 0.760
# Episode  549 | Score   540 | MaxTile   64 | MA50 1037.3 | ε 0.760
# Episode  550 | Score  1328 | MaxTile  128 | MA50 1022.6 | ε 0.759
# Episode  551 | Score   568 | MaxTile   64 | MA50 1021.4 | ε 0.759
# Episode  552 | Score   560 | MaxTile   64 | MA50  997.4 | ε 0.758
# Episode  553 | Score  1288 | MaxTile  128 | MA50  994.3 | ε 0.758
# Episode  554 | Score  1348 | MaxTile  128 | MA50 1007.3 | ε 0.758
# Episode  555 | Score  1088 | MaxTile  128 | MA50 1022.8 | ε 0.757
# Episode  556 | Score   772 | MaxTile   64 | MA50 1025.6 | ε 0.757
# Episode  557 | Score  1364 | MaxTile  128 | MA50 1015.9 | ε 0.756
# Episode  558 | Score  2024 | MaxTile  128 | MA50 1002.3 | ε 0.756
# Episode  559 | Score   860 | MaxTile   64 | MA50 1033.0 | ε 0.756
# Episode  560 | Score  1288 | MaxTile  128 | MA50 1024.3 | ε 0.755
# Episode  561 | Score  1260 | MaxTile  128 | MA50 1024.3 | ε 0.755
# Episode  562 | Score   632 | MaxTile   64 | MA50 1039.7 | ε 0.755
# Episode  563 | Score  1108 | MaxTile  128 | MA50 1032.4 | ε 0.754
# Episode  564 | Score   628 | MaxTile   64 | MA50 1027.0 | ε 0.754
# Episode  565 | Score   752 | MaxTile   64 | MA50 1019.3 | ε 0.753
# Episode  566 | Score   728 | MaxTile   64 | MA50 1007.0 | ε 0.753
# Episode  567 | Score   628 | MaxTile   64 | MA50  994.5 | ε 0.753
# Episode  568 | Score   592 | MaxTile   64 | MA50  979.8 | ε 0.752
# Episode  569 | Score  1456 | MaxTile  128 | MA50  980.3 | ε 0.752
# Episode  570 | Score  1452 | MaxTile  128 | MA50 1003.4 | ε 0.752
# Episode  571 | Score   672 | MaxTile   64 | MA50 1012.6 | ε 0.751
# Episode  572 | Score  1424 | MaxTile  128 | MA50  975.7 | ε 0.751
# Episode  573 | Score  1984 | MaxTile  256 | MA50  991.6 | ε 0.750
# Episode  574 | Score   544 | MaxTile   64 | MA50 1007.0 | ε 0.750
# Episode  575 | Score  1944 | MaxTile  256 | MA50 1005.1 | ε 0.750
# Episode  576 | Score   592 | MaxTile   64 | MA50 1035.0 | ε 0.749
# Episode  577 | Score  1508 | MaxTile  128 | MA50 1030.5 | ε 0.749
# Episode  578 | Score   596 | MaxTile   64 | MA50 1021.8 | ε 0.749
# Episode  579 | Score  1404 | MaxTile  128 | MA50 1005.7 | ε 0.748
# Episode  580 | Score  1296 | MaxTile  128 | MA50 1006.5 | ε 0.748
# Episode  581 | Score   600 | MaxTile   64 | MA50 1023.4 | ε 0.747
# Episode  582 | Score  1076 | MaxTile  128 | MA50 1021.4 | ε 0.747
# Episode  583 | Score  2500 | MaxTile  256 | MA50 1016.3 | ε 0.747
# Episode  584 | Score  1848 | MaxTile  128 | MA50 1053.6 | ε 0.746
# Episode  585 | Score  1296 | MaxTile  128 | MA50 1076.4 | ε 0.746
# Episode  586 | Score   464 | MaxTile   64 | MA50 1075.8 | ε 0.746
# Episode  587 | Score  1496 | MaxTile  128 | MA50 1070.1 | ε 0.745
# Episode  588 | Score   892 | MaxTile   64 | MA50 1072.6 | ε 0.745
# Episode  589 | Score  1392 | MaxTile  128 | MA50 1071.4 | ε 0.744
# Episode  590 | Score  1800 | MaxTile  128 | MA50 1072.8 | ε 0.744
# Episode  591 | Score  1316 | MaxTile  128 | MA50 1095.4 | ε 0.744
# Episode  592 | Score   772 | MaxTile   64 | MA50 1109.9 | ε 0.743
# Episode  593 | Score   624 | MaxTile   64 | MA50 1098.0 | ε 0.743
# Episode  594 | Score   644 | MaxTile   64 | MA50 1095.1 | ε 0.743
# Episode  595 | Score   864 | MaxTile   64 | MA50 1102.2 | ε 0.742
# Episode  596 | Score   924 | MaxTile   64 | MA50 1091.3 | ε 0.742
# Episode  597 | Score   880 | MaxTile   64 | MA50 1086.7 | ε 0.742
# Episode  598 | Score  1176 | MaxTile  128 | MA50 1083.4 | ε 0.741
# Episode  599 | Score  1448 | MaxTile  128 | MA50 1095.8 | ε 0.741
# Episode  600 | Score   524 | MaxTile   64 | MA50 1114.0 | ε 0.740
#   → Eval @ ep 600: Avg 1149.2, Max 2836
#      Tile p25/p50/p75: 64.0/128.0/128.0
#      Tiles hist: {32: 4, 64: 45, 128: 38, 256: 13}
# Episode  601 | Score  1000 | MaxTile  128 | MA50 1097.9 | ε 0.740
# Episode  602 | Score  1232 | MaxTile  128 | MA50 1106.6 | ε 0.740
# Episode  603 | Score  1860 | MaxTile  128 | MA50 1120.0 | ε 0.739
# Episode  604 | Score  1168 | MaxTile  128 | MA50 1131.4 | ε 0.739
# Episode  605 | Score   284 | MaxTile   32 | MA50 1127.8 | ε 0.739
# Episode  606 | Score   616 | MaxTile   64 | MA50 1111.8 | ε 0.738
# Episode  607 | Score   676 | MaxTile   64 | MA50 1108.6 | ε 0.738
# Episode  608 | Score  1320 | MaxTile  128 | MA50 1094.9 | ε 0.737
# Episode  609 | Score  1876 | MaxTile  256 | MA50 1080.8 | ε 0.737
# Episode  610 | Score   580 | MaxTile   64 | MA50 1101.1 | ε 0.737
# Episode  611 | Score  1020 | MaxTile  128 | MA50 1087.0 | ε 0.736
# Episode  612 | Score  1108 | MaxTile  128 | MA50 1082.2 | ε 0.736
# Episode  613 | Score   548 | MaxTile   64 | MA50 1091.7 | ε 0.736
# Episode  614 | Score   696 | MaxTile   64 | MA50 1080.5 | ε 0.735
# Episode  615 | Score  1344 | MaxTile  128 | MA50 1081.8 | ε 0.735
# Episode  616 | Score   660 | MaxTile   64 | MA50 1093.7 | ε 0.734
# Episode  617 | Score   780 | MaxTile   64 | MA50 1092.3 | ε 0.734
# Episode  618 | Score  1432 | MaxTile  128 | MA50 1095.4 | ε 0.734
# Episode  619 | Score   372 | MaxTile   32 | MA50 1112.2 | ε 0.733
# Episode  620 | Score   656 | MaxTile   64 | MA50 1090.5 | ε 0.733
# Episode  621 | Score   628 | MaxTile   64 | MA50 1074.6 | ε 0.733
# Episode  622 | Score   652 | MaxTile   64 | MA50 1073.7 | ε 0.732
# Episode  623 | Score  1052 | MaxTile  128 | MA50 1058.2 | ε 0.732
# Episode  624 | Score   912 | MaxTile  128 | MA50 1039.6 | ε 0.732
# Episode  625 | Score   356 | MaxTile   32 | MA50 1047.0 | ε 0.731
# Episode  626 | Score  1296 | MaxTile  128 | MA50 1015.2 | ε 0.731
# Episode  627 | Score  1880 | MaxTile  128 | MA50 1029.3 | ε 0.730
# Episode  628 | Score   548 | MaxTile   64 | MA50 1036.7 | ε 0.730
# Episode  629 | Score  1120 | MaxTile  128 | MA50 1035.8 | ε 0.730
# Episode  630 | Score   572 | MaxTile   64 | MA50 1030.1 | ε 0.729
# Episode  631 | Score  1512 | MaxTile  128 | MA50 1015.6 | ε 0.729
# Episode  632 | Score   712 | MaxTile   64 | MA50 1033.8 | ε 0.729
# Episode  633 | Score  1100 | MaxTile  128 | MA50 1026.6 | ε 0.728
# Episode  634 | Score  1260 | MaxTile  128 | MA50  998.6 | ε 0.728
# Episode  635 | Score  1224 | MaxTile  128 | MA50  986.8 | ε 0.728
# Episode  636 | Score  1288 | MaxTile  128 | MA50  985.4 | ε 0.727
# Episode  637 | Score  1044 | MaxTile  128 | MA50 1001.8 | ε 0.727
# Episode  638 | Score  1024 | MaxTile  128 | MA50  992.8 | ε 0.726
# Episode  639 | Score   776 | MaxTile   64 | MA50  995.4 | ε 0.726
# Episode  640 | Score  1060 | MaxTile  128 | MA50  983.1 | ε 0.726
# Episode  641 | Score  1316 | MaxTile  128 | MA50  968.3 | ε 0.725
# Episode  642 | Score  1128 | MaxTile  128 | MA50  968.3 | ε 0.725
# Episode  643 | Score  1224 | MaxTile  128 | MA50  975.4 | ε 0.725
# Episode  644 | Score  1028 | MaxTile  128 | MA50  987.4 | ε 0.724
# Episode  645 | Score  2124 | MaxTile  128 | MA50  995.1 | ε 0.724
# Episode  646 | Score   552 | MaxTile   64 | MA50 1020.3 | ε 0.724
# Episode  647 | Score   856 | MaxTile   64 | MA50 1012.9 | ε 0.723
# Episode  648 | Score   784 | MaxTile   64 | MA50 1012.4 | ε 0.723
# Episode  649 | Score  1460 | MaxTile  128 | MA50 1004.6 | ε 0.722
# Episode  650 | Score  1292 | MaxTile  128 | MA50 1004.8 | ε 0.722
# Episode  651 | Score  1308 | MaxTile  128 | MA50 1020.2 | ε 0.722
# Episode  652 | Score  2720 | MaxTile  256 | MA50 1026.3 | ε 0.721
# Episode  653 | Score  1104 | MaxTile  128 | MA50 1056.1 | ε 0.721
# Episode  654 | Score  1372 | MaxTile  128 | MA50 1041.0 | ε 0.721
# Episode  655 | Score   420 | MaxTile   32 | MA50 1045.0 | ε 0.720
# Episode  656 | Score   728 | MaxTile   64 | MA50 1047.8 | ε 0.720
# Episode  657 | Score  1380 | MaxTile  128 | MA50 1050.0 | ε 0.720
# Episode  658 | Score  2268 | MaxTile  256 | MA50 1064.1 | ε 0.719
# Episode  659 | Score  1764 | MaxTile  256 | MA50 1083.0 | ε 0.719
# Episode  660 | Score  1404 | MaxTile  128 | MA50 1080.8 | ε 0.719
# Episode  661 | Score  1820 | MaxTile  256 | MA50 1097.3 | ε 0.718
# Episode  662 | Score   628 | MaxTile   64 | MA50 1113.3 | ε 0.718
# Episode  663 | Score   660 | MaxTile   64 | MA50 1103.7 | ε 0.717
# Episode  664 | Score   544 | MaxTile   64 | MA50 1105.9 | ε 0.717
# Episode  665 | Score  1276 | MaxTile  128 | MA50 1102.9 | ε 0.717
# Episode  666 | Score  2272 | MaxTile  256 | MA50 1101.5 | ε 0.716
# Episode  667 | Score   684 | MaxTile   64 | MA50 1133.8 | ε 0.716
# Episode  668 | Score   652 | MaxTile   64 | MA50 1131.8 | ε 0.716
# Episode  669 | Score  1412 | MaxTile  128 | MA50 1116.2 | ε 0.715
# Episode  670 | Score   656 | MaxTile   64 | MA50 1137.0 | ε 0.715
# Episode  671 | Score  1572 | MaxTile  128 | MA50 1137.0 | ε 0.715
# Episode  672 | Score  1068 | MaxTile  128 | MA50 1155.9 | ε 0.714
# Episode  673 | Score   788 | MaxTile   64 | MA50 1164.2 | ε 0.714
# Episode  674 | Score   388 | MaxTile   32 | MA50 1159.0 | ε 0.713
# Episode  675 | Score   656 | MaxTile   32 | MA50 1148.5 | ε 0.713
# Episode  676 | Score  1212 | MaxTile  128 | MA50 1154.5 | ε 0.713
# Episode  677 | Score   244 | MaxTile   32 | MA50 1152.8 | ε 0.712
# Episode  678 | Score  1408 | MaxTile  128 | MA50 1120.1 | ε 0.712
# Episode  679 | Score  1008 | MaxTile  128 | MA50 1137.3 | ε 0.712
# Episode  680 | Score  1216 | MaxTile  128 | MA50 1135.0 | ε 0.711
# Episode  681 | Score   304 | MaxTile   32 | MA50 1147.9 | ε 0.711
# Episode  682 | Score   696 | MaxTile   64 | MA50 1123.8 | ε 0.711
# Episode  683 | Score   740 | MaxTile   64 | MA50 1123.4 | ε 0.710
# Episode  684 | Score  1376 | MaxTile  128 | MA50 1116.2 | ε 0.710
# Episode  685 | Score  1904 | MaxTile  256 | MA50 1118.6 | ε 0.710
# Episode  686 | Score   604 | MaxTile   64 | MA50 1132.2 | ε 0.709
# Episode  687 | Score  1424 | MaxTile  128 | MA50 1118.5 | ε 0.709
# Episode  688 | Score  1212 | MaxTile  128 | MA50 1126.1 | ε 0.709
# Episode  689 | Score  2484 | MaxTile  256 | MA50 1129.8 | ε 0.708
# Episode  690 | Score  1500 | MaxTile  128 | MA50 1164.0 | ε 0.708
# Episode  691 | Score   868 | MaxTile   64 | MA50 1172.8 | ε 0.707
# Episode  692 | Score  1248 | MaxTile  128 | MA50 1163.8 | ε 0.707
# Episode  693 | Score   400 | MaxTile   32 | MA50 1166.2 | ε 0.707
# Episode  694 | Score  1328 | MaxTile  128 | MA50 1149.8 | ε 0.706
# Episode  695 | Score  1448 | MaxTile  128 | MA50 1155.8 | ε 0.706
# Episode  696 | Score   740 | MaxTile   64 | MA50 1142.2 | ε 0.706
# Episode  697 | Score   804 | MaxTile   64 | MA50 1146.0 | ε 0.705
# Episode  698 | Score  1484 | MaxTile  128 | MA50 1145.0 | ε 0.705
# Episode  699 | Score   692 | MaxTile   64 | MA50 1159.0 | ε 0.705
# Episode  700 | Score  1056 | MaxTile  128 | MA50 1143.6 | ε 0.704
#   → Eval @ ep 700: Avg 1187.8, Max 2608
#      Tile p25/p50/p75: 64.0/128.0/128.0
#      Tiles hist: {32: 3, 64: 31, 128: 62, 256: 4}
# Episode  701 | Score   488 | MaxTile   64 | MA50 1138.9 | ε 0.704
# Episode  702 | Score  1388 | MaxTile  128 | MA50 1122.5 | ε 0.704
# Episode  703 | Score   476 | MaxTile   32 | MA50 1095.8 | ε 0.703
# Episode  704 | Score   600 | MaxTile   64 | MA50 1083.3 | ε 0.703
# Episode  705 | Score  1284 | MaxTile  128 | MA50 1067.8 | ε 0.703
# ...
# Episode 5182 | Score   416 | MaxTile   64 | MA50  818.2 | ε 0.075
# Episode 5183 | Score  1128 | MaxTile   64 | MA50  789.8 | ε 0.075
# Episode 5184 | Score   476 | MaxTile   64 | MA50  804.2 | ε 0.075
# Episode 5185 | Score   768 | MaxTile   64 | MA50  786.3 | ε 0.075
# Episode 5186 | Score  1764 | MaxTile  256 | MA50  773.4 | ε 0.075
# Episode 5187 | Score   628 | MaxTile   64 | MA50  802.2 | ε 0.075
# Episode 5188 | Score  1528 | MaxTile  128 | MA50  774.8 | ε 0.075
# Episode 5189 | Score   416 | MaxTile   32 | MA50  795.3 | ε 0.075
# Episode 5190 | Score   700 | MaxTile   64 | MA50  789.0 | ε 0.075
# Episode 5191 | Score   600 | MaxTile   64 | MA50  791.5 | ε 0.075
# Episode 5192 | Score  1104 | MaxTile  128 | MA50  790.1 | ε 0.074
# Episode 5193 | Score   864 | MaxTile   64 | MA50  805.2 | ε 0.074
# Episode 5194 | Score   680 | MaxTile   64 | MA50  808.4 | ε 0.074
# Episode 5195 | Score  1056 | MaxTile  128 | MA50  808.6 | ε 0.074
# Episode 5196 | Score   668 | MaxTile   64 | MA50  824.2 | ε 0.074
# Episode 5197 | Score   696 | MaxTile   64 | MA50  831.5 | ε 0.074
# Episode 5198 | Score   704 | MaxTile   64 | MA50  822.7 | ε 0.074
# Episode 5199 | Score  2012 | MaxTile  256 | MA50  828.8 | ε 0.074
# Episode 5200 | Score   648 | MaxTile   64 | MA50  842.4 | ε 0.074
#   → Eval @ ep 5200: Avg 846.6, Max 2716
#      Tile p25/p50/p75: 64.0/64.0/128.0
#      Tiles hist: {16: 3, 32: 21, 64: 41, 128: 31, 256: 4}
# Episode 5201 | Score   420 | MaxTile   32 | MA50  835.8 | ε 0.074
# Episode 5202 | Score   616 | MaxTile   64 | MA50  831.4 | ε 0.074
# Episode 5203 | Score   384 | MaxTile   32 | MA50  831.3 | ε 0.074
# Episode 5204 | Score  1568 | MaxTile  128 | MA50  825.8 | ε 0.074
# Episode 5205 | Score   792 | MaxTile   64 | MA50  843.0 | ε 0.074
# Episode 5206 | Score   752 | MaxTile   64 | MA50  843.9 | ε 0.074
# Episode 5207 | Score   244 | MaxTile   32 | MA50  830.6 | ε 0.074
# Episode 5208 | Score   228 | MaxTile   16 | MA50  810.9 | ε 0.074
# Episode 5209 | Score  1024 | MaxTile  128 | MA50  806.9 | ε 0.074
# Episode 5210 | Score   380 | MaxTile   32 | MA50  816.0 | ε 0.074
# Episode 5211 | Score  1092 | MaxTile  128 | MA50  818.3 | ε 0.074
# Episode 5212 | Score   448 | MaxTile   32 | MA50  830.8 | ε 0.074
# Episode 5213 | Score   880 | MaxTile   64 | MA50  817.3 | ε 0.074
# Episode 5214 | Score   460 | MaxTile   64 | MA50  827.9 | ε 0.074
# Episode 5215 | Score  1116 | MaxTile  128 | MA50  808.9 | ε 0.074
# Episode 5216 | Score  2028 | MaxTile  256 | MA50  816.5 | ε 0.074
# Episode 5217 | Score   412 | MaxTile   32 | MA50  843.0 | ε 0.074
# Episode 5218 | Score   460 | MaxTile   32 | MA50  845.0 | ε 0.074
# Episode 5219 | Score  1416 | MaxTile  128 | MA50  839.8 | ε 0.073
# Episode 5220 | Score  1852 | MaxTile  128 | MA50  856.9 | ε 0.073
# Episode 5221 | Score   868 | MaxTile   64 | MA50  870.2 | ε 0.073
# Episode 5222 | Score   824 | MaxTile   64 | MA50  871.8 | ε 0.073
# Episode 5223 | Score   544 | MaxTile   64 | MA50  863.7 | ε 0.073
# Episode 5224 | Score  1364 | MaxTile  128 | MA50  856.1 | ε 0.073
# Episode 5225 | Score   884 | MaxTile   64 | MA50  877.8 | ε 0.073
# Episode 5226 | Score   436 | MaxTile   32 | MA50  854.0 | ε 0.073
# Episode 5227 | Score  1512 | MaxTile  128 | MA50  846.6 | ε 0.073
# Episode 5228 | Score   488 | MaxTile   64 | MA50  870.4 | ε 0.073
# Episode 5229 | Score  1080 | MaxTile  128 | MA50  863.0 | ε 0.073
# Episode 5230 | Score   516 | MaxTile   64 | MA50  870.8 | ε 0.073
# Episode 5231 | Score  2072 | MaxTile  256 | MA50  868.1 | ε 0.073
# Episode 5232 | Score  1248 | MaxTile  128 | MA50  880.3 | ε 0.073
# Episode 5233 | Score   604 | MaxTile   64 | MA50  897.0 | ε 0.073
# Episode 5234 | Score  1272 | MaxTile  128 | MA50  886.5 | ε 0.073
# Episode 5235 | Score  1724 | MaxTile  128 | MA50  902.4 | ε 0.073
# Episode 5236 | Score  1096 | MaxTile   64 | MA50  921.5 | ε 0.073
# Episode 5237 | Score  1284 | MaxTile  128 | MA50  908.2 | ε 0.073
# Episode 5238 | Score  1712 | MaxTile  128 | MA50  921.3 | ε 0.073
# Episode 5239 | Score  2864 | MaxTile  256 | MA50  925.0 | ε 0.073
# Episode 5240 | Score  2340 | MaxTile  256 | MA50  973.9 | ε 0.073
# Episode 5241 | Score   344 | MaxTile   32 | MA50 1006.7 | ε 0.073
# Episode 5242 | Score  1120 | MaxTile  128 | MA50 1001.6 | ε 0.073
# Episode 5243 | Score   800 | MaxTile   64 | MA50 1001.9 | ε 0.073
# Episode 5244 | Score  2032 | MaxTile  256 | MA50 1000.6 | ε 0.073
# Episode 5245 | Score   948 | MaxTile   64 | MA50 1027.7 | ε 0.073
# Episode 5246 | Score  2548 | MaxTile  256 | MA50 1025.5 | ε 0.073
# Episode 5247 | Score  1484 | MaxTile  128 | MA50 1063.1 | ε 0.072
# Episode 5248 | Score   596 | MaxTile   64 | MA50 1078.9 | ε 0.072
# Episode 5249 | Score  1008 | MaxTile   64 | MA50 1076.7 | ε 0.072
# Episode 5250 | Score  1308 | MaxTile  128 | MA50 1056.6 | ε 0.072
# Episode 5251 | Score  1360 | MaxTile  128 | MA50 1069.8 | ε 0.072
# Episode 5252 | Score  2332 | MaxTile  256 | MA50 1088.6 | ε 0.072
# Episode 5253 | Score  1360 | MaxTile  128 | MA50 1123.0 | ε 0.072
# Episode 5254 | Score  1104 | MaxTile   64 | MA50 1142.5 | ε 0.072
# Episode 5255 | Score   520 | MaxTile   32 | MA50 1133.2 | ε 0.072
# Episode 5256 | Score  2084 | MaxTile  256 | MA50 1127.8 | ε 0.072
# Episode 5257 | Score   856 | MaxTile   64 | MA50 1154.4 | ε 0.072
# Episode 5258 | Score   544 | MaxTile   64 | MA50 1166.6 | ε 0.072
# Episode 5259 | Score   684 | MaxTile   64 | MA50 1173.0 | ε 0.072
# Episode 5260 | Score  1696 | MaxTile  128 | MA50 1166.2 | ε 0.072
# Episode 5261 | Score  1032 | MaxTile   64 | MA50 1192.5 | ε 0.072
# Episode 5262 | Score   900 | MaxTile   64 | MA50 1191.3 | ε 0.072
# Episode 5263 | Score  2184 | MaxTile  256 | MA50 1200.3 | ε 0.072
# Episode 5264 | Score  1604 | MaxTile  128 | MA50 1226.4 | ε 0.072
# Episode 5265 | Score  1304 | MaxTile  128 | MA50 1249.3 | ε 0.072
# Episode 5266 | Score  1852 | MaxTile  128 | MA50 1253.0 | ε 0.072
# Episode 5267 | Score  2508 | MaxTile  256 | MA50 1249.5 | ε 0.072
# Episode 5268 | Score   524 | MaxTile   32 | MA50 1291.4 | ε 0.072
# Episode 5269 | Score  1172 | MaxTile  128 | MA50 1292.7 | ε 0.072
# Episode 5270 | Score   896 | MaxTile   64 | MA50 1287.8 | ε 0.072
# Episode 5271 | Score  2664 | MaxTile  256 | MA50 1268.7 | ε 0.072
# Episode 5272 | Score  1384 | MaxTile  128 | MA50 1304.6 | ε 0.072
# Episode 5273 | Score  1124 | MaxTile  128 | MA50 1315.8 | ε 0.072
# Episode 5274 | Score  1008 | MaxTile   64 | MA50 1327.4 | ε 0.071
# Episode 5275 | Score  1312 | MaxTile  128 | MA50 1320.3 | ε 0.071
# Episode 5276 | Score  1548 | MaxTile  128 | MA50 1328.9 | ε 0.071
# Episode 5277 | Score   640 | MaxTile   64 | MA50 1351.1 | ε 0.071
# Episode 5278 | Score   760 | MaxTile   64 | MA50 1333.7 | ε 0.071
# Episode 5279 | Score  1164 | MaxTile  128 | MA50 1339.1 | ε 0.071
# Episode 5280 | Score  1728 | MaxTile  128 | MA50 1340.8 | ε 0.071
# Episode 5281 | Score  1624 | MaxTile  128 | MA50 1365.0 | ε 0.071
# Episode 5282 | Score  2196 | MaxTile  256 | MA50 1356.1 | ε 0.071
# Episode 5283 | Score   648 | MaxTile   64 | MA50 1375.0 | ε 0.071
# Episode 5284 | Score   688 | MaxTile   64 | MA50 1375.9 | ε 0.071
# Episode 5285 | Score  2312 | MaxTile  256 | MA50 1364.2 | ε 0.071
# Episode 5286 | Score   756 | MaxTile   64 | MA50 1376.0 | ε 0.071
# Episode 5287 | Score  1420 | MaxTile  128 | MA50 1369.2 | ε 0.071
# Episode 5288 | Score  2912 | MaxTile  256 | MA50 1371.9 | ε 0.071
# Episode 5289 | Score  1704 | MaxTile  128 | MA50 1395.9 | ε 0.071
# Episode 5290 | Score   744 | MaxTile   64 | MA50 1372.7 | ε 0.071
# Episode 5291 | Score  2104 | MaxTile  256 | MA50 1340.8 | ε 0.071
# Episode 5292 | Score  1060 | MaxTile  128 | MA50 1376.0 | ε 0.071
# Episode 5293 | Score   596 | MaxTile   64 | MA50 1374.8 | ε 0.071
# Episode 5294 | Score  3568 | MaxTile  512 | MA50 1370.7 | ε 0.071
# Episode 5295 | Score  2020 | MaxTile  256 | MA50 1401.4 | ε 0.071
# Episode 5296 | Score  1800 | MaxTile  256 | MA50 1422.9 | ε 0.071
# Episode 5297 | Score  1388 | MaxTile  128 | MA50 1407.9 | ε 0.071
# Episode 5298 | Score  2436 | MaxTile  256 | MA50 1406.0 | ε 0.071
# Episode 5299 | Score  2552 | MaxTile  256 | MA50 1442.8 | ε 0.071
# Episode 5300 | Score  1436 | MaxTile  128 | MA50 1473.7 | ε 0.071
#   → Eval @ ep 5300: Avg 2081.1, Max 6444
#      Tile p25/p50/p75: 128.0/128.0/256.0
#      Tiles hist: {32: 2, 64: 14, 128: 40, 256: 35, 512: 9}
# Episode 5301 | Score  1488 | MaxTile  128 | MA50 1476.2 | ε 0.071
# Episode 5302 | Score  1328 | MaxTile  128 | MA50 1478.8 | ε 0.070
# Episode 5303 | Score  2508 | MaxTile  256 | MA50 1458.7 | ε 0.070
# Episode 5304 | Score  1696 | MaxTile  128 | MA50 1481.7 | ε 0.070
# Episode 5305 | Score  1180 | MaxTile  128 | MA50 1493.5 | ε 0.070
# Episode 5306 | Score  1588 | MaxTile  128 | MA50 1506.7 | ε 0.070
# Episode 5307 | Score   792 | MaxTile   64 | MA50 1496.8 | ε 0.070
# Episode 5308 | Score  2548 | MaxTile  256 | MA50 1495.5 | ε 0.070
# Episode 5309 | Score  1504 | MaxTile  128 | MA50 1535.6 | ε 0.070
# Episode 5310 | Score  1636 | MaxTile  128 | MA50 1552.0 | ε 0.070
# Episode 5311 | Score  1408 | MaxTile  128 | MA50 1550.8 | ε 0.070
# Episode 5312 | Score  1668 | MaxTile  128 | MA50 1558.3 | ε 0.070
# Episode 5313 | Score   704 | MaxTile   64 | MA50 1573.7 | ε 0.070
# Episode 5314 | Score  2092 | MaxTile  256 | MA50 1544.1 | ε 0.070
# Episode 5315 | Score  1144 | MaxTile  128 | MA50 1553.8 | ε 0.070
# Episode 5316 | Score  1636 | MaxTile  128 | MA50 1550.6 | ε 0.070
# Episode 5317 | Score  1156 | MaxTile  128 | MA50 1546.3 | ε 0.070
# Episode 5318 | Score   936 | MaxTile   64 | MA50 1519.3 | ε 0.070
# Episode 5319 | Score  2088 | MaxTile  256 | MA50 1527.5 | ε 0.070
# Episode 5320 | Score  1860 | MaxTile  128 | MA50 1545.8 | ε 0.070
# Episode 5321 | Score  1796 | MaxTile  128 | MA50 1565.1 | ε 0.070
# Episode 5322 | Score  2712 | MaxTile  256 | MA50 1547.8 | ε 0.070
# Episode 5323 | Score  2552 | MaxTile  256 | MA50 1574.3 | ε 0.070
# Episode 5324 | Score  1512 | MaxTile  128 | MA50 1602.9 | ε 0.070
# Episode 5325 | Score  4044 | MaxTile  512 | MA50 1613.0 | ε 0.070
# Episode 5326 | Score  1368 | MaxTile  128 | MA50 1667.6 | ε 0.070
# Episode 5327 | Score  1216 | MaxTile  128 | MA50 1664.0 | ε 0.070
# Episode 5328 | Score  2320 | MaxTile  128 | MA50 1675.5 | ε 0.070
# Episode 5329 | Score  2600 | MaxTile  256 | MA50 1706.7 | ε 0.070
# Episode 5330 | Score  1324 | MaxTile  128 | MA50 1735.4 | ε 0.070
# Episode 5331 | Score   612 | MaxTile   64 | MA50 1727.4 | ε 0.069
# Episode 5332 | Score   344 | MaxTile   32 | MA50 1707.1 | ε 0.069
# Episode 5333 | Score   308 | MaxTile   32 | MA50 1670.1 | ε 0.069
# Episode 5334 | Score   692 | MaxTile   64 | MA50 1663.3 | ε 0.069
# Episode 5335 | Score  1896 | MaxTile  128 | MA50 1663.4 | ε 0.069
# Episode 5336 | Score  2664 | MaxTile  256 | MA50 1655.0 | ε 0.069
# Episode 5337 | Score   644 | MaxTile   64 | MA50 1693.2 | ε 0.069
# Episode 5338 | Score  2080 | MaxTile  256 | MA50 1677.7 | ε 0.069
# Episode 5339 | Score  1536 | MaxTile  128 | MA50 1661.0 | ε 0.069
# Episode 5340 | Score  2036 | MaxTile  256 | MA50 1657.7 | ε 0.069
# Episode 5341 | Score  1864 | MaxTile  128 | MA50 1683.5 | ε 0.069
# Episode 5342 | Score  1460 | MaxTile  128 | MA50 1678.7 | ε 0.069
# Episode 5343 | Score  2088 | MaxTile  128 | MA50 1686.7 | ε 0.069
# Episode 5344 | Score  1840 | MaxTile  256 | MA50 1716.6 | ε 0.069
# Episode 5345 | Score  1432 | MaxTile  128 | MA50 1682.0 | ε 0.069
# Episode 5346 | Score  2000 | MaxTile  128 | MA50 1670.2 | ε 0.069
# Episode 5347 | Score  2340 | MaxTile  256 | MA50 1674.2 | ε 0.069
# Episode 5348 | Score   608 | MaxTile   64 | MA50 1693.3 | ε 0.069
# Episode 5349 | Score  1728 | MaxTile  128 | MA50 1656.7 | ε 0.069
# Episode 5350 | Score  1444 | MaxTile  128 | MA50 1640.2 | ε 0.069
# Episode 5351 | Score  2824 | MaxTile  256 | MA50 1640.4 | ε 0.069
# Episode 5352 | Score  1188 | MaxTile  128 | MA50 1667.1 | ε 0.069
# Episode 5353 | Score  1968 | MaxTile  256 | MA50 1664.3 | ε 0.069
# Episode 5354 | Score  1404 | MaxTile  128 | MA50 1653.5 | ε 0.069
# Episode 5355 | Score  2440 | MaxTile  256 | MA50 1647.7 | ε 0.069
# Episode 5356 | Score  1604 | MaxTile  128 | MA50 1672.9 | ε 0.069
# Episode 5357 | Score  1324 | MaxTile  128 | MA50 1673.2 | ε 0.069
# Episode 5358 | Score  1460 | MaxTile  128 | MA50 1683.8 | ε 0.069
# Episode 5359 | Score  1460 | MaxTile  128 | MA50 1662.1 | ε 0.069
# Episode 5360 | Score  2608 | MaxTile  256 | MA50 1661.2 | ε 0.068
# Episode 5361 | Score  2972 | MaxTile  256 | MA50 1680.6 | ε 0.068
# Episode 5362 | Score   636 | MaxTile   64 | MA50 1711.9 | ε 0.068
# Episode 5363 | Score  3384 | MaxTile  256 | MA50 1691.3 | ε 0.068
# Episode 5364 | Score  1780 | MaxTile  128 | MA50 1744.9 | ε 0.068
# Episode 5365 | Score  1768 | MaxTile  128 | MA50 1738.6 | ε 0.068
# Episode 5366 | Score  1196 | MaxTile  128 | MA50 1751.1 | ε 0.068
# Episode 5367 | Score  1600 | MaxTile  128 | MA50 1742.3 | ε 0.068
# Episode 5368 | Score  1112 | MaxTile   64 | MA50 1751.2 | ε 0.068
# Episode 5369 | Score  1272 | MaxTile  128 | MA50 1754.7 | ε 0.068
# Episode 5370 | Score   684 | MaxTile   32 | MA50 1738.4 | ε 0.068
# Episode 5371 | Score  1728 | MaxTile  128 | MA50 1714.9 | ε 0.068
# Episode 5372 | Score  2300 | MaxTile  256 | MA50 1713.5 | ε 0.068
# Episode 5373 | Score   860 | MaxTile   64 | MA50 1705.3 | ε 0.068
# Episode 5374 | Score  3140 | MaxTile  256 | MA50 1671.4 | ε 0.068
# Episode 5375 | Score  1336 | MaxTile  128 | MA50 1704.0 | ε 0.068
# Episode 5376 | Score  2568 | MaxTile  256 | MA50 1649.8 | ε 0.068
# Episode 5377 | Score  2772 | MaxTile  256 | MA50 1673.8 | ε 0.068
# Episode 5378 | Score   780 | MaxTile   64 | MA50 1705.0 | ε 0.068
# Episode 5379 | Score  2652 | MaxTile  256 | MA50 1674.2 | ε 0.068
# Episode 5380 | Score  2336 | MaxTile  256 | MA50 1675.2 | ε 0.068
# Episode 5381 | Score  2120 | MaxTile  256 | MA50 1695.4 | ε 0.068
# Episode 5382 | Score  1552 | MaxTile  128 | MA50 1725.6 | ε 0.068
# Episode 5383 | Score  2464 | MaxTile  256 | MA50 1749.8 | ε 0.068
# Episode 5384 | Score  1052 | MaxTile   64 | MA50 1792.9 | ε 0.068
# Episode 5385 | Score  1560 | MaxTile  128 | MA50 1800.1 | ε 0.068
# Episode 5386 | Score  1756 | MaxTile  128 | MA50 1793.4 | ε 0.068
# Episode 5387 | Score   708 | MaxTile   64 | MA50 1775.2 | ε 0.068
# Episode 5388 | Score   820 | MaxTile   64 | MA50 1776.5 | ε 0.068
# Episode 5389 | Score   956 | MaxTile   64 | MA50 1751.3 | ε 0.067
# Episode 5390 | Score  1416 | MaxTile  128 | MA50 1739.7 | ε 0.067
# Episode 5391 | Score   876 | MaxTile   64 | MA50 1727.3 | ε 0.067
# Episode 5392 | Score  1588 | MaxTile  128 | MA50 1707.5 | ε 0.067
# Episode 5393 | Score   364 | MaxTile   32 | MA50 1710.1 | ε 0.067
# Episode 5394 | Score  2760 | MaxTile  256 | MA50 1675.6 | ε 0.067
# Episode 5395 | Score   924 | MaxTile   64 | MA50 1694.0 | ε 0.067
# Episode 5396 | Score  1852 | MaxTile  128 | MA50 1683.8 | ε 0.067
# Episode 5397 | Score  1392 | MaxTile  128 | MA50 1680.9 | ε 0.067
# Episode 5398 | Score  1292 | MaxTile  128 | MA50 1661.9 | ε 0.067
# Episode 5399 | Score  3740 | MaxTile  512 | MA50 1675.6 | ε 0.067
# Episode 5400 | Score  2284 | MaxTile  256 | MA50 1715.8 | ε 0.067
#   → Eval @ ep 5400: Avg 2187.1, Max 5156
#      Tile p25/p50/p75: 128.0/128.0/256.0
#      Tiles hist: {32: 1, 64: 10, 128: 40, 256: 46, 512: 3}
# Episode 5401 | Score  2172 | MaxTile  256 | MA50 1732.6 | ε 0.067
# Episode 5402 | Score  3772 | MaxTile  512 | MA50 1719.6 | ε 0.067
# Episode 5403 | Score  2896 | MaxTile  256 | MA50 1771.3 | ε 0.067
# Episode 5404 | Score  1016 | MaxTile   64 | MA50 1789.8 | ε 0.067
# Episode 5405 | Score   904 | MaxTile   64 | MA50 1782.1 | ε 0.067
# Episode 5406 | Score  2500 | MaxTile  256 | MA50 1751.4 | ε 0.067
# Episode 5407 | Score  3140 | MaxTile  256 | MA50 1769.3 | ε 0.067
# Episode 5408 | Score  2088 | MaxTile  128 | MA50 1805.6 | ε 0.067
# Episode 5409 | Score  2264 | MaxTile  256 | MA50 1818.2 | ε 0.067
# Episode 5410 | Score  1668 | MaxTile  128 | MA50 1834.2 | ε 0.067
# Episode 5411 | Score  2944 | MaxTile  256 | MA50 1815.4 | ε 0.067
# ✅ Converged at ep 5411
#
# === Move Frequencies Overall ===
# Up: 126827
# Right: 195876
# Down: 130270
# Left: 156060
#
# === FINAL ===
# Highest tile over everything: 512
# Eval Avg: 2533.72  |  Max Score: 6212
# Eval Tiles: Counter({256: 42, 128: 41, 512: 10, 64: 6, 32: 1})
# Eval Moves: defaultdict(<class 'int'>, {'Up': 16287, 'Right': 5810, 'Left': 1140, 'Down': 340})

# %%
du_ma = np.convolve(dueling_scores, np.ones(100)/100, mode='valid')
print(du_ma.max())
